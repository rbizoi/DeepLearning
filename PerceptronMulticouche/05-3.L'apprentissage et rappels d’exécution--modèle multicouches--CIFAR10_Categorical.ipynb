# %% [markdown]
# <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'>CIFAR10</div>
# <div style='text-align: center'>
#     <img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/CIFAR10.png" width="512">
# </div>
#
# > https://www.larousse.fr/dictionnaires/francais/inf%C3%A9rence/42907<br><br>
#
# >> **inférence** : Opération par laquelle on passe d'une assertion considérée comme vraie à une autre assertion au moyen d'un système de règles qui rend cette deuxième assertion également vraie.<br>
#
# >> **Inférence statistique** : Ensemble des méthodes permettant de formuler en termes probabilistes un jugement sur une population à partir des résultats observés sur un échantillon extrait au hasard de cette population.<br>
#
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ['TF_XLA_FLAGS']='--tf_xla_auto_jit=1,--tf_xla_always_defer_compilation=true'
# os.environ['XLA_FLAGS']='--xla_backend_optimization_level=0,--xla_gpu_autotune_level=4,--xla_gpu_disable_ptxas_optimizations=true,--xla_gpu_use_cudnn_batchnorm_level=2'
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, pickle, time
from matplotlib import pyplot as plt
from datetime import datetime as dt

import matplotlib.font_manager as fm
from matplotlib.lines import Line2D

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist,fashion_mnist,cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D


from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer, confusion_matrix, roc_curve, auc, accuracy_score, log_loss, hamming_loss, \
                            precision_score, recall_score, f1_score, fbeta_score, jaccard_score, \
                            precision_recall_curve, average_precision_score, balanced_accuracy_score, \
                            classification_report,roc_auc_score

tf.get_logger().setLevel('ERROR')# Suppress TensorFlow logging (2)

# %%
print("Tensorflow\t : %s\tCUDA %s\tGPU %s\tXLA %s\nKeras\t\t : %s\nPandas\t\t : %s\nNumPy\t\t : %s"%
      (tf.__version__, 
       tf.test.is_built_with_cuda(), 
       tf.test.is_built_with_gpu_support(), 
       tf.test.is_built_with_xla(), 
       tf.keras.__version__, 
       pd.__version__, 
       np.__version__))
# Out:
# Tensorflow	 : 2.17.0	CUDA True	GPU True	XLA True
# Keras		 : 3.6.0
# Pandas		 : 2.2.2
# NumPy		 : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des GPUs presents</div></b>

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) >  0 :
    for i, gpu in enumerate(physical_devices):
        tf.config.experimental.set_memory_growth(physical_devices[i], True)

    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('Le système est initialisé avec {0:d} GPUs'.format(strategy.num_replicas_in_sync))
# Out:
# Le système est initialisé avec 1 GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751893685.398049 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.419887 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.419999 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751893685.426873 1227225 service.cc:146] XLA service 0x4149ef70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751893685.426917 1227225 service.cc:154]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1751893685.488752 1227381 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.488883 1227225 service.cc:146] XLA service 0x3e8015e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751893685.488903 1227225 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1751893685.489080 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.489212 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.489357 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.492688 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751893685.492787 1227225 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
palette = [
            "#030aa7", "#e50000", "#d8863b", "#005f6a", "#6b7c85", "#751973", "#d1e5f0", "#fddbc7",
            "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#f5054f", "#a0450e",
            "#0339f8", "#f4320c", "#fec615", "#017a79", "#85a3b2", "#fe2f4a", "#a00498", "#b04e0f",
            "#0165fc", "#ff724c", "#fddc5c", "#11875d", "#89a0b0", "#fe828c", "#cb00f5", "#b75203",
            "#0485d1", "#ff7855", "#fbeeac", "#0cb577", "#95a3a6", "#ffb7ce", "#c071fe", "#ca6b02",
            "#92c5de", "#f4a582", "#fef69e", "#18d17b", "#c5c9c7", "#ffcfdc", "#caa0ff", "#cb7723",
            "#d1e5f0", "#fddbc7", "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#d8863b",
            "#030764", "#be0119", "#dbb40c", "#005249", "#3c4142", "#cb0162", "#5d1451", "#653700",
            "#040348", "#67001f", "#b27a01", "#002d04", "#000000", "#a0025c", "#490648", "#3c0008"
          ]

# %%
nom_projet                = "05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical"
repertoireProjet          = os.getcwd()
repertoireEnregistrement  = repertoireProjet +'/'+nom_projet+ '/repertoire.images'
repertoireSauvegardes     = repertoireProjet +'/'+nom_projet+ '/repertoire.sauvegardes'

def controleExistenceRepertoire(directory, create_if_needed=True):
    """Voir si le répertoire existe. S'il n'existe pas il est créé."""
    path_exists = os.path.exists(directory)
    if path_exists:
        if not os.path.isdir(directory):
            raise Exception("Trouvé le nom "+directory+" mais c'est un fichier, pas un répertoire")
            return False
        return True
    if create_if_needed:
        os.makedirs(directory)
        
controleExistenceRepertoire(repertoireEnregistrement)
controleExistenceRepertoire(repertoireSauvegardes)

def sauvegarderImage( fichier):
    """Enregistrez la figure. Appelez la méthode juste avant plt.show ()."""
    plt.savefig(os.path.join(repertoireEnregistrement,
                             fichier+f"--{dt.now().strftime('%Y_%m_%d_%H.%M.%S')}.png"), 
                             dpi=600, 
                             bbox_inches='tight')
    
def sauvegarderModelPoids(model, fichierPoids, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez les poids du modèle Keras."""
    if fichierPoids != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichierPoids))
        model.save_weights(nomFichier)

def sauvegarderModel(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez le modèle Keras."""
    if fichier != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
        model.save(nomFichier)

def lectureModelPoids(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Si le fichier existe, il est chargé et retourne True, sinon retourne False."""
    nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
    if os.path.exists(nomFichier):
        if os.path.isfile(nomFichier):
            model.load_weights(nomFichier)
            return True
    return False

def sauvegardeHistorique(model,
                         repertoireSauvegardes,
                         nomSauvegarde='one_hidden_layer_history_batch_size_1'):

    history = pd.DataFrame( model.history)
    history.reset_index(inplace=True)
    history.rename(columns={'index':'epoch'},inplace=True)
    history.to_parquet(os.path.join(repertoireSauvegardes,f'{nomSauvegarde}.gzip'),compression='gzip', engine='pyarrow') 
    return history

def afficheHistoriqueEntrainement(history, palette):
    fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(48,16));
    markersize = 8
    linewidth=2
    
    graph = sns.lineplot(x='epoch', 
                         y='accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='val_accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    
    graph = sns.lineplot(x='epoch', 
                         y='loss',  
                         data=history,
                         ax=ax[1],      
                         label='loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_loss',  
                         data=history,
                         ax=ax[1],      
                         label='val_loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    sauvegarderImage('afficheHistoriqueEntrainement')

def afficheMatriceConfusion(observations,predictions,dictLabels):
    plt.figure(figsize=(8,8))
    sns.set(font_scale=1.5)
    sns.heatmap(pd.crosstab(observations,predictions), 
                fmt= '.0f',
                linewidths=0.3,
                #vmax=1.0, 
                square=True, 
                cmap=plt.cm.Blues,
                linecolor='white', 
                annot=True,
                cbar=False,
                xticklabels=dictLabels.values(), 
                yticklabels=dictLabels.values()
               );
    plt.xlabel('Observations', fontsize = 18);
    plt.ylabel('Prédictions', fontsize = 18);
    sauvegarderImage('afficheMatriceConfusion')

def executeApprentissageChoixClassifieurs(model,
                                          X_test,
                                          y_test,
                                          label_dict,
                                          couleurs,
                                          nom_essai = 'initial'
                                         ):
    
    def afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict):
        plt.figure(figsize=(24, 24));
        for i, color in zip(range(nbClasses), palette):
            plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
                     label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
                                                             ''.format(i, aucROCt[i]))
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('Taux de faux Positifs-(1 - Spécificité) = VN / (FP + VN)',size=18)
        plt.ylabel('Taux de vrais positifs-Sensibilité = VP / (VP + FN)',size=18)
        plt.title('Courbe ROC (Receiver Operating Caracteristic) -- ',size=20)
        plt.legend(loc="lower right"); #, fontsize='large'
        sauvegarderImage('Courbe ROC')
        
        plt.figure(figsize=(24,24));
    
        f_scores = np.linspace(0.2, 0.9, num=8)
        for f_score in f_scores:
            x = np.linspace(0.01, 1)
            y = f_score * x / (2 * x - f_score)
            l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
            plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
    
        for i, color in zip(range(nbClasses), palette):
            plt.step(sensibilites[i], 
                         precisions[i], 
                         where='post', 
                         color=color, 
                         lw=lw, 
                         label=f"{label_dict[i]}(APR = {avgPrecRec[label_dict[i]]:0.8f})"
                    )
            plt.fill_between(sensibilites[i], precisions[i], step='post', alpha=0.05)            
    
            # plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
            #          label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
            #                                                  ''.format(i, aucROCt[i]))        
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])        
        plt.xlabel('Sensibilité/Rappel(Recall) = VP / (VP + FN)',size=18)
        plt.ylabel('Précision = VP / (VP + FP)',size=18)        
        plt.title('Courbe Précision-Rappel',size=20)
        plt.legend(loc="lower right") # , fontsize = 'large'
        sauvegarderImage('Courbe Précision-Rappel')
    
    cvF1, cvF1SD, cvAccuracy, cvAccSD, aucROC, avgPrecRec, accuracy, balanced_accuracy, logloss, hammingloss, precision, sensibilite, \
    f1, f2, f05, jaccard, vrais_negatifs, faux_positifs, faux_negatifs, vrais_positifs, total_positifs, aucROCtn = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(),\
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    #
    oneloss, precision_micro, precision_macro, precision_weighted, \
    sensibilite_macro, sensibilite_micro, sensibilite_weighted, \
    f1_micro, f1_macro, f1_weighted,f2_micro,f2_macro,f2_weighted,f05_micro,f05_macro,f05_weighted = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    
    fauxPositifs, vraisPositifs, precisions, sensibilites, aucROCt, pr_auc, tauxROC, tauxPR = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()        
    
    
    lw = 1
    # couleurs    = sns.hls_palette(len(classifieursDict.keys()), l=.4, s=.9)
    nbClasses   = len(dictLabels.keys())
    listClasses = list(dictLabels.keys())
    
    y_testA  = label_binarize(y_test, classes=listClasses)
    plt.figure(figsize=(18,18))
    
    
    t1 = time.time()  
    classifier = model
    
    # y_score     = model.predict_proba(X_test)
    # y_pred      = model.predict(X_test)
    y_score     = model.predict(X_test)
    y_pred      = np.argmax(y_score, axis=-1) 
    y_predA     = label_binarize(y_pred, classes=listClasses)
    
    accuracy['global']              = accuracy_score(y_test, y_pred)
    balanced_accuracy['global']     = balanced_accuracy_score(y_test, y_pred)
    precision['global']             = precision_score(y_test, y_pred, average='weighted')
    sensibilite['global']           = recall_score(y_test, y_pred, average='weighted')
    
    f1['global']                    = f1_score(y_test, y_pred, average='weighted')
    f2['global']                    = fbeta_score(y_test, y_pred, beta=2, average='weighted')
    f05['global']                   = fbeta_score(y_test, y_pred, beta=0.5, average='weighted')
    
    vrais_negatifs['global']        = 0
    faux_positifs ['global']        = 0
    faux_negatifs ['global']        = 0
    vrais_positifs['global']        = 0
    total_positifs['global']        = 0
    
    
    aucROC['global'] = roc_auc_score(y_test, y_score, multi_class='ovr')
    
    for i in range(nbClasses):
        fauxPositifs[i], vraisPositifs[i], tauxROC[i] = roc_curve(y_testA[:, i], y_score[:, i])
        aucROCt[i]                                    = auc(fauxPositifs[i], vraisPositifs[i])
        precisions[i], sensibilites[i], tauxPR[i]     = precision_recall_curve(y_testA[:, i], y_score[:, i])
    
        aucROC[label_dict[i]]                = aucROCt[i]
        avgPrecRec[label_dict[i]]            = average_precision_score(y_testA[:, i], y_score[:, i])
        accuracy[label_dict[i]]              = accuracy_score(y_testA[:, i], y_predA[:, i])
        balanced_accuracy[label_dict[i]]     = balanced_accuracy_score(y_testA[:, i],y_predA[:, i])
        logloss[label_dict[i]]               = log_loss(y_testA[:, i], y_predA[:, i])
        hammingloss[label_dict[i]]           = hamming_loss(y_testA[:, i], y_predA[:, i])
        precision[label_dict[i]]             = precision_score(y_testA[:, i], y_predA[:, i])
        sensibilite[label_dict[i]]           = recall_score(y_testA[:, i], y_predA[:, i])
        f1[label_dict[i]]                    = f1_score(y_testA[:, i], y_predA[:, i])
        f2[label_dict[i]]                    = fbeta_score(y_testA[:, i], y_predA[:, i], beta=2)
        f05[label_dict[i]]                   = fbeta_score(y_testA[:, i], y_predA[:, i], beta=0.5)
      
        jaccard[label_dict[i]]               = jaccard_score(y_testA[:, i], y_predA[:, i])
        vrais_negatifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 0]
        faux_positifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 1]
        faux_negatifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 0]
        vrais_positifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 1]
        total_positifs[label_dict[i]]        = vrais_positifs[label_dict[i]] + faux_negatifs [label_dict[i]]
        vrais_negatifs['global']              += vrais_negatifs[label_dict[i]]
        faux_positifs ['global']              += faux_positifs [label_dict[i]]
        faux_negatifs ['global']              += faux_negatifs [label_dict[i]]
        vrais_positifs['global']              += vrais_positifs[label_dict[i]]
    
    
    total_positifs['global'] = vrais_positifs['global'] + faux_negatifs ['global']
    
    
    fauxPositifs["micro"], vraisPositifs["micro"], _ = roc_curve(y_testA.ravel(), y_score.ravel())
    aucROCt["micro"]                                 = auc(fauxPositifs["micro"], vraisPositifs["micro"])
    
    listFauxPositifs = np.unique(np.concatenate([fauxPositifs[i] for i in range(nbClasses)]))
    moyenneVraisPositifs = np.zeros_like(listFauxPositifs)
    for i in range(nbClasses):
        moyenneVraisPositifs += np.interp(listFauxPositifs, fauxPositifs[i], vraisPositifs[i])
    
    moyenneVraisPositifs /= nbClasses
    
    fauxPositifs["macro"], vraisPositifs["macro"] = listFauxPositifs, moyenneVraisPositifs
    aucROCt["macro"] = auc(fauxPositifs["macro"], vraisPositifs["macro"])
    # aucROC['global'] = aucROCt["macro"]  # (aucROCt["micro"],aucROCt["macro"])
    
    avgPrecRec['global'] = average_precision_score(y_testA.ravel(), y_score.ravel(), average='weighted')
    
    afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict);
    
    print ("Area under the ROC curve : %0.4f" % aucROC['global'],end='\t--\t')
    print('Exécution  :'+('%.2fs' % (time.time() - t1)).lstrip('0'))
        
    resultats = pd.DataFrame(pd.Series(aucROC), columns=["aucROC"])
    resultats["avgPrecRec"]              = pd.Series(avgPrecRec)
    resultats["f1"]                      = pd.Series(f1)
    resultats["f2"]                      = pd.Series(f2)
    resultats["f05"]                     = pd.Series(f05)
    resultats["accuracy"]                = pd.Series(accuracy)
    
    resultats["precision"]               = pd.Series(precision)
    resultats["sensibilite"]             = pd.Series(sensibilite)
    resultats["vrais_positifs"]          = pd.Series(vrais_positifs)
    resultats["vrais_negatifs"]          = pd.Series(vrais_negatifs)
    resultats["faux_positifs"]           = pd.Series(faux_positifs)
    resultats["faux_negatifs"]           = pd.Series(faux_negatifs)
    resultats["total_positifs"]          = pd.Series(total_positifs)
    
    resultats.reset_index(inplace=True)
    resultats.rename(columns={"index": "Classe"}, inplace=True)
    resultats['essai'] = nom_essai
    return resultats

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Lecture des données</div></b>

# %%
dictLabels = {0:'airplane', 
              1:'automobile', 
              2:'bird', 
              3:'cat', 
              4:'deer', 
              5:'dog', 
              6:'frog', 
              7:'horse', 
              8:'ship', 
              9:'truck'}

# %%
random_seed = 42
np.random.seed(random_seed)

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
image_height = X_train.shape[1]
image_width = X_train.shape[2]
number_of_pixels = image_height * image_width * X_train.shape[3]

X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')

# scale data to range [0, 1]
X_train /= 255.0
X_test /= 255.0

# scale data to range [-0.5, 0.5]
X_train -= 0.5
X_test -= 0.5

# save the original y_train and y_test
original_y_train = y_train
original_y_test = y_test

# replace label data with one-hot encoded versions
number_of_classes = len(dictLabels.keys())
y_train = tf.keras.utils.to_categorical(y_train, num_classes=number_of_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=number_of_classes)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
epochs=1024
batch_size = 4096
initial_lrate = 1e-3
min_lrate = 1e-4

drop_lrate = 0.5
epochs_drop = epochs * 0.1

# %%
def make_model():
    model = Sequential()
    model.add(Dense(1024, 
                    activation='relu',
                    input_shape=[number_of_pixels]
                   )
             )
    for _ in range(15):    
        model.add(Dropout(0.3))
        model.add(BatchNormalization())
        model.add(Dense(1024, activation='relu'))
        
        
    model.add(Dropout(0.3))
    model.add(Dense(number_of_classes, 
                    activation='softmax'))
    
    return model

# make the model
model = make_model()

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Compilation du modèle </div></b>

# %%
model.compile(
        optimizer=tf.keras.optimizers.Adam(initial_lrate), 
        loss=tf.keras.losses.CategoricalCrossentropy(),
        metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy')],
    )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1024)           │     3,146,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,962,442 (72.34 MB)
#  Trainable params: 18,931,722 (72.22 MB)
#  Non-trainable params: 30,720 (120.00 KB)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>
#
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
# learning rate scheduler
def step_decay(epoch):
    lrate = (initial_lrate - min_lrate ) * drop_lrate**((1+epoch)/epochs_drop) + min_lrate
    return lrate
# learning schedule callback

learningRate = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
rng = [i for i in range(epochs)]
y = [step_decay(x) for x in rng]
plt.plot(rng, y)
print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.000994 à 0.000101

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels de sauvegarde automatique du modèle </div></b>

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde chaque étape </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic1-epoch-{epoch:04d}.keras')
checkpointTimer1  = tf.keras.callbacks.ModelCheckpoint(filename,save_freq='epoch')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde tous les 5 étapes </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic5-epoch-{epoch:04d}.keras')
checkpointTimer5 = tf.keras.callbacks.ModelCheckpoint(filename,save_freq=5)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_loss minim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVLoss-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')

checkpointLoss = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                    monitor = 'val_loss',
                                                    verbose = 1, 
                                                    save_best_only = True, 
                                                    mode = 'min')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_accuracy maxim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVAccuracy-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
checkpointAccuracy = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                           monitor = 'val_accuracy', 
                                                           verbose = 1, 
                                                           save_best_only = True, 
                                                           mode = 'max')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Arrêt de l'apprentissage</div></b>

# %%
arretPrecoce = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, verbose=1)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels utilisés</div></b>

# %%
callbacks = [
    learningRate,
    # checkpointTimer1,
    # checkpointTimer5,
    checkpointLoss,
    # checkpointAccuracy,
    arretPrecoce
]

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle -Batch Size 256</div></b>

# %%
model_history = model.fit( X_train.reshape((X_train.shape[0], number_of_pixels)), 
                           y_train, 
                           validation_data=(X_test.reshape((X_test.shape[0], number_of_pixels)), y_test),
                           callbacks=callbacks,
                           epochs=epochs, 
                           batch_size=batch_size, 
                           verbose=2)
# Out:
# Epoch 1/1024
# I0000 00:00:1751893695.989303 1227415 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 2.29547, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0001-val_loss-2.295-val_accuracy-0.103.keras
# 13/13 - 14s - 1s/step - accuracy: 0.1062 - loss: 2.7028 - val_accuracy: 0.1026 - val_loss: 2.2955 - learning_rate: 9.9393e-04
# Epoch 2/1024
#
# Epoch 2: val_loss did not improve from 2.29547
# 13/13 - 0s - 22ms/step - accuracy: 0.1084 - loss: 2.5299 - val_accuracy: 0.1315 - val_loss: 4.2015 - learning_rate: 9.8790e-04
# Epoch 3/1024
#
# Epoch 3: val_loss did not improve from 2.29547
# 13/13 - 0s - 23ms/step - accuracy: 0.1365 - loss: 2.3914 - val_accuracy: 0.1022 - val_loss: 12.3296 - learning_rate: 9.8191e-04
# Epoch 4/1024
#
# Epoch 4: val_loss did not improve from 2.29547
# 13/13 - 0s - 22ms/step - accuracy: 0.1660 - loss: 2.2383 - val_accuracy: 0.1101 - val_loss: 10.4379 - learning_rate: 9.7596e-04
# Epoch 5/1024
#
# Epoch 5: val_loss did not improve from 2.29547
# 13/13 - 0s - 22ms/step - accuracy: 0.1915 - loss: 2.1409 - val_accuracy: 0.1651 - val_loss: 6.4438 - learning_rate: 9.7005e-04
# Epoch 6/1024
#
# Epoch 6: val_loss did not improve from 2.29547
# 13/13 - 0s - 21ms/step - accuracy: 0.2138 - loss: 2.0734 - val_accuracy: 0.1933 - val_loss: 4.1912 - learning_rate: 9.6418e-04
# Epoch 7/1024
#
# Epoch 7: val_loss did not improve from 2.29547
# 13/13 - 0s - 23ms/step - accuracy: 0.2319 - loss: 2.0212 - val_accuracy: 0.2209 - val_loss: 3.1951 - learning_rate: 9.5835e-04
# Epoch 8/1024
#
# Epoch 8: val_loss did not improve from 2.29547
# 13/13 - 0s - 22ms/step - accuracy: 0.2512 - loss: 1.9792 - val_accuracy: 0.2475 - val_loss: 2.3732 - learning_rate: 9.5256e-04
# Epoch 9/1024
#
# Epoch 9: val_loss did not improve from 2.29547
# 13/13 - 0s - 21ms/step - accuracy: 0.2682 - loss: 1.9397 - val_accuracy: 0.2608 - val_loss: 2.3360 - learning_rate: 9.4681e-04
# Epoch 10/1024
#
# Epoch 10: val_loss improved from 2.29547 to 2.23758, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0010-val_loss-2.238-val_accuracy-0.281.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.2806 - loss: 1.9065 - val_accuracy: 0.2806 - val_loss: 2.2376 - learning_rate: 9.4110e-04
# Epoch 11/1024
#
# Epoch 11: val_loss improved from 2.23758 to 2.17810, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0011-val_loss-2.178-val_accuracy-0.296.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.2974 - loss: 1.8711 - val_accuracy: 0.2959 - val_loss: 2.1781 - learning_rate: 9.3542e-04
# Epoch 12/1024
#
# Epoch 12: val_loss improved from 2.17810 to 2.17357, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0012-val_loss-2.174-val_accuracy-0.313.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.3120 - loss: 1.8381 - val_accuracy: 0.3131 - val_loss: 2.1736 - learning_rate: 9.2978e-04
# Epoch 13/1024
#
# Epoch 13: val_loss did not improve from 2.17357
# 13/13 - 0s - 22ms/step - accuracy: 0.3337 - loss: 1.8024 - val_accuracy: 0.3300 - val_loss: 2.2076 - learning_rate: 9.2419e-04
# Epoch 14/1024
#
# Epoch 14: val_loss improved from 2.17357 to 2.05443, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0014-val_loss-2.054-val_accuracy-0.342.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.3490 - loss: 1.7689 - val_accuracy: 0.3418 - val_loss: 2.0544 - learning_rate: 9.1863e-04
# Epoch 15/1024
#
# Epoch 15: val_loss did not improve from 2.05443
# 13/13 - 0s - 22ms/step - accuracy: 0.3580 - loss: 1.7346 - val_accuracy: 0.3518 - val_loss: 2.0983 - learning_rate: 9.1310e-04
# Epoch 16/1024
#
# Epoch 16: val_loss improved from 2.05443 to 2.04716, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0016-val_loss-2.047-val_accuracy-0.383.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.3738 - loss: 1.7014 - val_accuracy: 0.3826 - val_loss: 2.0472 - learning_rate: 9.0762e-04
# Epoch 17/1024
#
# Epoch 17: val_loss improved from 2.04716 to 1.95236, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0017-val_loss-1.952-val_accuracy-0.405.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.3899 - loss: 1.6668 - val_accuracy: 0.4047 - val_loss: 1.9524 - learning_rate: 9.0217e-04
# Epoch 18/1024
#
# Epoch 18: val_loss improved from 1.95236 to 1.94725, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0018-val_loss-1.947-val_accuracy-0.420.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.4010 - loss: 1.6401 - val_accuracy: 0.4201 - val_loss: 1.9472 - learning_rate: 8.9676e-04
# Epoch 19/1024
#
# Epoch 19: val_loss did not improve from 1.94725
# 13/13 - 0s - 23ms/step - accuracy: 0.4169 - loss: 1.6106 - val_accuracy: 0.4193 - val_loss: 2.0136 - learning_rate: 8.9138e-04
# Epoch 20/1024
#
# Epoch 20: val_loss did not improve from 1.94725
# 13/13 - 0s - 21ms/step - accuracy: 0.4228 - loss: 1.5811 - val_accuracy: 0.4296 - val_loss: 1.9692 - learning_rate: 8.8605e-04
# Epoch 21/1024
#
# Epoch 21: val_loss improved from 1.94725 to 1.93541, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0021-val_loss-1.935-val_accuracy-0.441.keras
# 13/13 - 1s - 46ms/step - accuracy: 0.4331 - loss: 1.5611 - val_accuracy: 0.4408 - val_loss: 1.9354 - learning_rate: 8.8074e-04
# Epoch 22/1024
#
# Epoch 22: val_loss improved from 1.93541 to 1.87996, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0022-val_loss-1.880-val_accuracy-0.443.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.4435 - loss: 1.5395 - val_accuracy: 0.4432 - val_loss: 1.8800 - learning_rate: 8.7548e-04
# Epoch 23/1024
#
# Epoch 23: val_loss did not improve from 1.87996
# 13/13 - 0s - 21ms/step - accuracy: 0.4542 - loss: 1.5138 - val_accuracy: 0.4479 - val_loss: 1.8987 - learning_rate: 8.7024e-04
# Epoch 24/1024
#
# Epoch 24: val_loss did not improve from 1.87996
# 13/13 - 0s - 21ms/step - accuracy: 0.4607 - loss: 1.4944 - val_accuracy: 0.4434 - val_loss: 1.9162 - learning_rate: 8.6505e-04
# Epoch 25/1024
#
# Epoch 25: val_loss did not improve from 1.87996
# 13/13 - 0s - 23ms/step - accuracy: 0.4730 - loss: 1.4640 - val_accuracy: 0.4544 - val_loss: 1.9454 - learning_rate: 8.5989e-04
# Epoch 26/1024
#
# Epoch 26: val_loss improved from 1.87996 to 1.80219, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0026-val_loss-1.802-val_accuracy-0.472.keras
# 13/13 - 1s - 46ms/step - accuracy: 0.4787 - loss: 1.4479 - val_accuracy: 0.4725 - val_loss: 1.8022 - learning_rate: 8.5476e-04
# Epoch 27/1024
#
# Epoch 27: val_loss improved from 1.80219 to 1.80057, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0027-val_loss-1.801-val_accuracy-0.478.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.4845 - loss: 1.4348 - val_accuracy: 0.4780 - val_loss: 1.8006 - learning_rate: 8.4967e-04
# Epoch 28/1024
#
# Epoch 28: val_loss improved from 1.80057 to 1.80039, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0028-val_loss-1.800-val_accuracy-0.476.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.4917 - loss: 1.4166 - val_accuracy: 0.4760 - val_loss: 1.8004 - learning_rate: 8.4461e-04
# Epoch 29/1024
#
# Epoch 29: val_loss improved from 1.80039 to 1.70013, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0029-val_loss-1.700-val_accuracy-0.487.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.4985 - loss: 1.3946 - val_accuracy: 0.4871 - val_loss: 1.7001 - learning_rate: 8.3959e-04
# Epoch 30/1024
#
# Epoch 30: val_loss improved from 1.70013 to 1.69229, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0030-val_loss-1.692-val_accuracy-0.493.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.5038 - loss: 1.3840 - val_accuracy: 0.4929 - val_loss: 1.6923 - learning_rate: 8.3460e-04
# Epoch 31/1024
#
# Epoch 31: val_loss improved from 1.69229 to 1.62659, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0031-val_loss-1.627-val_accuracy-0.508.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.5102 - loss: 1.3683 - val_accuracy: 0.5077 - val_loss: 1.6266 - learning_rate: 8.2964e-04
# Epoch 32/1024
#
# Epoch 32: val_loss did not improve from 1.62659
# 13/13 - 0s - 23ms/step - accuracy: 0.5181 - loss: 1.3501 - val_accuracy: 0.4936 - val_loss: 1.6513 - learning_rate: 8.2472e-04
# Epoch 33/1024
#
# Epoch 33: val_loss did not improve from 1.62659
# 13/13 - 0s - 21ms/step - accuracy: 0.5247 - loss: 1.3324 - val_accuracy: 0.5091 - val_loss: 1.6349 - learning_rate: 8.1983e-04
# Epoch 34/1024
#
# Epoch 34: val_loss improved from 1.62659 to 1.61071, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0034-val_loss-1.611-val_accuracy-0.512.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.5332 - loss: 1.3107 - val_accuracy: 0.5122 - val_loss: 1.6107 - learning_rate: 8.1498e-04
# Epoch 35/1024
#
# Epoch 35: val_loss did not improve from 1.61071
# 13/13 - 0s - 20ms/step - accuracy: 0.5410 - loss: 1.2898 - val_accuracy: 0.5152 - val_loss: 1.6305 - learning_rate: 8.1015e-04
# Epoch 36/1024
#
# Epoch 36: val_loss improved from 1.61071 to 1.61042, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0036-val_loss-1.610-val_accuracy-0.522.keras
# 13/13 - 1s - 46ms/step - accuracy: 0.5482 - loss: 1.2768 - val_accuracy: 0.5220 - val_loss: 1.6104 - learning_rate: 8.0536e-04
# Epoch 37/1024
#
# Epoch 37: val_loss improved from 1.61042 to 1.60977, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0037-val_loss-1.610-val_accuracy-0.523.keras
# 13/13 - 1s - 45ms/step - accuracy: 0.5515 - loss: 1.2539 - val_accuracy: 0.5229 - val_loss: 1.6098 - learning_rate: 8.0060e-04
# Epoch 38/1024
#
# Epoch 38: val_loss did not improve from 1.60977
# 13/13 - 0s - 23ms/step - accuracy: 0.5539 - loss: 1.2517 - val_accuracy: 0.5136 - val_loss: 1.6149 - learning_rate: 7.9588e-04
# Epoch 39/1024
#
# Epoch 39: val_loss improved from 1.60977 to 1.60671, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0039-val_loss-1.607-val_accuracy-0.518.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.5591 - loss: 1.2403 - val_accuracy: 0.5183 - val_loss: 1.6067 - learning_rate: 7.9118e-04
# Epoch 40/1024
#
# Epoch 40: val_loss improved from 1.60671 to 1.60179, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0040-val_loss-1.602-val_accuracy-0.529.keras
# 13/13 - 1s - 42ms/step - accuracy: 0.5656 - loss: 1.2213 - val_accuracy: 0.5286 - val_loss: 1.6018 - learning_rate: 7.8652e-04
# Epoch 41/1024
#
# Epoch 41: val_loss improved from 1.60179 to 1.59863, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0041-val_loss-1.599-val_accuracy-0.529.keras
# 13/13 - 1s - 45ms/step - accuracy: 0.5714 - loss: 1.2097 - val_accuracy: 0.5287 - val_loss: 1.5986 - learning_rate: 7.8189e-04
# Epoch 42/1024
#
# Epoch 42: val_loss improved from 1.59863 to 1.57625, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0042-val_loss-1.576-val_accuracy-0.527.keras
# 13/13 - 1s - 45ms/step - accuracy: 0.5780 - loss: 1.1903 - val_accuracy: 0.5275 - val_loss: 1.5763 - learning_rate: 7.7729e-04
# Epoch 43/1024
#
# Epoch 43: val_loss improved from 1.57625 to 1.51803, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0043-val_loss-1.518-val_accuracy-0.535.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.5818 - loss: 1.1786 - val_accuracy: 0.5348 - val_loss: 1.5180 - learning_rate: 7.7272e-04
# Epoch 44/1024
#
# Epoch 44: val_loss did not improve from 1.51803
# 13/13 - 0s - 22ms/step - accuracy: 0.5911 - loss: 1.1612 - val_accuracy: 0.5349 - val_loss: 1.5525 - learning_rate: 7.6818e-04
# Epoch 45/1024
#
# Epoch 45: val_loss did not improve from 1.51803
# 13/13 - 0s - 23ms/step - accuracy: 0.5910 - loss: 1.1539 - val_accuracy: 0.5254 - val_loss: 1.5681 - learning_rate: 7.6367e-04
# Epoch 46/1024
#
# Epoch 46: val_loss improved from 1.51803 to 1.51710, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0046-val_loss-1.517-val_accuracy-0.540.keras
# 13/13 - 1s - 45ms/step - accuracy: 0.5971 - loss: 1.1382 - val_accuracy: 0.5400 - val_loss: 1.5171 - learning_rate: 7.5920e-04
# Epoch 47/1024
#
# Epoch 47: val_loss did not improve from 1.51710
# 13/13 - 0s - 22ms/step - accuracy: 0.6044 - loss: 1.1184 - val_accuracy: 0.5401 - val_loss: 1.5269 - learning_rate: 7.5475e-04
# Epoch 48/1024
#
# Epoch 48: val_loss improved from 1.51710 to 1.51673, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0048-val_loss-1.517-val_accuracy-0.545.keras
# 13/13 - 1s - 44ms/step - accuracy: 0.6084 - loss: 1.1042 - val_accuracy: 0.5453 - val_loss: 1.5167 - learning_rate: 7.5033e-04
# Epoch 49/1024
#
# Epoch 49: val_loss did not improve from 1.51673
# 13/13 - 0s - 21ms/step - accuracy: 0.6127 - loss: 1.0943 - val_accuracy: 0.5371 - val_loss: 1.5605 - learning_rate: 7.4594e-04
# Epoch 50/1024
#
# Epoch 50: val_loss improved from 1.51673 to 1.47132, saving model to /home/razvan/documentation/DeepLearning/PerceptronMulticouche/05-L'apprentissage et rappels d’exécution--modèle multicouches--CIFAR10-Categorical/repertoire.sauvegardes/modelVLoss-epoch-0050-val_loss-1.471-val_accuracy-0.547.keras
# 13/13 - 1s - 43ms/step - accuracy: 0.6137 - loss: 1.0899 - val_accuracy: 0.5472 - val_loss: 1.4713 - learning_rate: 7.4159e-04
# Epoch 51/1024
#
# Epoch 51: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6234 - loss: 1.0701 - val_accuracy: 0.5510 - val_loss: 1.4988 - learning_rate: 7.3726e-04
# Epoch 52/1024
#
# Epoch 52: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.6260 - loss: 1.0606 - val_accuracy: 0.5452 - val_loss: 1.5171 - learning_rate: 7.3296e-04
# Epoch 53/1024
#
# Epoch 53: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6319 - loss: 1.0440 - val_accuracy: 0.5477 - val_loss: 1.5450 - learning_rate: 7.2869e-04
# Epoch 54/1024
#
# Epoch 54: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.6369 - loss: 1.0390 - val_accuracy: 0.5538 - val_loss: 1.5117 - learning_rate: 7.2445e-04
# Epoch 55/1024
#
# Epoch 55: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6412 - loss: 1.0221 - val_accuracy: 0.5468 - val_loss: 1.5149 - learning_rate: 7.2024e-04
# Epoch 56/1024
#
# Epoch 56: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6460 - loss: 1.0040 - val_accuracy: 0.5443 - val_loss: 1.5154 - learning_rate: 7.1605e-04
# Epoch 57/1024
#
# Epoch 57: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6484 - loss: 0.9956 - val_accuracy: 0.5439 - val_loss: 1.5148 - learning_rate: 7.1190e-04
# Epoch 58/1024
#
# Epoch 58: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6537 - loss: 0.9868 - val_accuracy: 0.5570 - val_loss: 1.5178 - learning_rate: 7.0777e-04
# Epoch 59/1024
#
# Epoch 59: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6539 - loss: 0.9811 - val_accuracy: 0.5545 - val_loss: 1.5303 - learning_rate: 7.0367e-04
# Epoch 60/1024
#
# Epoch 60: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6573 - loss: 0.9774 - val_accuracy: 0.5568 - val_loss: 1.5252 - learning_rate: 6.9959e-04
# Epoch 61/1024
#
# Epoch 61: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6638 - loss: 0.9593 - val_accuracy: 0.5623 - val_loss: 1.5091 - learning_rate: 6.9555e-04
# Epoch 62/1024
#
# Epoch 62: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6701 - loss: 0.9410 - val_accuracy: 0.5436 - val_loss: 1.5656 - learning_rate: 6.9153e-04
# Epoch 63/1024
#
# Epoch 63: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6761 - loss: 0.9260 - val_accuracy: 0.5578 - val_loss: 1.5287 - learning_rate: 6.8754e-04
# Epoch 64/1024
#
# Epoch 64: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.6811 - loss: 0.9093 - val_accuracy: 0.5602 - val_loss: 1.5082 - learning_rate: 6.8358e-04
# Epoch 65/1024
#
# Epoch 65: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.6859 - loss: 0.9003 - val_accuracy: 0.5612 - val_loss: 1.5185 - learning_rate: 6.7964e-04
# Epoch 66/1024
#
# Epoch 66: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6854 - loss: 0.8967 - val_accuracy: 0.5645 - val_loss: 1.5176 - learning_rate: 6.7573e-04
# Epoch 67/1024
#
# Epoch 67: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.6925 - loss: 0.8865 - val_accuracy: 0.5624 - val_loss: 1.5096 - learning_rate: 6.7185e-04
# Epoch 68/1024
#
# Epoch 68: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6934 - loss: 0.8745 - val_accuracy: 0.5669 - val_loss: 1.5693 - learning_rate: 6.6799e-04
# Epoch 69/1024
#
# Epoch 69: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.6959 - loss: 0.8671 - val_accuracy: 0.5521 - val_loss: 1.5679 - learning_rate: 6.6416e-04
# Epoch 70/1024
#
# Epoch 70: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7024 - loss: 0.8538 - val_accuracy: 0.5556 - val_loss: 1.6083 - learning_rate: 6.6035e-04
# Epoch 71/1024
#
# Epoch 71: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7002 - loss: 0.8610 - val_accuracy: 0.5647 - val_loss: 1.5423 - learning_rate: 6.5657e-04
# Epoch 72/1024
#
# Epoch 72: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.7051 - loss: 0.8427 - val_accuracy: 0.5607 - val_loss: 1.5487 - learning_rate: 6.5282e-04
# Epoch 73/1024
#
# Epoch 73: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7091 - loss: 0.8315 - val_accuracy: 0.5682 - val_loss: 1.5788 - learning_rate: 6.4909e-04
# Epoch 74/1024
#
# Epoch 74: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7140 - loss: 0.8195 - val_accuracy: 0.5705 - val_loss: 1.5889 - learning_rate: 6.4538e-04
# Epoch 75/1024
#
# Epoch 75: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7204 - loss: 0.8059 - val_accuracy: 0.5718 - val_loss: 1.5697 - learning_rate: 6.4170e-04
# Epoch 76/1024
#
# Epoch 76: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7190 - loss: 0.8017 - val_accuracy: 0.5697 - val_loss: 1.5541 - learning_rate: 6.3805e-04
# Epoch 77/1024
#
# Epoch 77: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7268 - loss: 0.7818 - val_accuracy: 0.5729 - val_loss: 1.5579 - learning_rate: 6.3442e-04
# Epoch 78/1024
#
# Epoch 78: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.7336 - loss: 0.7650 - val_accuracy: 0.5657 - val_loss: 1.6096 - learning_rate: 6.3081e-04
# Epoch 79/1024
#
# Epoch 79: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7353 - loss: 0.7628 - val_accuracy: 0.5686 - val_loss: 1.5771 - learning_rate: 6.2723e-04
# Epoch 80/1024
#
# Epoch 80: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7408 - loss: 0.7501 - val_accuracy: 0.5666 - val_loss: 1.5863 - learning_rate: 6.2368e-04
# Epoch 81/1024
#
# Epoch 81: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7387 - loss: 0.7504 - val_accuracy: 0.5712 - val_loss: 1.6149 - learning_rate: 6.2014e-04
# Epoch 82/1024
#
# Epoch 82: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7439 - loss: 0.7398 - val_accuracy: 0.5681 - val_loss: 1.6071 - learning_rate: 6.1663e-04
# Epoch 83/1024
#
# Epoch 83: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7458 - loss: 0.7306 - val_accuracy: 0.5726 - val_loss: 1.5793 - learning_rate: 6.1315e-04
# Epoch 84/1024
#
# Epoch 84: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7522 - loss: 0.7214 - val_accuracy: 0.5697 - val_loss: 1.6154 - learning_rate: 6.0969e-04
# Epoch 85/1024
#
# Epoch 85: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7533 - loss: 0.7109 - val_accuracy: 0.5748 - val_loss: 1.5791 - learning_rate: 6.0625e-04
# Epoch 86/1024
#
# Epoch 86: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7552 - loss: 0.7083 - val_accuracy: 0.5698 - val_loss: 1.6203 - learning_rate: 6.0283e-04
# Epoch 87/1024
#
# Epoch 87: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.7612 - loss: 0.6929 - val_accuracy: 0.5786 - val_loss: 1.6123 - learning_rate: 5.9944e-04
# Epoch 88/1024
#
# Epoch 88: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7620 - loss: 0.6865 - val_accuracy: 0.5678 - val_loss: 1.6167 - learning_rate: 5.9607e-04
# Epoch 89/1024
#
# Epoch 89: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7613 - loss: 0.6873 - val_accuracy: 0.5793 - val_loss: 1.5928 - learning_rate: 5.9273e-04
# Epoch 90/1024
#
# Epoch 90: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7685 - loss: 0.6637 - val_accuracy: 0.5739 - val_loss: 1.6863 - learning_rate: 5.8940e-04
# Epoch 91/1024
#
# Epoch 91: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7693 - loss: 0.6654 - val_accuracy: 0.5756 - val_loss: 1.6892 - learning_rate: 5.8610e-04
# Epoch 92/1024
#
# Epoch 92: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7702 - loss: 0.6616 - val_accuracy: 0.5716 - val_loss: 1.6437 - learning_rate: 5.8282e-04
# Epoch 93/1024
#
# Epoch 93: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7774 - loss: 0.6464 - val_accuracy: 0.5752 - val_loss: 1.6459 - learning_rate: 5.7956e-04
# Epoch 94/1024
#
# Epoch 94: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7765 - loss: 0.6431 - val_accuracy: 0.5729 - val_loss: 1.6683 - learning_rate: 5.7633e-04
# Epoch 95/1024
#
# Epoch 95: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.7789 - loss: 0.6454 - val_accuracy: 0.5751 - val_loss: 1.6570 - learning_rate: 5.7311e-04
# Epoch 96/1024
#
# Epoch 96: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7859 - loss: 0.6191 - val_accuracy: 0.5772 - val_loss: 1.6908 - learning_rate: 5.6992e-04
# Epoch 97/1024
#
# Epoch 97: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7861 - loss: 0.6215 - val_accuracy: 0.5755 - val_loss: 1.6646 - learning_rate: 5.6675e-04
# Epoch 98/1024
#
# Epoch 98: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7907 - loss: 0.6086 - val_accuracy: 0.5809 - val_loss: 1.6854 - learning_rate: 5.6360e-04
# Epoch 99/1024
#
# Epoch 99: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7936 - loss: 0.6016 - val_accuracy: 0.5775 - val_loss: 1.6655 - learning_rate: 5.6048e-04
# Epoch 100/1024
#
# Epoch 100: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.7969 - loss: 0.5939 - val_accuracy: 0.5751 - val_loss: 1.6846 - learning_rate: 5.5737e-04
# Epoch 101/1024
#
# Epoch 101: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.7970 - loss: 0.5907 - val_accuracy: 0.5763 - val_loss: 1.6975 - learning_rate: 5.5428e-04
# Epoch 102/1024
#
# Epoch 102: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8004 - loss: 0.5800 - val_accuracy: 0.5807 - val_loss: 1.7198 - learning_rate: 5.5122e-04
# Epoch 103/1024
#
# Epoch 103: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8019 - loss: 0.5734 - val_accuracy: 0.5831 - val_loss: 1.6693 - learning_rate: 5.4818e-04
# Epoch 104/1024
#
# Epoch 104: val_loss did not improve from 1.47132
# 13/13 - 0s - 23ms/step - accuracy: 0.8072 - loss: 0.5591 - val_accuracy: 0.5754 - val_loss: 1.7180 - learning_rate: 5.4515e-04
# Epoch 105/1024
#
# Epoch 105: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8117 - loss: 0.5472 - val_accuracy: 0.5738 - val_loss: 1.7211 - learning_rate: 5.4215e-04
# Epoch 106/1024
#
# Epoch 106: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8117 - loss: 0.5503 - val_accuracy: 0.5772 - val_loss: 1.7386 - learning_rate: 5.3917e-04
# Epoch 107/1024
#
# Epoch 107: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8118 - loss: 0.5466 - val_accuracy: 0.5768 - val_loss: 1.7556 - learning_rate: 5.3620e-04
# Epoch 108/1024
#
# Epoch 108: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8154 - loss: 0.5405 - val_accuracy: 0.5778 - val_loss: 1.7551 - learning_rate: 5.3326e-04
# Epoch 109/1024
#
# Epoch 109: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8192 - loss: 0.5280 - val_accuracy: 0.5709 - val_loss: 1.7731 - learning_rate: 5.3034e-04
# Epoch 110/1024
#
# Epoch 110: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8219 - loss: 0.5215 - val_accuracy: 0.5765 - val_loss: 1.7296 - learning_rate: 5.2744e-04
# Epoch 111/1024
#
# Epoch 111: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8240 - loss: 0.5121 - val_accuracy: 0.5814 - val_loss: 1.7719 - learning_rate: 5.2455e-04
# Epoch 112/1024
#
# Epoch 112: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8243 - loss: 0.5132 - val_accuracy: 0.5750 - val_loss: 1.7408 - learning_rate: 5.2169e-04
# Epoch 113/1024
#
# Epoch 113: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8265 - loss: 0.5069 - val_accuracy: 0.5772 - val_loss: 1.7879 - learning_rate: 5.1884e-04
# Epoch 114/1024
#
# Epoch 114: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8296 - loss: 0.4964 - val_accuracy: 0.5843 - val_loss: 1.8072 - learning_rate: 5.1602e-04
# Epoch 115/1024
#
# Epoch 115: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8312 - loss: 0.4944 - val_accuracy: 0.5823 - val_loss: 1.7702 - learning_rate: 5.1321e-04
# Epoch 116/1024
#
# Epoch 116: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8364 - loss: 0.4829 - val_accuracy: 0.5721 - val_loss: 1.8002 - learning_rate: 5.1042e-04
# Epoch 117/1024
#
# Epoch 117: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8358 - loss: 0.4867 - val_accuracy: 0.5758 - val_loss: 1.8254 - learning_rate: 5.0765e-04
# Epoch 118/1024
#
# Epoch 118: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8379 - loss: 0.4730 - val_accuracy: 0.5763 - val_loss: 1.8268 - learning_rate: 5.0490e-04
# Epoch 119/1024
#
# Epoch 119: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8405 - loss: 0.4694 - val_accuracy: 0.5786 - val_loss: 1.8338 - learning_rate: 5.0217e-04
# Epoch 120/1024
#
# Epoch 120: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8377 - loss: 0.4728 - val_accuracy: 0.5773 - val_loss: 1.7910 - learning_rate: 4.9946e-04
# Epoch 121/1024
#
# Epoch 121: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8409 - loss: 0.4684 - val_accuracy: 0.5801 - val_loss: 1.7900 - learning_rate: 4.9676e-04
# Epoch 122/1024
#
# Epoch 122: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8430 - loss: 0.4639 - val_accuracy: 0.5805 - val_loss: 1.8312 - learning_rate: 4.9409e-04
# Epoch 123/1024
#
# Epoch 123: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8471 - loss: 0.4525 - val_accuracy: 0.5861 - val_loss: 1.8042 - learning_rate: 4.9143e-04
# Epoch 124/1024
#
# Epoch 124: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8487 - loss: 0.4438 - val_accuracy: 0.5785 - val_loss: 1.8679 - learning_rate: 4.8879e-04
# Epoch 125/1024
#
# Epoch 125: val_loss did not improve from 1.47132
# 13/13 - 0s - 20ms/step - accuracy: 0.8515 - loss: 0.4364 - val_accuracy: 0.5750 - val_loss: 1.8339 - learning_rate: 4.8617e-04
# Epoch 126/1024
#
# Epoch 126: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8509 - loss: 0.4417 - val_accuracy: 0.5806 - val_loss: 1.8465 - learning_rate: 4.8356e-04
# Epoch 127/1024
#
# Epoch 127: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8550 - loss: 0.4291 - val_accuracy: 0.5817 - val_loss: 1.8523 - learning_rate: 4.8097e-04
# Epoch 128/1024
#
# Epoch 128: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8573 - loss: 0.4182 - val_accuracy: 0.5848 - val_loss: 1.8428 - learning_rate: 4.7840e-04
# Epoch 129/1024
#
# Epoch 129: val_loss did not improve from 1.47132
# 13/13 - 0s - 20ms/step - accuracy: 0.8621 - loss: 0.4095 - val_accuracy: 0.5849 - val_loss: 1.8429 - learning_rate: 4.7585e-04
# Epoch 130/1024
#
# Epoch 130: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8644 - loss: 0.4027 - val_accuracy: 0.5807 - val_loss: 1.9113 - learning_rate: 4.7332e-04
# Epoch 131/1024
#
# Epoch 131: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8641 - loss: 0.4037 - val_accuracy: 0.5794 - val_loss: 1.9165 - learning_rate: 4.7080e-04
# Epoch 132/1024
#
# Epoch 132: val_loss did not improve from 1.47132
# 13/13 - 0s - 20ms/step - accuracy: 0.8642 - loss: 0.4029 - val_accuracy: 0.5836 - val_loss: 1.8937 - learning_rate: 4.6830e-04
# Epoch 133/1024
#
# Epoch 133: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8641 - loss: 0.4016 - val_accuracy: 0.5814 - val_loss: 1.8718 - learning_rate: 4.6581e-04
# Epoch 134/1024
#
# Epoch 134: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8681 - loss: 0.3862 - val_accuracy: 0.5821 - val_loss: 1.8881 - learning_rate: 4.6334e-04
# Epoch 135/1024
#
# Epoch 135: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8695 - loss: 0.3901 - val_accuracy: 0.5812 - val_loss: 1.8507 - learning_rate: 4.6089e-04
# Epoch 136/1024
#
# Epoch 136: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8725 - loss: 0.3841 - val_accuracy: 0.5830 - val_loss: 1.9007 - learning_rate: 4.5846e-04
# Epoch 137/1024
#
# Epoch 137: val_loss did not improve from 1.47132
# 13/13 - 0s - 20ms/step - accuracy: 0.8705 - loss: 0.3846 - val_accuracy: 0.5840 - val_loss: 1.8972 - learning_rate: 4.5604e-04
# Epoch 138/1024
#
# Epoch 138: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8787 - loss: 0.3633 - val_accuracy: 0.5833 - val_loss: 1.8793 - learning_rate: 4.5364e-04
# Epoch 139/1024
#
# Epoch 139: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8773 - loss: 0.3661 - val_accuracy: 0.5797 - val_loss: 1.8944 - learning_rate: 4.5125e-04
# Epoch 140/1024
#
# Epoch 140: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8792 - loss: 0.3637 - val_accuracy: 0.5832 - val_loss: 1.9041 - learning_rate: 4.4888e-04
# Epoch 141/1024
#
# Epoch 141: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8781 - loss: 0.3620 - val_accuracy: 0.5851 - val_loss: 1.9025 - learning_rate: 4.4653e-04
# Epoch 142/1024
#
# Epoch 142: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8814 - loss: 0.3558 - val_accuracy: 0.5810 - val_loss: 1.9481 - learning_rate: 4.4419e-04
# Epoch 143/1024
#
# Epoch 143: val_loss did not improve from 1.47132
# 13/13 - 0s - 20ms/step - accuracy: 0.8823 - loss: 0.3562 - val_accuracy: 0.5862 - val_loss: 1.8962 - learning_rate: 4.4187e-04
# Epoch 144/1024
#
# Epoch 144: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8849 - loss: 0.3466 - val_accuracy: 0.5839 - val_loss: 1.9494 - learning_rate: 4.3956e-04
# Epoch 145/1024
#
# Epoch 145: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8857 - loss: 0.3445 - val_accuracy: 0.5817 - val_loss: 1.9571 - learning_rate: 4.3727e-04
# Epoch 146/1024
#
# Epoch 146: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8861 - loss: 0.3446 - val_accuracy: 0.5826 - val_loss: 1.9437 - learning_rate: 4.3500e-04
# Epoch 147/1024
#
# Epoch 147: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8884 - loss: 0.3319 - val_accuracy: 0.5836 - val_loss: 1.9256 - learning_rate: 4.3274e-04
# Epoch 148/1024
#
# Epoch 148: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8865 - loss: 0.3374 - val_accuracy: 0.5844 - val_loss: 1.9058 - learning_rate: 4.3049e-04
# Epoch 149/1024
#
# Epoch 149: val_loss did not improve from 1.47132
# 13/13 - 0s - 22ms/step - accuracy: 0.8886 - loss: 0.3337 - val_accuracy: 0.5796 - val_loss: 1.9388 - learning_rate: 4.2826e-04
# Epoch 150/1024
#
# Epoch 150: val_loss did not improve from 1.47132
# 13/13 - 0s - 21ms/step - accuracy: 0.8910 - loss: 0.3258 - val_accuracy: 0.5818 - val_loss: 1.9282 - learning_rate: 4.2605e-04
# Epoch 150: early stopping

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
history = sauvegardeHistorique(model_history,
                               repertoireSauvegardes,
                               nomSauvegarde='history_batch_size_256')

# %%
afficheHistoriqueEntrainement(history, palette)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_256.keras'))

# %%
sauvegarderModel(model, 'history_batch_size_256')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du modèle </div></b>

# %%
model = tf.keras.models.load_model(os.path.join(repertoireSauvegardes,
                                   'Keras-03-HistoriqueEntrainement.history_batch_size_256.keras'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1024)           │     3,146,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,825,888 (216.77 MB)
#  Trainable params: 18,931,722 (72.22 MB)
#  Non-trainable params: 30,720 (120.00 KB)
#  Optimizer params: 37,863,446 (144.44 MB)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
probabilities = model.predict(X_test.reshape((X_test.shape[0], number_of_pixels)), verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
def afficheProbabilites(probabilities, ind, ax):
    prediction = pd.DataFrame(probabilities).iloc[ind,:].reset_index()
    prediction.columns = ['Classe','Probabilite']
    
    graph = sns.barplot(
                        x='Classe',
                        y='Probabilite',
                        data=prediction.sort_values('Probabilite',ascending=False),
                        palette=palette[1:],
                        ax=ax        
                        );
    for patche in graph.patches:
        if patche.get_height() > 0 :
            graph.text(
                        patche.get_x()+0.4,
                        0.4, #2*patche.get_height()/3,
                        f'{patche.get_height()*100:0.4f}%',
                        color='black',
                        rotation='vertical',
                        # size='large',
                        fontsize='large',
                        bbox=dict(boxstyle='round', facecolor='white', alpha=0.6),
                        verticalalignment='center',
                        horizontalalignment='center',
                       )       

fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(48,16));
for i in range(4):
    afficheProbabilites(probabilities,ind=i,ax=ax[i])

sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [raw]
# plt.figure(figsize=(20,8))
# for i in range(4):
#     plt.subplot(1, 4, i+1)
#     plt.bar(range(number_of_classes), probabilities[i], color="#030aa7", align='center')
#     plt.xlim(-0.5, 9.5)
#     plt.ylim(0, 1)
#     plt.title(predictions[i],fontsize=30)
# plt.tight_layout()
# sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=np.argmax(y_test, axis=-1),predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=X_test.reshape((X_test.shape[0], number_of_pixels)),
                                                  y_test=np.argmax(y_test, axis=-1),
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Area under the ROC curve : 0.8996	--	Exécution  :9.96s
#         Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0       global  0.899625    0.627960  0.584011  0.582362  0.586570    0.5818
# 1     airplane  0.920678    0.688107  0.661249  0.655061  0.667555    0.9333
# 2   automobile  0.943119    0.745126  0.681889  0.666734  0.697749    0.9387
# 3         bird  0.839687    0.483748  0.487552  0.476867  0.498727    0.9012
# 4          cat  0.841919    0.358945  0.393123  0.410520  0.377140    0.8694
# 5         deer  0.873048    0.520453  0.515315  0.547893  0.486395    0.8924
# 6          dog  0.881832    0.500611  0.472309  0.459910  0.485395    0.8990
# 7         frog  0.919000    0.689037  0.630537  0.614962  0.646920    0.9291
# 8        horse  0.914121    0.708207  0.656576  0.639748  0.674314    0.9342
# 9         ship  0.938986    0.776507  0.710290  0.710716  0.709864    0.9420
# 10       truck  0.923862    0.679402  0.631271  0.641203  0.621642    0.9243
#
#     precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0    0.588757       0.5818            5818           85818           4182
# 1    0.671827       0.6510             651            8682            318
# 2    0.708738       0.6570             657            8730            270
# 3    0.506466       0.4700             470            8542            458
# 4    0.367188       0.4230             423            8271            729
# 5    0.468852       0.5720             572            8352            648
# 6    0.494530       0.4520             452            8538            462
# 7    0.658324       0.6050             605            8686            314
# 8    0.686681       0.6290             629            8713            287
# 9    0.709581       0.7110             711            8709            291
# 10   0.615385       0.6480             648            8595            405
#
#     faux_negatifs  total_positifs    essai
# 0            4182           10000  initial
# 1             349            1000  initial
# 2             343            1000  initial
# 3             530            1000  initial
# 4             577            1000  initial
# 5             428            1000  initial
# 6             548            1000  initial
# 7             395            1000  initial
# 8             371            1000  initial
# 9             289            1000  initial
# 10            352            1000  initial
