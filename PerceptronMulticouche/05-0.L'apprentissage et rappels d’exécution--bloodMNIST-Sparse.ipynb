# %% [markdown]
# <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'>BloodMNIST<br> Standardized Biomedical Images</div>
# <div style='text-align: center'>
#     <img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/bloodMNIST.png" width="512">
# </div>
#
# > https://www.larousse.fr/dictionnaires/francais/inf%C3%A9rence/42907<br><br>
#
# >> **inférence** : Opération par laquelle on passe d'une assertion considérée comme vraie à une autre assertion au moyen d'un système de règles qui rend cette deuxième assertion également vraie.<br>
#
# >> **Inférence statistique** : Ensemble des méthodes permettant de formuler en termes probabilistes un jugement sur une population à partir des résultats observés sur un échantillon extrait au hasard de cette population.<br>
#
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ['TF_XLA_FLAGS']='--tf_xla_auto_jit=1,--tf_xla_always_defer_compilation=true'
# os.environ['XLA_FLAGS']='--xla_backend_optimization_level=0,--xla_gpu_autotune_level=4,--xla_gpu_disable_ptxas_optimizations=true,--xla_gpu_use_cudnn_batchnorm_level=2'
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, pickle, time
from matplotlib import pyplot as plt
from datetime import datetime as dt

import matplotlib.font_manager as fm
from matplotlib.lines import Line2D

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist,fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Conv2D, MaxPooling2D


from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer, confusion_matrix, roc_curve, auc, accuracy_score, log_loss, hamming_loss, \
                            precision_score, recall_score, f1_score, fbeta_score, jaccard_score, \
                            precision_recall_curve, average_precision_score, balanced_accuracy_score, \
                            classification_report,roc_auc_score
tf.get_logger().setLevel('ERROR')# Suppress TensorFlow logging (2)

# %%
print("Tensorflow\t : %s\tCUDA %s\tGPU %s\tXLA %s\nKeras\t\t : %s\nPandas\t\t : %s\nNumPy\t\t : %s"%
      (tf.__version__, 
       tf.test.is_built_with_cuda(), 
       tf.test.is_built_with_gpu_support(), 
       tf.test.is_built_with_xla(), 
       tf.keras.__version__, 
       pd.__version__, 
       np.__version__))
# Out:
# Tensorflow	 : 2.17.0	CUDA True	GPU True	XLA True
# Keras		 : 3.6.0
# Pandas		 : 2.2.2
# NumPy		 : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des GPUs presents</div></b>

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) >  0 :
    for i, gpu in enumerate(physical_devices):
        tf.config.experimental.set_memory_growth(physical_devices[i], True)

    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('Le système est initialisé avec {0:d} GPUs'.format(strategy.num_replicas_in_sync))
# Out:
# Le système est initialisé avec 1 GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751707489.372985  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.394914  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.395025  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751707489.401785  117505 service.cc:146] XLA service 0x3a443380 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751707489.401804  117505 service.cc:154]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1751707489.455072  117660 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.455236  117505 service.cc:146] XLA service 0x377c6030 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751707489.455251  117505 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1751707489.455379  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.455485  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.455538  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.458963  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751707489.459046  117505 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
palette = [
            "#030aa7", "#e50000", "#d8863b", "#005f6a", "#6b7c85", "#751973", "#d1e5f0", "#fddbc7",
            "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#f5054f", "#a0450e",
            "#0339f8", "#f4320c", "#fec615", "#017a79", "#85a3b2", "#fe2f4a", "#a00498", "#b04e0f",
            "#0165fc", "#ff724c", "#fddc5c", "#11875d", "#89a0b0", "#fe828c", "#cb00f5", "#b75203",
            "#0485d1", "#ff7855", "#fbeeac", "#0cb577", "#95a3a6", "#ffb7ce", "#c071fe", "#ca6b02",
            "#92c5de", "#f4a582", "#fef69e", "#18d17b", "#c5c9c7", "#ffcfdc", "#caa0ff", "#cb7723",
            "#d1e5f0", "#fddbc7", "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#d8863b",
            "#030764", "#be0119", "#dbb40c", "#005249", "#3c4142", "#cb0162", "#5d1451", "#653700",
            "#040348", "#67001f", "#b27a01", "#002d04", "#000000", "#a0025c", "#490648", "#3c0008"
          ]

# %%
nom_projet                = "05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse"
repertoireProjet          = os.getcwd()
repertoireEnregistrement  = repertoireProjet +'/'+nom_projet+ '/repertoire.images'
repertoireSauvegardes     = repertoireProjet +'/'+nom_projet+ '/repertoire.sauvegardes'

def controleExistenceRepertoire(directory, create_if_needed=True):
    """Voir si le répertoire existe. S'il n'existe pas il est créé."""
    path_exists = os.path.exists(directory)
    if path_exists:
        if not os.path.isdir(directory):
            raise Exception("Trouvé le nom "+directory+" mais c'est un fichier, pas un répertoire")
            return False
        return True
    if create_if_needed:
        os.makedirs(directory)
        
controleExistenceRepertoire(repertoireEnregistrement)
controleExistenceRepertoire(repertoireSauvegardes)

def sauvegarderImage( fichier):
    """Enregistrez la figure. Appelez la méthode juste avant plt.show ()."""
    plt.savefig(os.path.join(repertoireEnregistrement,
                             fichier+f"--{dt.now().strftime('%Y_%m_%d_%H.%M.%S')}.png"), 
                             dpi=600, 
                             bbox_inches='tight')
    
def sauvegarderModelPoids(model, fichierPoids, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez les poids du modèle Keras."""
    if fichierPoids != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichierPoids))
        model.save_weights(nomFichier)

def sauvegarderModel(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez le modèle Keras."""
    if fichier != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
        model.save(nomFichier)

def lectureModelPoids(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Si le fichier existe, il est chargé et retourne True, sinon retourne False."""
    nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
    if os.path.exists(nomFichier):
        if os.path.isfile(nomFichier):
            model.load_weights(nomFichier)
            return True
    return False

def sauvegardeHistorique(model,
                         repertoireSauvegardes,
                         nomSauvegarde='one_hidden_layer_history_batch_size_1'):

    history = pd.DataFrame( model.history)
    history.reset_index(inplace=True)
    history.rename(columns={'index':'epoch'},inplace=True)
    history.to_parquet(os.path.join(repertoireSauvegardes,f'{nomSauvegarde}.gzip'),compression='gzip', engine='pyarrow') 
    return history

def afficheHistoriqueEntrainement(history, palette):
    fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(48,16));
    markersize = 8
    linewidth=2
    
    graph = sns.lineplot(x='epoch', 
                         y='accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='val_accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    
    graph = sns.lineplot(x='epoch', 
                         y='loss',  
                         data=history,
                         ax=ax[1],      
                         label='loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_loss',  
                         data=history,
                         ax=ax[1],      
                         label='val_loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    sauvegarderImage('afficheHistoriqueEntrainement')

def afficheMatriceConfusion(observations,predictions,dictLabels):
    plt.figure(figsize=(8,8))
    sns.set(font_scale=1.5)
    sns.heatmap(pd.crosstab(observations,predictions), 
                fmt= '.0f',
                linewidths=0.3,
                #vmax=1.0, 
                square=True, 
                cmap=plt.cm.Blues,
                linecolor='white', 
                annot=True,
                cbar=False,
                xticklabels=dictLabels.values(), 
                yticklabels=dictLabels.values()
               );
    plt.xlabel('Observations', fontsize = 18);
    plt.ylabel('Prédictions', fontsize = 18);
    sauvegarderImage('afficheMatriceConfusion')

def executeApprentissageChoixClassifieurs(model,
                                          X_test,
                                          y_test,
                                          label_dict,
                                          couleurs,
                                          nom_essai = 'initial'
                                         ):
    
    def afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict):
        plt.figure(figsize=(24, 24));
        for i, color in zip(range(nbClasses), palette):
            plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
                     label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
                                                             ''.format(i, aucROCt[i]))
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('Taux de faux Positifs-(1 - Spécificité) = VN / (FP + VN)',size=18)
        plt.ylabel('Taux de vrais positifs-Sensibilité = VP / (VP + FN)',size=18)
        plt.title('Courbe ROC (Receiver Operating Caracteristic) -- ',size=20)
        plt.legend(loc="lower right"); #, fontsize='large'
        sauvegarderImage('Courbe ROC')
        
        plt.figure(figsize=(24,24));
    
        f_scores = np.linspace(0.2, 0.9, num=8)
        for f_score in f_scores:
            x = np.linspace(0.01, 1)
            y = f_score * x / (2 * x - f_score)
            l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
            plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
    
        for i, color in zip(range(nbClasses), palette):
            plt.step(sensibilites[i], 
                         precisions[i], 
                         where='post', 
                         color=color, 
                         lw=lw, 
                         label=f"{label_dict[i]}(APR = {avgPrecRec[label_dict[i]]:0.8f})"
                    )
            plt.fill_between(sensibilites[i], precisions[i], step='post', alpha=0.05)            
    
            # plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
            #          label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
            #                                                  ''.format(i, aucROCt[i]))        
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])        
        plt.xlabel('Sensibilité/Rappel(Recall) = VP / (VP + FN)',size=18)
        plt.ylabel('Précision = VP / (VP + FP)',size=18)        
        plt.title('Courbe Précision-Rappel',size=20)
        plt.legend(loc="lower right") # , fontsize = 'large'
        sauvegarderImage('Courbe Précision-Rappel')
    
    cvF1, cvF1SD, cvAccuracy, cvAccSD, aucROC, avgPrecRec, accuracy, balanced_accuracy, logloss, hammingloss, precision, sensibilite, \
    f1, f2, f05, jaccard, vrais_negatifs, faux_positifs, faux_negatifs, vrais_positifs, total_positifs, aucROCtn = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(),\
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    #
    oneloss, precision_micro, precision_macro, precision_weighted, \
    sensibilite_macro, sensibilite_micro, sensibilite_weighted, \
    f1_micro, f1_macro, f1_weighted,f2_micro,f2_macro,f2_weighted,f05_micro,f05_macro,f05_weighted = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    
    fauxPositifs, vraisPositifs, precisions, sensibilites, aucROCt, pr_auc, tauxROC, tauxPR = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()        
    
    
    lw = 1
    # couleurs    = sns.hls_palette(len(classifieursDict.keys()), l=.4, s=.9)
    nbClasses   = len(dictLabels.keys())
    listClasses = list(dictLabels.keys())
    
    y_testA  = label_binarize(y_test, classes=listClasses)
    plt.figure(figsize=(18,18))
    
    
    t1 = time.time()  
    classifier = model
    
    # y_score     = model.predict_proba(X_test)
    # y_pred      = model.predict(X_test)
    y_score     = model.predict(X_test)
    y_pred      = np.argmax(y_score, axis=-1) 
    y_predA     = label_binarize(y_pred, classes=listClasses)
    
    accuracy['global']              = accuracy_score(y_test, y_pred)
    balanced_accuracy['global']     = balanced_accuracy_score(y_test, y_pred)
    precision['global']             = precision_score(y_test, y_pred, average='weighted')
    sensibilite['global']           = recall_score(y_test, y_pred, average='weighted')
    
    f1['global']                    = f1_score(y_test, y_pred, average='weighted')
    f2['global']                    = fbeta_score(y_test, y_pred, beta=2, average='weighted')
    f05['global']                   = fbeta_score(y_test, y_pred, beta=0.5, average='weighted')
    
    vrais_negatifs['global']        = 0
    faux_positifs ['global']        = 0
    faux_negatifs ['global']        = 0
    vrais_positifs['global']        = 0
    total_positifs['global']        = 0
    
    
    aucROC['global'] = roc_auc_score(y_test, y_score, multi_class='ovr')
    
    for i in range(nbClasses):
        fauxPositifs[i], vraisPositifs[i], tauxROC[i] = roc_curve(y_testA[:, i], y_score[:, i])
        aucROCt[i]                                    = auc(fauxPositifs[i], vraisPositifs[i])
        precisions[i], sensibilites[i], tauxPR[i]     = precision_recall_curve(y_testA[:, i], y_score[:, i])
    
        aucROC[label_dict[i]]                = aucROCt[i]
        avgPrecRec[label_dict[i]]            = average_precision_score(y_testA[:, i], y_score[:, i])
        accuracy[label_dict[i]]              = accuracy_score(y_testA[:, i], y_predA[:, i])
        balanced_accuracy[label_dict[i]]     = balanced_accuracy_score(y_testA[:, i],y_predA[:, i])
        logloss[label_dict[i]]               = log_loss(y_testA[:, i], y_predA[:, i])
        hammingloss[label_dict[i]]           = hamming_loss(y_testA[:, i], y_predA[:, i])
        precision[label_dict[i]]             = precision_score(y_testA[:, i], y_predA[:, i])
        sensibilite[label_dict[i]]           = recall_score(y_testA[:, i], y_predA[:, i])
        f1[label_dict[i]]                    = f1_score(y_testA[:, i], y_predA[:, i])
        f2[label_dict[i]]                    = fbeta_score(y_testA[:, i], y_predA[:, i], beta=2)
        f05[label_dict[i]]                   = fbeta_score(y_testA[:, i], y_predA[:, i], beta=0.5)
      
        jaccard[label_dict[i]]               = jaccard_score(y_testA[:, i], y_predA[:, i])
        vrais_negatifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 0]
        faux_positifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 1]
        faux_negatifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 0]
        vrais_positifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 1]
        total_positifs[label_dict[i]]        = vrais_positifs[label_dict[i]] + faux_negatifs [label_dict[i]]
        vrais_negatifs['global']              += vrais_negatifs[label_dict[i]]
        faux_positifs ['global']              += faux_positifs [label_dict[i]]
        faux_negatifs ['global']              += faux_negatifs [label_dict[i]]
        vrais_positifs['global']              += vrais_positifs[label_dict[i]]
    
    
    total_positifs['global'] = vrais_positifs['global'] + faux_negatifs ['global']
    
    
    fauxPositifs["micro"], vraisPositifs["micro"], _ = roc_curve(y_testA.ravel(), y_score.ravel())
    aucROCt["micro"]                                 = auc(fauxPositifs["micro"], vraisPositifs["micro"])
    
    listFauxPositifs = np.unique(np.concatenate([fauxPositifs[i] for i in range(nbClasses)]))
    moyenneVraisPositifs = np.zeros_like(listFauxPositifs)
    for i in range(nbClasses):
        moyenneVraisPositifs += np.interp(listFauxPositifs, fauxPositifs[i], vraisPositifs[i])
    
    moyenneVraisPositifs /= nbClasses
    
    fauxPositifs["macro"], vraisPositifs["macro"] = listFauxPositifs, moyenneVraisPositifs
    aucROCt["macro"] = auc(fauxPositifs["macro"], vraisPositifs["macro"])
    # aucROC['global'] = aucROCt["macro"]  # (aucROCt["micro"],aucROCt["macro"])
    
    avgPrecRec['global'] = average_precision_score(y_testA.ravel(), y_score.ravel(), average='weighted')
    
    afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict);
    
    print ("Area under the ROC curve : %0.4f" % aucROC['global'],end='\t--\t')
    print('Exécution  :'+('%.2fs' % (time.time() - t1)).lstrip('0'))
        
    resultats = pd.DataFrame(pd.Series(aucROC), columns=["aucROC"])
    resultats["avgPrecRec"]              = pd.Series(avgPrecRec)
    resultats["f1"]                      = pd.Series(f1)
    resultats["f2"]                      = pd.Series(f2)
    resultats["f05"]                     = pd.Series(f05)
    resultats["accuracy"]                = pd.Series(accuracy)
    
    resultats["precision"]               = pd.Series(precision)
    resultats["sensibilite"]             = pd.Series(sensibilite)
    resultats["vrais_positifs"]          = pd.Series(vrais_positifs)
    resultats["vrais_negatifs"]          = pd.Series(vrais_negatifs)
    resultats["faux_positifs"]           = pd.Series(faux_positifs)
    resultats["faux_negatifs"]           = pd.Series(faux_negatifs)
    resultats["total_positifs"]          = pd.Series(total_positifs)
    
    resultats.reset_index(inplace=True)
    resultats.rename(columns={"index": "Classe"}, inplace=True)
    resultats['essai'] = nom_essai
    return resultats

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Lecture des données</div></b>

# %%
imagesize = [28,28,3]
number_of_pixels = imagesize[0]*imagesize[1]*imagesize[2]
number_of_classes = 8

# %%
! ls ../donnees/MedMNIST/bloodmnist.npz
# Out:
# ../donnees/MedMNIST/bloodmnist.npz

# %%
dictLabels = { 0:"basophil",
               1:"eosinophil",
               2:"erythroblast",
               3:"immature",# granulocytes(myelocytes, metamyelocytes and promyelocytes)",
               4:"lymphocyte",
               5:"monocyte",
               6:"neutrophil",
               7:"platelet"}

# %%
donnees = np.load("../donnees/MedMNIST/bloodmnist.npz")

# %%
apprentissage = np.reshape(donnees["train_images"],(donnees["train_images"].shape[0],
                                    donnees["train_images"].shape[1]*donnees["train_images"].shape[2]*donnees["train_images"].shape[3])).astype('float64')

validation = np.reshape(donnees["val_images"],(donnees["val_images"].shape[0],
                                    donnees["val_images"].shape[1]*donnees["val_images"].shape[2]*donnees["val_images"].shape[3])).astype('float64')

# %%
# scale data to range [0, 1]
apprentissage /= 255.0
validation /= 255.0

# scale data to range [-0.5, 0.5]
apprentissage -= 0.5
validation -= 0.5

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
epochs=56
batch_size = 256
initial_lrate = 1e-3
min_lrate = 1e-4

drop_lrate = 0.5
epochs_drop = epochs * 0.1

# %%
def make_model():
    model = Sequential()
    model.add(Dense(number_of_pixels, 
                    activation='relu',
                    input_shape=[number_of_pixels]
                   )
             )
    model.add(Dense(number_of_classes, 
                    activation='softmax'))
    
    return model

# make the model
model = make_model()

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Compilation du modèle </div></b>

# %%
model.compile(
        optimizer=tf.keras.optimizers.Adam(initial_lrate), 
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
    )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2352)           │     5,534,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │        18,824 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,553,080 (21.18 MB)
#  Trainable params: 5,553,080 (21.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>
#
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
# learning rate scheduler
def step_decay(epoch):
    lrate = (initial_lrate - min_lrate ) * drop_lrate**((1+epoch)/epochs_drop) + min_lrate
    return lrate
# learning schedule callback

learningRate = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
rng = [i for i in range(128)]
y = [step_decay(x) for x in rng]
plt.plot(rng, y)
print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.000895 à 0.0001

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels de sauvegarde automatique du modèle </div></b>

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde chaque étape </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic1-epoch-{epoch:04d}.keras')
checkpointTimer1  = tf.keras.callbacks.ModelCheckpoint(filename,save_freq='epoch')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde tous les 5 étapes </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic5-epoch-{epoch:04d}.keras')
checkpointTimer5 = tf.keras.callbacks.ModelCheckpoint(filename,save_freq=5)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_loss minim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVLoss-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
filename = os.path.join(repertoireSauvegardes, 'modelCheckpoint.keras')

checkpointLoss = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                    monitor = 'val_loss',
                                                    verbose = 1, 
                                                    save_best_only = True, 
                                                    mode = 'min')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_accuracy maxim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVAccuracy-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
checkpointAccuracy = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                           monitor = 'val_accuracy', 
                                                           verbose = 1, 
                                                           save_best_only = True, 
                                                           mode = 'max')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Arrêt de l'apprentissage</div></b>

# %%
arretPrecoce = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels utilisés</div></b>

# %%
callbacks = [
    learningRate,
    checkpointTimer1,
    checkpointTimer5,
    checkpointLoss,
    checkpointAccuracy,
    arretPrecoce
]

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle -Batch Size 256</div></b>

# %%
history = model.fit( apprentissage, 
                     donnees["train_labels"].ravel(), 
                     validation_data=(validation,donnees["val_labels"].ravel()), 
                     callbacks=callbacks,
                     epochs=epochs, 
                     batch_size=batch_size, 
                     verbose=1)
# Out:
# Epoch 1/56
#  5/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2572 - loss: 3.9367
# I0000 00:00:1751707492.279097  117692 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3972 - loss: 2.4525
# Epoch 1: val_loss improved from inf to 0.78658, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.72897, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0001-val_loss-0.787-val_accuracy-0.729.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.4002 - loss: 2.4339 - val_accuracy: 0.7290 - val_loss: 0.7866 - learning_rate: 8.9522e-04
# Epoch 2/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7420 - loss: 0.7810
# Epoch 2: val_loss improved from 0.78658 to 0.69459, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 2: val_accuracy improved from 0.72897 to 0.75467, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0002-val_loss-0.695-val_accuracy-0.755.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7431 - loss: 0.7776 - val_accuracy: 0.7547 - val_loss: 0.6946 - learning_rate: 8.0264e-04
# Epoch 3/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7774 - loss: 0.6653
# Epoch 3: val_loss improved from 0.69459 to 0.57777, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 3: val_accuracy improved from 0.75467 to 0.79556, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0003-val_loss-0.578-val_accuracy-0.796.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7780 - loss: 0.6642 - val_accuracy: 0.7956 - val_loss: 0.5778 - learning_rate: 7.2084e-04
# Epoch 4/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7955 - loss: 0.5948
# Epoch 4: val_loss improved from 0.57777 to 0.53224, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 4: val_accuracy improved from 0.79556 to 0.81542, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0004-val_loss-0.532-val_accuracy-0.815.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7964 - loss: 0.5935 - val_accuracy: 0.8154 - val_loss: 0.5322 - learning_rate: 6.4856e-04
# Epoch 5/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8161 - loss: 0.5407
# Epoch 5: val_loss improved from 0.53224 to 0.51643, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 5: val_accuracy improved from 0.81542 to 0.81951, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0005-val_loss-0.516-val_accuracy-0.820.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8161 - loss: 0.5406 - val_accuracy: 0.8195 - val_loss: 0.5164 - learning_rate: 5.8469e-04
# Epoch 6/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8350 - loss: 0.5012
# Epoch 6: val_loss improved from 0.51643 to 0.47760, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 6: val_accuracy improved from 0.81951 to 0.83528, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0006-val_loss-0.478-val_accuracy-0.835.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8349 - loss: 0.5012 - val_accuracy: 0.8353 - val_loss: 0.4776 - learning_rate: 5.2826e-04
# Epoch 7/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8424 - loss: 0.4720
# Epoch 7: val_loss improved from 0.47760 to 0.47475, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 7: val_accuracy improved from 0.83528 to 0.84171, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0007-val_loss-0.475-val_accuracy-0.842.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8422 - loss: 0.4718 - val_accuracy: 0.8417 - val_loss: 0.4748 - learning_rate: 4.7840e-04
# Epoch 8/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8455 - loss: 0.4523
# Epoch 8: val_loss improved from 0.47475 to 0.46884, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 8: val_accuracy did not improve from 0.84171
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8454 - loss: 0.4523 - val_accuracy: 0.8382 - val_loss: 0.4688 - learning_rate: 4.3435e-04
# Epoch 9/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8505 - loss: 0.4384
# Epoch 9: val_loss improved from 0.46884 to 0.44197, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 9: val_accuracy improved from 0.84171 to 0.85397, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0009-val_loss-0.442-val_accuracy-0.854.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.8505 - loss: 0.4380 - val_accuracy: 0.8540 - val_loss: 0.4420 - learning_rate: 3.9542e-04
# Epoch 10/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8597 - loss: 0.4068
# Epoch 10: val_loss improved from 0.44197 to 0.43014, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 10: val_accuracy did not improve from 0.85397
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8597 - loss: 0.4068 - val_accuracy: 0.8522 - val_loss: 0.4301 - learning_rate: 3.6103e-04
# Epoch 11/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8687 - loss: 0.4019
# Epoch 11: val_loss improved from 0.43014 to 0.42460, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 11: val_accuracy improved from 0.85397 to 0.85748, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0011-val_loss-0.425-val_accuracy-0.857.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8686 - loss: 0.4014 - val_accuracy: 0.8575 - val_loss: 0.4246 - learning_rate: 3.3064e-04
# Epoch 12/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8708 - loss: 0.3794
# Epoch 12: val_loss did not improve from 0.42460
#
# Epoch 12: val_accuracy did not improve from 0.85748
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8705 - loss: 0.3801 - val_accuracy: 0.8446 - val_loss: 0.4455 - learning_rate: 3.0379e-04
# Epoch 13/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8697 - loss: 0.3732
# Epoch 13: val_loss improved from 0.42460 to 0.42189, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 13: val_accuracy improved from 0.85748 to 0.86157, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0013-val_loss-0.422-val_accuracy-0.862.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8698 - loss: 0.3732 - val_accuracy: 0.8616 - val_loss: 0.4219 - learning_rate: 2.8006e-04
# Epoch 14/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8779 - loss: 0.3564
# Epoch 14: val_loss improved from 0.42189 to 0.41345, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 14: val_accuracy did not improve from 0.86157
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8780 - loss: 0.3565 - val_accuracy: 0.8557 - val_loss: 0.4135 - learning_rate: 2.5910e-04
# Epoch 15/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8814 - loss: 0.3471
# Epoch 15: val_loss improved from 0.41345 to 0.40796, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 15: val_accuracy improved from 0.86157 to 0.86215, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0015-val_loss-0.408-val_accuracy-0.862.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8814 - loss: 0.3470 - val_accuracy: 0.8621 - val_loss: 0.4080 - learning_rate: 2.4058e-04
# Epoch 16/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8880 - loss: 0.3384
# Epoch 16: val_loss improved from 0.40796 to 0.40389, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 16: val_accuracy did not improve from 0.86215
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8878 - loss: 0.3386 - val_accuracy: 0.8586 - val_loss: 0.4039 - learning_rate: 2.2421e-04
# Epoch 17/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8862 - loss: 0.3403
# Epoch 17: val_loss improved from 0.40389 to 0.39250, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 17: val_accuracy improved from 0.86215 to 0.86916, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0017-val_loss-0.393-val_accuracy-0.869.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.8864 - loss: 0.3395 - val_accuracy: 0.8692 - val_loss: 0.3925 - learning_rate: 2.0975e-04
# Epoch 18/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8890 - loss: 0.3284
# Epoch 18: val_loss did not improve from 0.39250
#
# Epoch 18: val_accuracy did not improve from 0.86916
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8892 - loss: 0.3282 - val_accuracy: 0.8668 - val_loss: 0.3935 - learning_rate: 1.9697e-04
# Epoch 19/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9020 - loss: 0.3100
# Epoch 19: val_loss improved from 0.39250 to 0.38755, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 19: val_accuracy did not improve from 0.86916
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9017 - loss: 0.3104 - val_accuracy: 0.8627 - val_loss: 0.3876 - learning_rate: 1.8568e-04
# Epoch 20/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8983 - loss: 0.3072
# Epoch 20: val_loss improved from 0.38755 to 0.38132, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 20: val_accuracy improved from 0.86916 to 0.87442, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0020-val_loss-0.381-val_accuracy-0.874.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8983 - loss: 0.3072 - val_accuracy: 0.8744 - val_loss: 0.3813 - learning_rate: 1.7571e-04
# Epoch 21/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8999 - loss: 0.3089
# Epoch 21: val_loss improved from 0.38132 to 0.37770, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 21: val_accuracy improved from 0.87442 to 0.87792, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0021-val_loss-0.378-val_accuracy-0.878.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.8999 - loss: 0.3085 - val_accuracy: 0.8779 - val_loss: 0.3777 - learning_rate: 1.6689e-04
# Epoch 22/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9039 - loss: 0.2911
# Epoch 22: val_loss did not improve from 0.37770
#
# Epoch 22: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9036 - loss: 0.2919 - val_accuracy: 0.8768 - val_loss: 0.3804 - learning_rate: 1.5911e-04
# Epoch 23/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9081 - loss: 0.2869
# Epoch 23: val_loss improved from 0.37770 to 0.37429, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 23: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9080 - loss: 0.2872 - val_accuracy: 0.8744 - val_loss: 0.3743 - learning_rate: 1.5222e-04
# Epoch 24/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9109 - loss: 0.2838
# Epoch 24: val_loss improved from 0.37429 to 0.37272, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 24: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9105 - loss: 0.2842 - val_accuracy: 0.8750 - val_loss: 0.3727 - learning_rate: 1.4614e-04
# Epoch 25/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9116 - loss: 0.2789
# Epoch 25: val_loss improved from 0.37272 to 0.37040, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 25: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9115 - loss: 0.2790 - val_accuracy: 0.8715 - val_loss: 0.3704 - learning_rate: 1.4077e-04
# Epoch 26/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9140 - loss: 0.2838
# Epoch 26: val_loss did not improve from 0.37040
#
# Epoch 26: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9138 - loss: 0.2836 - val_accuracy: 0.8703 - val_loss: 0.3717 - learning_rate: 1.3602e-04
# Epoch 27/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9159 - loss: 0.2672
# Epoch 27: val_loss improved from 0.37040 to 0.36587, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 27: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9155 - loss: 0.2680 - val_accuracy: 0.8756 - val_loss: 0.3659 - learning_rate: 1.3183e-04
# Epoch 28/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9148 - loss: 0.2721
# Epoch 28: val_loss improved from 0.36587 to 0.36458, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 28: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9147 - loss: 0.2721 - val_accuracy: 0.8768 - val_loss: 0.3646 - learning_rate: 1.2813e-04
# Epoch 29/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9163 - loss: 0.2635
# Epoch 29: val_loss did not improve from 0.36458
#
# Epoch 29: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9162 - loss: 0.2639 - val_accuracy: 0.8762 - val_loss: 0.3671 - learning_rate: 1.2485e-04
# Epoch 30/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9130 - loss: 0.2690
# Epoch 30: val_loss improved from 0.36458 to 0.36225, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 30: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9130 - loss: 0.2689 - val_accuracy: 0.8762 - val_loss: 0.3622 - learning_rate: 1.2196e-04
# Epoch 31/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9116 - loss: 0.2703
# Epoch 31: val_loss did not improve from 0.36225
#
# Epoch 31: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9119 - loss: 0.2697 - val_accuracy: 0.8732 - val_loss: 0.3653 - learning_rate: 1.1940e-04
# Epoch 32/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9168 - loss: 0.2563
# Epoch 32: val_loss improved from 0.36225 to 0.35987, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 32: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9171 - loss: 0.2564 - val_accuracy: 0.8768 - val_loss: 0.3599 - learning_rate: 1.1714e-04
# Epoch 33/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9236 - loss: 0.2499
# Epoch 33: val_loss did not improve from 0.35987
#
# Epoch 33: val_accuracy did not improve from 0.87792
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9235 - loss: 0.2501 - val_accuracy: 0.8709 - val_loss: 0.3638 - learning_rate: 1.1515e-04
# Epoch 34/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9257 - loss: 0.2465
# Epoch 34: val_loss improved from 0.35987 to 0.35756, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 34: val_accuracy improved from 0.87792 to 0.88026, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0034-val_loss-0.358-val_accuracy-0.880.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9254 - loss: 0.2468 - val_accuracy: 0.8803 - val_loss: 0.3576 - learning_rate: 1.1338e-04
# Epoch 35/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9169 - loss: 0.2484
# Epoch 35: val_loss did not improve from 0.35756
#
# Epoch 35: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9170 - loss: 0.2484 - val_accuracy: 0.8791 - val_loss: 0.3579 - learning_rate: 1.1183e-04
# Epoch 36/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9221 - loss: 0.2466
# Epoch 36: val_loss did not improve from 0.35756
#
# Epoch 36: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9222 - loss: 0.2465 - val_accuracy: 0.8750 - val_loss: 0.3584 - learning_rate: 1.1045e-04
# Epoch 37/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9242 - loss: 0.2457
# Epoch 37: val_loss improved from 0.35756 to 0.35163, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 37: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9243 - loss: 0.2452 - val_accuracy: 0.8768 - val_loss: 0.3516 - learning_rate: 1.0923e-04
# Epoch 38/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9262 - loss: 0.2377
# Epoch 38: val_loss did not improve from 0.35163
#
# Epoch 38: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9262 - loss: 0.2378 - val_accuracy: 0.8785 - val_loss: 0.3561 - learning_rate: 1.0816e-04
# Epoch 39/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9277 - loss: 0.2365
# Epoch 39: val_loss did not improve from 0.35163
#
# Epoch 39: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9276 - loss: 0.2364 - val_accuracy: 0.8785 - val_loss: 0.3570 - learning_rate: 1.0721e-04
# Epoch 40/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9278 - loss: 0.2326
# Epoch 40: val_loss improved from 0.35163 to 0.34723, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 40: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9278 - loss: 0.2326 - val_accuracy: 0.8773 - val_loss: 0.3472 - learning_rate: 1.0637e-04
# Epoch 41/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9339 - loss: 0.2254
# Epoch 41: val_loss did not improve from 0.34723
#
# Epoch 41: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9337 - loss: 0.2255 - val_accuracy: 0.8750 - val_loss: 0.3546 - learning_rate: 1.0563e-04
# Epoch 42/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9256 - loss: 0.2344
# Epoch 42: val_loss did not improve from 0.34723
#
# Epoch 42: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9260 - loss: 0.2338 - val_accuracy: 0.8750 - val_loss: 0.3513 - learning_rate: 1.0497e-04
# Epoch 43/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9329 - loss: 0.2206
# Epoch 43: val_loss did not improve from 0.34723
#
# Epoch 43: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9329 - loss: 0.2208 - val_accuracy: 0.8762 - val_loss: 0.3497 - learning_rate: 1.0439e-04
# Epoch 44/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9358 - loss: 0.2195
# Epoch 44: val_loss did not improve from 0.34723
#
# Epoch 44: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9356 - loss: 0.2197 - val_accuracy: 0.8773 - val_loss: 0.3478 - learning_rate: 1.0388e-04
# Epoch 45/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9396 - loss: 0.2119
# Epoch 45: val_loss did not improve from 0.34723
#
# Epoch 45: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9395 - loss: 0.2120 - val_accuracy: 0.8797 - val_loss: 0.3473 - learning_rate: 1.0343e-04
# Epoch 46/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9318 - loss: 0.2166
# Epoch 46: val_loss improved from 0.34723 to 0.34568, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 46: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9320 - loss: 0.2166 - val_accuracy: 0.8750 - val_loss: 0.3457 - learning_rate: 1.0303e-04
# Epoch 47/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9383 - loss: 0.2100
# Epoch 47: val_loss improved from 0.34568 to 0.34279, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 47: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9380 - loss: 0.2105 - val_accuracy: 0.8768 - val_loss: 0.3428 - learning_rate: 1.0268e-04
# Epoch 48/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9394 - loss: 0.2056
# Epoch 48: val_loss did not improve from 0.34279
#
# Epoch 48: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9393 - loss: 0.2058 - val_accuracy: 0.8756 - val_loss: 0.3511 - learning_rate: 1.0237e-04
# Epoch 49/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9390 - loss: 0.2065
# Epoch 49: val_loss did not improve from 0.34279
#
# Epoch 49: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9391 - loss: 0.2065 - val_accuracy: 0.8756 - val_loss: 0.3458 - learning_rate: 1.0209e-04
# Epoch 50/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9394 - loss: 0.2075
# Epoch 50: val_loss improved from 0.34279 to 0.33952, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 50: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9394 - loss: 0.2075 - val_accuracy: 0.8779 - val_loss: 0.3395 - learning_rate: 1.0185e-04
# Epoch 51/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9427 - loss: 0.1992
# Epoch 51: val_loss did not improve from 0.33952
#
# Epoch 51: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9426 - loss: 0.1993 - val_accuracy: 0.8791 - val_loss: 0.3420 - learning_rate: 1.0163e-04
# Epoch 52/56
# 43/47 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9407 - loss: 0.1980
# Epoch 52: val_loss did not improve from 0.33952
#
# Epoch 52: val_accuracy did not improve from 0.88026
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9409 - loss: 0.1980 - val_accuracy: 0.8803 - val_loss: 0.3446 - learning_rate: 1.0144e-04
# Epoch 53/56
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9449 - loss: 0.1895
# Epoch 53: val_loss improved from 0.33952 to 0.33914, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 53: val_accuracy improved from 0.88026 to 0.88201, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelVAccuracy-epoch-0053-val_loss-0.339-val_accuracy-0.882.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9448 - loss: 0.1899 - val_accuracy: 0.8820 - val_loss: 0.3391 - learning_rate: 1.0127e-04
# Epoch 54/56
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9423 - loss: 0.1947
# Epoch 54: val_loss did not improve from 0.33914
#
# Epoch 54: val_accuracy did not improve from 0.88201
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9423 - loss: 0.1948 - val_accuracy: 0.8750 - val_loss: 0.3416 - learning_rate: 1.0113e-04
# Epoch 55/56
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9452 - loss: 0.1946
# Epoch 55: val_loss did not improve from 0.33914
#
# Epoch 55: val_accuracy did not improve from 0.88201
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9452 - loss: 0.1946 - val_accuracy: 0.8803 - val_loss: 0.3394 - learning_rate: 1.0099e-04
# Epoch 56/56
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9463 - loss: 0.1835
# Epoch 56: val_loss improved from 0.33914 to 0.33456, saving model to /home/razvan/documentation/DeepLearning/CNN/05-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras
#
# Epoch 56: val_accuracy did not improve from 0.88201
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9462 - loss: 0.1838 - val_accuracy: 0.8820 - val_loss: 0.3346 - learning_rate: 1.0088e-04

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
history = sauvegardeHistorique(history,
                               repertoireSauvegardes,
                               nomSauvegarde='one_hidden_layer_history_batch_size_256')

# %%
afficheHistoriqueEntrainement(history, palette)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.one_hidden_layer_history_batch_size_256.keras'))

# %%
sauvegarderModel(model, 'one_hidden_layer_history_batch_size_256')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du modèle </div></b>

# %%
model = tf.keras.models.load_model("/home/razvan/documentation/DeepLearning/CNN/04-L'apprentissage et rappels d’exécution-bloodMNIST-Sparse/repertoire.sauvegardes/modelCheckpoint.keras")

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2352)           │     5,534,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │        18,824 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,659,242 (63.55 MB)
#  Trainable params: 5,553,080 (21.18 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 11,106,162 (42.37 MB)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
probabilities = model.predict(validation, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
plt.figure(figsize=(20,8))
for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.bar(range(8), probabilities[i], color="#030aa7", align='center')
    plt.xlim(-0.5, 9.5)
    plt.ylim(0, 1)
    plt.title(predictions[i],fontsize=30)
plt.tight_layout()
sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=donnees["val_labels"].ravel(),predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=validation,
                                                  y_test=donnees["val_labels"].ravel(),
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step
# Area under the ROC curve : 0.9872	--	Exécution  :9.44s
#          Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0        global  0.987155    0.956774  0.881867  0.881897  0.882010  0.882009
# 1      basophil  0.978044    0.827429  0.735043  0.716667  0.754386  0.963785
# 2    eosinophil  0.999020    0.995820  0.959742  0.956969  0.962532  0.985397
# 3  erythroblast  0.986355    0.956214  0.912621  0.910853  0.914397  0.984229
# 4      immature  0.956606    0.821899  0.738095  0.744170  0.732119  0.910047
# 5    lymphocyte  0.995278    0.946264  0.864407  0.847176  0.882353  0.981308
# 6      monocyte  0.987217    0.878862  0.793103  0.799722  0.786594  0.964953
# 7    neutrophil  0.994843    0.982205  0.942222  0.949821  0.934744  0.977220
# 8      platelet  0.999879    0.999207  0.989384  0.990646  0.988126  0.997079
#
#    precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0   0.882205     0.882009            1510           11782            202
# 1   0.767857     0.704918              86            1564             26
# 2   0.964401     0.955128             298            1389             11
# 3   0.915584     0.909677             141            1544             13
# 4   0.728188     0.748276             217            1341             81
# 5   0.894737     0.836066             102            1578             12
# 6   0.782313     0.804196             115            1537             32
# 7   0.929825     0.954955             318            1355             24
# 8   0.987288     0.991489             233            1474              3
#
#    faux_negatifs  total_positifs    essai
# 0            202            1712  initial
# 1             36             122  initial
# 2             14             312  initial
# 3             14             155  initial
# 4             73             290  initial
# 5             20             122  initial
# 6             28             143  initial
# 7             15             333  initial
# 8              2             235  initial
