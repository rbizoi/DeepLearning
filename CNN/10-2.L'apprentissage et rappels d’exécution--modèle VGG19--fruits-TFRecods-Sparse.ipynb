# %% [markdown]
# <table>
# <tr>
#      <th>
#          <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'><a href="https://www.kaggle.com/datasets/sshikamaru/fruit-recognition">Reconnaissance des Fruits</a></div>
#      </th>
#      <th><img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/fruits.jpg" width="96"></th>
#  </tr>
# </table>
#
#
#
# **Reconnaissance des fruits**<br>
# Le jeu de données contient **13 514** images de fleurs étiquetées en **24** classes.
#
# <table>
# <tr>
#      <th>
# <table>
#     <tr>
#          <th  style="text-align:left;background-color:#053061;color:white;">Valeur</th>
#          <th  style="text-align:left;background-color:#053061;color:white;">Nom classe</th>
#      </tr>
#     <tr>
#         <th  style="text-align:left">0</th>
#         <th  style="text-align:left">Abricot</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">1</th>
#         <th  style="text-align:left">Ananas</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">2</th>
#         <th  style="text-align:left">Avocat</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">3</th>
#         <th  style="text-align:left">Banane</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">4</th>
#         <th  style="text-align:left">Cerise</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">5</th>
#         <th  style="text-align:left">Citron</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">6</th>
#         <th  style="text-align:left">Clémentine</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">7</th>
#         <th  style="text-align:left">Fraise</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">8</th>
#         <th  style="text-align:left">Framboise</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">9</th>
#         <th  style="text-align:left">Kiwi</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">10</th>
#         <th  style="text-align:left">Maïs</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">11</th>
#         <th  style="text-align:left">Mangue</th>
#     </tr>
#
#
# </table>    </th>
#      <th>
# <table>
#     <tr>
#          <th  style="text-align:left;background-color:#053061;color:white;">Valeur</th>
#          <th  style="text-align:left;background-color:#053061;color:white;">Nom classe</th>
#      </tr>
#     <tr>
#         <th  style="text-align:left">12</th>
#         <th  style="text-align:left">Myrtille</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">13</th>
#         <th  style="text-align:left">Oignon</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">14</th>
#         <th  style="text-align:left">Orange</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">15</th>
#         <th  style="text-align:left">Papaye</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">16</th>
#         <th  style="text-align:left">Pastèque</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">17</th>
#         <th  style="text-align:left">Pêche</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">18</th>
#         <th  style="text-align:left">Poire</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">19</th>
#         <th  style="text-align:left">Poivron</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">20</th>
#         <th  style="text-align:left">Pomme</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">21</th>
#         <th  style="text-align:left">Pomme de terre</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">22</th>
#         <th  style="text-align:left">Prune</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">23</th>
#         <th  style="text-align:left">Tomate</th>
#     </tr>
# </table>    </th>
#  </tr>
# </table>
#
#
# > https://www.larousse.fr/dictionnaires/francais/inf%C3%A9rence/42907<br><br>
#
# >> **inférence** : Opération par laquelle on passe d'une assertion considérée comme vraie à une autre assertion au moyen d'un système de règles qui rend cette deuxième assertion également vraie.<br>
#
# >> **Inférence statistique** : Ensemble des méthodes permettant de formuler en termes probabilistes un jugement sur une population à partir des résultats observés sur un échantillon extrait au hasard de cette population.<br>
#
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ['TF_XLA_FLAGS']='--tf_xla_auto_jit=1,--tf_xla_always_defer_compilation=true'
# os.environ['XLA_FLAGS']='--xla_backend_optimization_level=0,--xla_gpu_autotune_level=4,--xla_gpu_disable_ptxas_optimizations=true,--xla_gpu_use_cudnn_batchnorm_level=2'
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, pickle, time
from matplotlib import pyplot as plt
from datetime import datetime as dt

import matplotlib.font_manager as fm
from matplotlib.lines import Line2D

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist,fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm

from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer, confusion_matrix, roc_curve, auc, accuracy_score, log_loss, hamming_loss, \
                            precision_score, recall_score, f1_score, fbeta_score, jaccard_score, \
                            precision_recall_curve, average_precision_score, balanced_accuracy_score, \
                            classification_report,roc_auc_score

tf.get_logger().setLevel('ERROR')# Suppress TensorFlow logging (2)

# %%
print("Tensorflow\t : %s\tCUDA %s\tGPU %s\tXLA %s\nKeras\t\t : %s\nPandas\t\t : %s\nNumPy\t\t : %s"%
      (tf.__version__, 
       tf.test.is_built_with_cuda(), 
       tf.test.is_built_with_gpu_support(), 
       tf.test.is_built_with_xla(), 
       tf.keras.__version__, 
       pd.__version__, 
       np.__version__))
# Out:
# Tensorflow	 : 2.17.0	CUDA True	GPU True	XLA True
# Keras		 : 3.6.0
# Pandas		 : 2.2.2
# NumPy		 : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des GPUs presents</div></b>

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) >  0 :
    for i, gpu in enumerate(physical_devices):
        tf.config.experimental.set_memory_growth(physical_devices[i], True)

    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('Le système est initialisé avec {0:d} GPUs'.format(strategy.num_replicas_in_sync))
# Out:
# Le système est initialisé avec 1 GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751919957.623844 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.643803 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.643929 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751919957.650370 2619813 service.cc:146] XLA service 0x2ed4b560 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751919957.650389 2619813 service.cc:154]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1751919957.703053 2619968 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.703179 2619813 service.cc:146] XLA service 0x2c14ade0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751919957.703193 2619813 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1751919957.703335 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.703435 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.703491 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.706806 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751919957.706900 2619813 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
palette = [
            "#030aa7", "#e50000", "#d8863b", "#005f6a", "#6b7c85", "#751973", "#d1e5f0", "#fddbc7",
            "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#f5054f", "#a0450e",
            "#0339f8", "#f4320c", "#fec615", "#017a79", "#85a3b2", "#fe2f4a", "#a00498", "#b04e0f",
            "#0165fc", "#ff724c", "#fddc5c", "#11875d", "#89a0b0", "#fe828c", "#cb00f5", "#b75203",
            "#0485d1", "#ff7855", "#fbeeac", "#0cb577", "#95a3a6", "#ffb7ce", "#c071fe", "#ca6b02",
            "#92c5de", "#f4a582", "#fef69e", "#18d17b", "#c5c9c7", "#ffcfdc", "#caa0ff", "#cb7723",
            "#d1e5f0", "#fddbc7", "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#d8863b",
            "#030764", "#be0119", "#dbb40c", "#005249", "#3c4142", "#cb0162", "#5d1451", "#653700",
            "#040348", "#67001f", "#b27a01", "#002d04", "#000000", "#a0025c", "#490648", "#3c0008"
          ]

# %%
nom_projet                = "10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods"
repertoireProjet          = os.getcwd()
repertoireEnregistrement  = repertoireProjet +'/'+nom_projet+ '/repertoire.images'
repertoireSauvegardes     = repertoireProjet +'/'+nom_projet+ '/repertoire.sauvegardes'

def controleExistenceRepertoire(directory, create_if_needed=True):
    """Voir si le répertoire existe. S'il n'existe pas il est créé."""
    path_exists = os.path.exists(directory)
    if path_exists:
        if not os.path.isdir(directory):
            raise Exception("Trouvé le nom "+directory+" mais c'est un fichier, pas un répertoire")
            return False
        return True
    if create_if_needed:
        os.makedirs(directory)
        
controleExistenceRepertoire(repertoireEnregistrement)
controleExistenceRepertoire(repertoireSauvegardes)

def sauvegarderImage( fichier):
    """Enregistrez la figure. Appelez la méthode juste avant plt.show ()."""
    plt.savefig(os.path.join(repertoireEnregistrement,
                             fichier+f"--{dt.now().strftime('%Y_%m_%d_%H.%M.%S')}.png"), 
                             dpi=600, 
                             bbox_inches='tight')
    
def sauvegarderModelPoids(model, fichierPoids, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez les poids du modèle Keras."""
    if fichierPoids != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichierPoids))
        model.save_weights(nomFichier)

def sauvegarderModel(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez le modèle Keras."""
    if fichier != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
        model.save(nomFichier)

def lectureModelPoids(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Si le fichier existe, il est chargé et retourne True, sinon retourne False."""
    nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
    if os.path.exists(nomFichier):
        if os.path.isfile(nomFichier):
            model.load_weights(nomFichier)
            return True
    return False

def sauvegardeHistorique(model,
                         repertoireSauvegardes,
                         nomSauvegarde='one_hidden_layer_history_batch_size_1'):

    history = pd.DataFrame( model.history)
    history.reset_index(inplace=True)
    history.rename(columns={'index':'epoch'},inplace=True)
    history.to_parquet(os.path.join(repertoireSauvegardes,f'{nomSauvegarde}.gzip'),compression='gzip', engine='pyarrow') 
    return history


def afficheHistoriqueEntrainement(history, palette, nom):
    fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(48,16));
    markersize = 8
    linewidth=2
    
    graph = sns.lineplot(x='epoch', 
                         y='accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='val_accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
        
    ax[0].set_title(f'Accuracy {nom}', fontproperties=fm.FontProperties(size=32))
    
    graph = sns.lineplot(x='epoch', 
                         y='loss',  
                         data=history,
                         ax=ax[1],      
                         label='loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_loss',  
                         data=history,
                         ax=ax[1],      
                         label='val_loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    ax[1].set_title(f'Loss {nom}', fontproperties=fm.FontProperties(size=32))
    
    sauvegarderImage(f'afficheHistoriqueEntrainement-{nom}')



def afficheMatriceConfusion(observations,predictions,dictLabels):
    plt.figure(figsize=(8,8))
    sns.set(font_scale=1.5)
    sns.heatmap(pd.crosstab(observations,predictions), 
                fmt= '.0f',
                linewidths=0.3,
                #vmax=1.0, 
                square=True, 
                cmap=plt.cm.Blues,
                linecolor='white', 
                annot=True,
                cbar=False,
                xticklabels=dictLabels.values(), 
                yticklabels=dictLabels.values()
               );
    plt.xlabel('Observations', fontsize = 18);
    plt.ylabel('Prédictions', fontsize = 18);
    sauvegarderImage('afficheMatriceConfusion')

def executeApprentissageChoixClassifieurs(model,
                                          X_test,
                                          y_test,
                                          label_dict,
                                          couleurs,
                                          nom_essai = 'initial'
                                         ):
    
    def afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict):
        plt.figure(figsize=(24, 24));
        for i, color in zip(range(nbClasses), palette):
            plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
                     label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
                                                             ''.format(i, aucROCt[i]))
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('Taux de faux Positifs-(1 - Spécificité) = VN / (FP + VN)',size=18)
        plt.ylabel('Taux de vrais positifs-Sensibilité = VP / (VP + FN)',size=18)
        plt.title('Courbe ROC (Receiver Operating Caracteristic) -- ',size=20)
        plt.legend(loc="lower right"); #, fontsize='large'
        sauvegarderImage('Courbe ROC')
        
        plt.figure(figsize=(24,24));
    
        f_scores = np.linspace(0.2, 0.9, num=8)
        for f_score in f_scores:
            x = np.linspace(0.01, 1)
            y = f_score * x / (2 * x - f_score)
            l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
            plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
    
        for i, color in zip(range(nbClasses), palette):
            plt.step(sensibilites[i], 
                         precisions[i], 
                         where='post', 
                         color=color, 
                         lw=lw, 
                         label=f"{label_dict[i]}(APR = {avgPrecRec[label_dict[i]]:0.8f})"
                    )
            plt.fill_between(sensibilites[i], precisions[i], step='post', alpha=0.05)            
    
            # plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
            #          label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
            #                                                  ''.format(i, aucROCt[i]))        
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])        
        plt.xlabel('Sensibilité/Rappel(Recall) = VP / (VP + FN)',size=18)
        plt.ylabel('Précision = VP / (VP + FP)',size=18)        
        plt.title('Courbe Précision-Rappel',size=20)
        plt.legend(loc="lower right") # , fontsize = 'large'
        sauvegarderImage('Courbe Précision-Rappel')
    
    cvF1, cvF1SD, cvAccuracy, cvAccSD, aucROC, avgPrecRec, accuracy, balanced_accuracy, logloss, hammingloss, precision, sensibilite, \
    f1, f2, f05, jaccard, vrais_negatifs, faux_positifs, faux_negatifs, vrais_positifs, total_positifs, aucROCtn = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(),\
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    #
    oneloss, precision_micro, precision_macro, precision_weighted, \
    sensibilite_macro, sensibilite_micro, sensibilite_weighted, \
    f1_micro, f1_macro, f1_weighted,f2_micro,f2_macro,f2_weighted,f05_micro,f05_macro,f05_weighted = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    
    fauxPositifs, vraisPositifs, precisions, sensibilites, aucROCt, pr_auc, tauxROC, tauxPR = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()        
    
    
    lw = 1
    # couleurs    = sns.hls_palette(len(classifieursDict.keys()), l=.4, s=.9)
    nbClasses   = len(dictLabels.keys())
    listClasses = list(dictLabels.keys())
    
    y_testA  = label_binarize(y_test, classes=listClasses)
    plt.figure(figsize=(18,18))
    
    
    t1 = time.time()  
    classifier = model
    
    # y_score     = model.predict_proba(X_test)
    # y_pred      = model.predict(X_test)
    y_score     = model.predict(X_test)
    y_pred      = np.argmax(y_score, axis=-1) 
    y_predA     = label_binarize(y_pred, classes=listClasses)
    
    accuracy['global']              = accuracy_score(y_test, y_pred)
    balanced_accuracy['global']     = balanced_accuracy_score(y_test, y_pred)
    precision['global']             = precision_score(y_test, y_pred, average='weighted')
    sensibilite['global']           = recall_score(y_test, y_pred, average='weighted')
    
    f1['global']                    = f1_score(y_test, y_pred, average='weighted')
    f2['global']                    = fbeta_score(y_test, y_pred, beta=2, average='weighted')
    f05['global']                   = fbeta_score(y_test, y_pred, beta=0.5, average='weighted')
    
    vrais_negatifs['global']        = 0
    faux_positifs ['global']        = 0
    faux_negatifs ['global']        = 0
    vrais_positifs['global']        = 0
    total_positifs['global']        = 0
    
    
    aucROC['global'] = roc_auc_score(y_test, y_score, multi_class='ovr')
    
    for i in range(nbClasses):
        fauxPositifs[i], vraisPositifs[i], tauxROC[i] = roc_curve(y_testA[:, i], y_score[:, i])
        aucROCt[i]                                    = auc(fauxPositifs[i], vraisPositifs[i])
        precisions[i], sensibilites[i], tauxPR[i]     = precision_recall_curve(y_testA[:, i], y_score[:, i])
    
        aucROC[label_dict[i]]                = aucROCt[i]
        avgPrecRec[label_dict[i]]            = average_precision_score(y_testA[:, i], y_score[:, i])
        accuracy[label_dict[i]]              = accuracy_score(y_testA[:, i], y_predA[:, i])
        balanced_accuracy[label_dict[i]]     = balanced_accuracy_score(y_testA[:, i],y_predA[:, i])
        logloss[label_dict[i]]               = log_loss(y_testA[:, i], y_predA[:, i])
        hammingloss[label_dict[i]]           = hamming_loss(y_testA[:, i], y_predA[:, i])
        precision[label_dict[i]]             = precision_score(y_testA[:, i], y_predA[:, i])
        sensibilite[label_dict[i]]           = recall_score(y_testA[:, i], y_predA[:, i])
        f1[label_dict[i]]                    = f1_score(y_testA[:, i], y_predA[:, i])
        f2[label_dict[i]]                    = fbeta_score(y_testA[:, i], y_predA[:, i], beta=2)
        f05[label_dict[i]]                   = fbeta_score(y_testA[:, i], y_predA[:, i], beta=0.5)
      
        jaccard[label_dict[i]]               = jaccard_score(y_testA[:, i], y_predA[:, i])
        vrais_negatifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 0]
        faux_positifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 1]
        faux_negatifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 0]
        vrais_positifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 1]
        total_positifs[label_dict[i]]        = vrais_positifs[label_dict[i]] + faux_negatifs [label_dict[i]]
        vrais_negatifs['global']              += vrais_negatifs[label_dict[i]]
        faux_positifs ['global']              += faux_positifs [label_dict[i]]
        faux_negatifs ['global']              += faux_negatifs [label_dict[i]]
        vrais_positifs['global']              += vrais_positifs[label_dict[i]]
    
    
    total_positifs['global'] = vrais_positifs['global'] + faux_negatifs ['global']
    
    
    fauxPositifs["micro"], vraisPositifs["micro"], _ = roc_curve(y_testA.ravel(), y_score.ravel())
    aucROCt["micro"]                                 = auc(fauxPositifs["micro"], vraisPositifs["micro"])
    
    listFauxPositifs = np.unique(np.concatenate([fauxPositifs[i] for i in range(nbClasses)]))
    moyenneVraisPositifs = np.zeros_like(listFauxPositifs)
    for i in range(nbClasses):
        moyenneVraisPositifs += np.interp(listFauxPositifs, fauxPositifs[i], vraisPositifs[i])
    
    moyenneVraisPositifs /= nbClasses
    
    fauxPositifs["macro"], vraisPositifs["macro"] = listFauxPositifs, moyenneVraisPositifs
    aucROCt["macro"] = auc(fauxPositifs["macro"], vraisPositifs["macro"])
    # aucROC['global'] = aucROCt["macro"]  # (aucROCt["micro"],aucROCt["macro"])
    
    avgPrecRec['global'] = average_precision_score(y_testA.ravel(), y_score.ravel(), average='weighted')
    
    afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict);
    
    print ("Area under the ROC curve : %0.4f" % aucROC['global'],end='\t--\t')
    print('Exécution  :'+('%.2fs' % (time.time() - t1)).lstrip('0'))
        
    resultats = pd.DataFrame(pd.Series(aucROC), columns=["aucROC"])
    resultats["avgPrecRec"]              = pd.Series(avgPrecRec)
    resultats["f1"]                      = pd.Series(f1)
    resultats["f2"]                      = pd.Series(f2)
    resultats["f05"]                     = pd.Series(f05)
    resultats["accuracy"]                = pd.Series(accuracy)
    
    resultats["precision"]               = pd.Series(precision)
    resultats["sensibilite"]             = pd.Series(sensibilite)
    resultats["vrais_positifs"]          = pd.Series(vrais_positifs)
    resultats["vrais_negatifs"]          = pd.Series(vrais_negatifs)
    resultats["faux_positifs"]           = pd.Series(faux_positifs)
    resultats["faux_negatifs"]           = pd.Series(faux_negatifs)
    resultats["total_positifs"]          = pd.Series(total_positifs)
    
    resultats.reset_index(inplace=True)
    resultats.rename(columns={"index": "Classe"}, inplace=True)
    resultats['essai'] = nom_essai
    return resultats

def afficheProbabilites(probabilities, ind, ax, dictLabels):
    prediction = pd.DataFrame(probabilities).iloc[ind,:].reset_index()
    prediction.columns = ['Classe','Probabilite']
    prediction.Classe = prediction.Classe.apply(lambda x : f'{x:02d}-{dictLabels[x]}')
    
    graph = sns.barplot(
                        x='Classe',
                        y='Probabilite',
                        data=prediction.sort_values('Probabilite',ascending=False),
                        palette=palette[1:],
                        ax=ax        
                        );
    graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
    
    for i, patche in enumerate(graph.patches):
        if patche.get_height() > 0 :
            graph.text(
                        patche.get_x()+0.4,
                        0.4, #2*patche.get_height()/3,
                        f'{patche.get_height()*100:0.4f}%',
                        color='black',
                        rotation='vertical',
                        # size='large',
                        fontsize='large',
                        bbox=dict(boxstyle='round', facecolor='white', alpha=0.6),
                        verticalalignment='center',
                        horizontalalignment='center',
                       )       
    sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Paramétrés de l’exécution</div></b>

# %%
random_seed=123456
canaux=3 
image_size=(96, 96, 3)
image_height=image_size[0]
image_width=image_size[1]

batch_size = 16
epochs=200
dictLabels = {
                0   : 'Abricot',
                1   : 'Ananas',
                2   : 'Avocat',
                3   : 'Banane',
                4   : 'Cerise',
                5   : 'Citron',
                6   : 'Clémentine',
                7   : 'Fraise',
                8   : 'Framboise',
                9   : 'Kiwi',
                10  : 'Maïs',
                11  : 'Mangue',
                12  : 'Myrtille',
                13  : 'Oignon',
                14  : 'Orange',
                15  : 'Papaye',
                16  : 'Pastèque',
                17  : 'Pêche',
                18  : 'Poire',
                19  : 'Poivron',
                20  : 'Pomme',
                21  : 'Pomme de terre',
                22  : 'Prune',
                23  : 'Tomate'            }

number_of_classes=len(dictLabels.keys())


repertoireDonneesTFRec = '../donnees/tfRecords'

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Lecture des fichiers TFRecors</div></b>

# %%
redimensionnement_normalisation = tf.keras.models.Sequential(
    [
        tf.keras.layers.Resizing(height=image_size[0], width=image_size[1]),
        tf.keras.layers.Rescaling(scale=1./255.),
    ],
    name="redimensionnement_normalisation",
)

def _traitementImage(image):
    # image = tf.cast(tf.image.decode_jpeg(image, channels=canaux), tf.int32)
    # image = tf.cast(redimensionnement_normalisation(tf.image.decode_jpeg(image, channels=canaux)), tf.int32)
    image = redimensionnement_normalisation(tf.image.decode_jpeg(image, channels=canaux))
    return image

def _lectureTFRecord(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    enregistrement['image'] =  _traitementImage(enregistrement['image'])
    return enregistrement

def _dictToImageLabel(enregistrement):
    # return enregistrement['image'],tf.one_hot(enregistrement['label'], number_of_classes)
    return enregistrement['image'],enregistrement['label']

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(factor=(-0.2, 0.3)),
  # tf.keras.layers.RandomContrast(factor=(0.2, 0.95)),  
  # tf.keras.layers.RandomBrightness(factor=(-0.4, 0.4)),  
  # tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.3),width_factor=(-0.2, -0.3)),  
])

def _lectureTFRecordAugmentation(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    # enregistrement['image'] = tf.cast(data_augmentation(_traitementImage(enregistrement['image'])), tf.int32) 
    enregistrement['image'] = data_augmentation(_traitementImage(enregistrement['image']))
    return enregistrement

# %% [raw]
# def controleFichiersTfRecords(nom,dictLabels):
#
#     pipeline_train = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,f'{nom}-apprentissage.tfrecords'))
#     # pipeline_train = pipeline_train.map(_lectureTFRecord)
#     pipeline_train = pipeline_train.map(_lectureTFRecordAugmentation)
#     pipeline_train = pipeline_train.map(_dictToImageLabel)
#     pipeline_train = pipeline_train.batch(25)
#     pipeline_train = pipeline_train.prefetch(tf.data.AUTOTUNE)
#
#     image_batch, label_batch = next(iter(pipeline_train))
#
#     plt.figure(figsize=(24, 24))
#     for n in range(25):
#         ax = plt.subplot(5, 5, n + 1)
#         plt.imshow(image_batch[n])
#         plt.title(dictLabels[np.argmax(label_batch[n].numpy(), axis=-1)])
#         plt.axis("off")

# %% [raw]
# controleFichiersTfRecords('bloodmnist',dictLabels)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des flux de lecture des fichiers TFRecors</div></b>

# %%
pipeline_apprentissage = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'fruits-apprentissage.tfrecords'))
pipeline_apprentissage = pipeline_apprentissage.shuffle(batch_size).repeat(4)
pipeline_apprentissage = pipeline_apprentissage.map(_lectureTFRecordAugmentation)
pipeline_apprentissage = pipeline_apprentissage.map(_dictToImageLabel)
pipeline_apprentissage = pipeline_apprentissage.batch(batch_size)
pipeline_apprentissage = pipeline_apprentissage.prefetch(tf.data.AUTOTUNE)  

pipeline_validation = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'fruits-validation.tfrecords'))
pipeline_apprentissage = pipeline_apprentissage.shuffle(batch_size)
pipeline_validation = pipeline_validation.map(_lectureTFRecord)
pipeline_validation = pipeline_validation.map(_dictToImageLabel)
pipeline_validation = pipeline_validation.batch(batch_size)
pipeline_validation = pipeline_validation.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
pretrained_model = tf.keras.applications.VGG19(weights='imagenet', include_top=False)
inputs = tf.keras.Input(shape=image_size)
x = pretrained_model(inputs)    
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputs = tf.keras.layers.Dense(len(dictLabels.keys()), activation='softmax', name='chaussures_prob')(x)

for layer in pretrained_model.layers:  layer.trainable = False

model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 3, 3, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ chaussures_prob (Dense)         │ (None, 24)             │        12,312 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,036,696 (76.43 MB)
#  Trainable params: 12,312 (48.09 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Compilation du modèle </div></b>

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-03), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>
#
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
initial_lrate = 0.0001

max_lrate = 0.0009
min_lrate = 0.00001

epochs_runup_lrate = 3 
epochs_sustain_lrate = 8

drop_lrate = 0.95
epochs_drop = epochs * 0.1

# learning rate scheduler
def step_decay(epoch):
    if epoch < epochs_runup_lrate:
        lrate = (max_lrate - initial_lrate) / epochs_runup_lrate * epoch + initial_lrate
    elif epoch < epochs_runup_lrate + epochs_sustain_lrate:
        lrate = max_lrate
    else:
        lrate = (max_lrate - min_lrate) * drop_lrate**(epoch - epochs_runup_lrate - epochs_sustain_lrate) + min_lrate
    return lrate

learningRate = tf.keras.callbacks.LearningRateScheduler(step_decay)

rng = [i for i in range(epochs)]
y = [step_decay(x) for x in rng]
plt.plot(rng, y)
print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.0001 à 1.01e-05

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels de sauvegarde automatique du modèle </div></b>

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde chaque étape </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic1-epoch-{epoch:04d}.keras')
checkpointTimer1  = tf.keras.callbacks.ModelCheckpoint(filename,save_freq='epoch')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde tous les 5 étapes </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic5-epoch-{epoch:04d}.keras')
checkpointTimer5 = tf.keras.callbacks.ModelCheckpoint(filename,save_freq=5)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_loss minim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVLoss-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')

checkpointLoss = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                    monitor = 'val_loss',
                                                    verbose = 1, 
                                                    save_best_only = True, 
                                                    mode = 'min')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_accuracy maxim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVAccuracy-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
checkpointAccuracy = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                           monitor = 'val_accuracy', 
                                                           verbose = 1, 
                                                           save_best_only = True, 
                                                           mode = 'max')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Arrêt de l'apprentissage</div></b>

# %%
arretPrecoce = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels utilisés</div></b>

# %%
callbacks = [
    learningRate,
    # checkpointTimer1,
    # checkpointTimer5,
    checkpointLoss,
    # checkpointAccuracy,
    arretPrecoce
]

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle</div></b>

# %%
model_history = model.fit(pipeline_apprentissage, 
                    validation_data=pipeline_validation, 
                    epochs=epochs, 
                    batch_size=batch_size,
                    callbacks=callbacks,
                    verbose=2
                   )
# Out:
# Epoch 1/200
# I0000 00:00:1751919960.351529 2620003 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 1.93573, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0001-val_loss-1.936-val_accuracy-0.589.keras
# 3041/3041 - 97s - 32ms/step - accuracy: 0.3774 - loss: 2.3825 - val_accuracy: 0.5892 - val_loss: 1.9357 - learning_rate: 1.0000e-04
# Epoch 2/200
#
# Epoch 2: val_loss improved from 1.93573 to 0.96831, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0002-val_loss-0.968-val_accuracy-0.830.keras
# 3041/3041 - 84s - 28ms/step - accuracy: 0.7715 - loss: 1.2258 - val_accuracy: 0.8298 - val_loss: 0.9683 - learning_rate: 3.6667e-04
# Epoch 3/200
#
# Epoch 3: val_loss improved from 0.96831 to 0.57604, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0003-val_loss-0.576-val_accuracy-0.886.keras
# 3041/3041 - 82s - 27ms/step - accuracy: 0.8895 - loss: 0.6471 - val_accuracy: 0.8860 - val_loss: 0.5760 - learning_rate: 6.3333e-04
# Epoch 4/200
#
# Epoch 4: val_loss improved from 0.57604 to 0.38410, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0004-val_loss-0.384-val_accuracy-0.928.keras
# 3041/3041 - 85s - 28ms/step - accuracy: 0.9291 - loss: 0.3937 - val_accuracy: 0.9282 - val_loss: 0.3841 - learning_rate: 9.0000e-04
# Epoch 5/200
#
# Epoch 5: val_loss improved from 0.38410 to 0.28981, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0005-val_loss-0.290-val_accuracy-0.943.keras
# 3041/3041 - 86s - 28ms/step - accuracy: 0.9507 - loss: 0.2695 - val_accuracy: 0.9430 - val_loss: 0.2898 - learning_rate: 9.0000e-04
# Epoch 6/200
#
# Epoch 6: val_loss improved from 0.28981 to 0.23252, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0006-val_loss-0.233-val_accuracy-0.959.keras
# 3041/3041 - 72s - 24ms/step - accuracy: 0.9637 - loss: 0.2038 - val_accuracy: 0.9585 - val_loss: 0.2325 - learning_rate: 9.0000e-04
# Epoch 7/200
#
# Epoch 7: val_loss improved from 0.23252 to 0.19497, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0007-val_loss-0.195-val_accuracy-0.965.keras
# 3041/3041 - 64s - 21ms/step - accuracy: 0.9704 - loss: 0.1671 - val_accuracy: 0.9652 - val_loss: 0.1950 - learning_rate: 9.0000e-04
# Epoch 8/200
#
# Epoch 8: val_loss improved from 0.19497 to 0.16786, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0008-val_loss-0.168-val_accuracy-0.974.keras
# 3041/3041 - 37s - 12ms/step - accuracy: 0.9757 - loss: 0.1404 - val_accuracy: 0.9741 - val_loss: 0.1679 - learning_rate: 9.0000e-04
# Epoch 9/200
#
# Epoch 9: val_loss improved from 0.16786 to 0.14377, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0009-val_loss-0.144-val_accuracy-0.981.keras
# 3041/3041 - 68s - 22ms/step - accuracy: 0.9792 - loss: 0.1203 - val_accuracy: 0.9808 - val_loss: 0.1438 - learning_rate: 9.0000e-04
# Epoch 10/200
#
# Epoch 10: val_loss improved from 0.14377 to 0.13062, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0010-val_loss-0.131-val_accuracy-0.981.keras
# 3041/3041 - 41s - 13ms/step - accuracy: 0.9819 - loss: 0.1054 - val_accuracy: 0.9808 - val_loss: 0.1306 - learning_rate: 9.0000e-04
# Epoch 11/200
#
# Epoch 11: val_loss improved from 0.13062 to 0.11767, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0011-val_loss-0.118-val_accuracy-0.987.keras
# 3041/3041 - 70s - 23ms/step - accuracy: 0.9832 - loss: 0.0951 - val_accuracy: 0.9874 - val_loss: 0.1177 - learning_rate: 9.0000e-04
# Epoch 12/200
#
# Epoch 12: val_loss improved from 0.11767 to 0.10783, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0012-val_loss-0.108-val_accuracy-0.987.keras
# 3041/3041 - 74s - 24ms/step - accuracy: 0.9851 - loss: 0.0865 - val_accuracy: 0.9867 - val_loss: 0.1078 - learning_rate: 9.0000e-04
# Epoch 13/200
#
# Epoch 13: val_loss improved from 0.10783 to 0.10117, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0013-val_loss-0.101-val_accuracy-0.984.keras
# 3041/3041 - 75s - 25ms/step - accuracy: 0.9865 - loss: 0.0774 - val_accuracy: 0.9845 - val_loss: 0.1012 - learning_rate: 8.5550e-04
# Epoch 14/200
#
# Epoch 14: val_loss improved from 0.10117 to 0.09066, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0014-val_loss-0.091-val_accuracy-0.987.keras
# 3041/3041 - 72s - 24ms/step - accuracy: 0.9874 - loss: 0.0729 - val_accuracy: 0.9874 - val_loss: 0.0907 - learning_rate: 8.1322e-04
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.09066 to 0.08288, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0015-val_loss-0.083-val_accuracy-0.990.keras
# 3041/3041 - 64s - 21ms/step - accuracy: 0.9889 - loss: 0.0662 - val_accuracy: 0.9896 - val_loss: 0.0829 - learning_rate: 7.7306e-04
# Epoch 16/200
#
# Epoch 16: val_loss improved from 0.08288 to 0.07882, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0016-val_loss-0.079-val_accuracy-0.991.keras
# 3041/3041 - 80s - 26ms/step - accuracy: 0.9910 - loss: 0.0611 - val_accuracy: 0.9911 - val_loss: 0.0788 - learning_rate: 7.3491e-04
# Epoch 17/200
#
# Epoch 17: val_loss improved from 0.07882 to 0.07436, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0017-val_loss-0.074-val_accuracy-0.992.keras
# 3041/3041 - 57s - 19ms/step - accuracy: 0.9902 - loss: 0.0584 - val_accuracy: 0.9919 - val_loss: 0.0744 - learning_rate: 6.9867e-04
# Epoch 18/200
#
# Epoch 18: val_loss improved from 0.07436 to 0.07115, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0018-val_loss-0.071-val_accuracy-0.991.keras
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9908 - loss: 0.0560 - val_accuracy: 0.9911 - val_loss: 0.0711 - learning_rate: 6.6423e-04
# Epoch 19/200
#
# Epoch 19: val_loss improved from 0.07115 to 0.06963, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0019-val_loss-0.070-val_accuracy-0.990.keras
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9913 - loss: 0.0531 - val_accuracy: 0.9904 - val_loss: 0.0696 - learning_rate: 6.3152e-04
# Epoch 20/200
#
# Epoch 20: val_loss improved from 0.06963 to 0.06552, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0020-val_loss-0.066-val_accuracy-0.990.keras
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9923 - loss: 0.0506 - val_accuracy: 0.9896 - val_loss: 0.0655 - learning_rate: 6.0044e-04
# Epoch 21/200
#
# Epoch 21: val_loss improved from 0.06552 to 0.06468, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0021-val_loss-0.065-val_accuracy-0.992.keras
# 3041/3041 - 77s - 25ms/step - accuracy: 0.9923 - loss: 0.0486 - val_accuracy: 0.9919 - val_loss: 0.0647 - learning_rate: 5.7092e-04
# Epoch 22/200
#
# Epoch 22: val_loss improved from 0.06468 to 0.06073, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0022-val_loss-0.061-val_accuracy-0.992.keras
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9922 - loss: 0.0468 - val_accuracy: 0.9919 - val_loss: 0.0607 - learning_rate: 5.4288e-04
# Epoch 23/200
#
# Epoch 23: val_loss improved from 0.06073 to 0.05650, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0023-val_loss-0.057-val_accuracy-0.992.keras
# 3041/3041 - 87s - 29ms/step - accuracy: 0.9926 - loss: 0.0456 - val_accuracy: 0.9919 - val_loss: 0.0565 - learning_rate: 5.1623e-04
# Epoch 24/200
#
# Epoch 24: val_loss improved from 0.05650 to 0.05622, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0024-val_loss-0.056-val_accuracy-0.994.keras
# 3041/3041 - 78s - 26ms/step - accuracy: 0.9930 - loss: 0.0439 - val_accuracy: 0.9941 - val_loss: 0.0562 - learning_rate: 4.9092e-04
# Epoch 25/200
#
# Epoch 25: val_loss improved from 0.05622 to 0.05530, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0025-val_loss-0.055-val_accuracy-0.992.keras
# 3041/3041 - 75s - 25ms/step - accuracy: 0.9932 - loss: 0.0430 - val_accuracy: 0.9919 - val_loss: 0.0553 - learning_rate: 4.6687e-04
# Epoch 26/200
#
# Epoch 26: val_loss improved from 0.05530 to 0.05384, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0026-val_loss-0.054-val_accuracy-0.993.keras
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9940 - loss: 0.0414 - val_accuracy: 0.9933 - val_loss: 0.0538 - learning_rate: 4.4403e-04
# Epoch 27/200
#
# Epoch 27: val_loss improved from 0.05384 to 0.05224, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0027-val_loss-0.052-val_accuracy-0.994.keras
# 3041/3041 - 64s - 21ms/step - accuracy: 0.9944 - loss: 0.0400 - val_accuracy: 0.9941 - val_loss: 0.0522 - learning_rate: 4.2233e-04
# Epoch 28/200
#
# Epoch 28: val_loss did not improve from 0.05224
# 3041/3041 - 86s - 28ms/step - accuracy: 0.9938 - loss: 0.0398 - val_accuracy: 0.9941 - val_loss: 0.0526 - learning_rate: 4.0171e-04
# Epoch 29/200
#
# Epoch 29: val_loss improved from 0.05224 to 0.05045, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0029-val_loss-0.050-val_accuracy-0.993.keras
# 3041/3041 - 93s - 30ms/step - accuracy: 0.9939 - loss: 0.0388 - val_accuracy: 0.9926 - val_loss: 0.0505 - learning_rate: 3.8213e-04
# Epoch 30/200
#
# Epoch 30: val_loss improved from 0.05045 to 0.04856, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0030-val_loss-0.049-val_accuracy-0.995.keras
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9942 - loss: 0.0374 - val_accuracy: 0.9948 - val_loss: 0.0486 - learning_rate: 3.6352e-04
# Epoch 31/200
#
# Epoch 31: val_loss improved from 0.04856 to 0.04751, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0031-val_loss-0.048-val_accuracy-0.994.keras
# 3041/3041 - 92s - 30ms/step - accuracy: 0.9943 - loss: 0.0363 - val_accuracy: 0.9941 - val_loss: 0.0475 - learning_rate: 3.4584e-04
# Epoch 32/200
#
# Epoch 32: val_loss improved from 0.04751 to 0.04644, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0032-val_loss-0.046-val_accuracy-0.994.keras
# 3041/3041 - 56s - 18ms/step - accuracy: 0.9943 - loss: 0.0365 - val_accuracy: 0.9941 - val_loss: 0.0464 - learning_rate: 3.2905e-04
# Epoch 33/200
#
# Epoch 33: val_loss did not improve from 0.04644
# 3041/3041 - 44s - 14ms/step - accuracy: 0.9952 - loss: 0.0350 - val_accuracy: 0.9941 - val_loss: 0.0470 - learning_rate: 3.1310e-04
# Epoch 34/200
#
# Epoch 34: val_loss improved from 0.04644 to 0.04600, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0034-val_loss-0.046-val_accuracy-0.995.keras
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9946 - loss: 0.0354 - val_accuracy: 0.9948 - val_loss: 0.0460 - learning_rate: 2.9794e-04
# Epoch 35/200
#
# Epoch 35: val_loss improved from 0.04600 to 0.04418, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0035-val_loss-0.044-val_accuracy-0.995.keras
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9952 - loss: 0.0342 - val_accuracy: 0.9948 - val_loss: 0.0442 - learning_rate: 2.8355e-04
# Epoch 36/200
#
# Epoch 36: val_loss did not improve from 0.04418
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9951 - loss: 0.0339 - val_accuracy: 0.9963 - val_loss: 0.0444 - learning_rate: 2.6987e-04
# Epoch 37/200
#
# Epoch 37: val_loss improved from 0.04418 to 0.04413, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0037-val_loss-0.044-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9953 - loss: 0.0332 - val_accuracy: 0.9956 - val_loss: 0.0441 - learning_rate: 2.5688e-04
# Epoch 38/200
#
# Epoch 38: val_loss improved from 0.04413 to 0.04255, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0038-val_loss-0.043-val_accuracy-0.996.keras
# 3041/3041 - 98s - 32ms/step - accuracy: 0.9945 - loss: 0.0335 - val_accuracy: 0.9956 - val_loss: 0.0426 - learning_rate: 2.4453e-04
# Epoch 39/200
#
# Epoch 39: val_loss did not improve from 0.04255
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9952 - loss: 0.0324 - val_accuracy: 0.9956 - val_loss: 0.0433 - learning_rate: 2.3281e-04
# Epoch 40/200
#
# Epoch 40: val_loss improved from 0.04255 to 0.04065, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0040-val_loss-0.041-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9949 - loss: 0.0326 - val_accuracy: 0.9963 - val_loss: 0.0407 - learning_rate: 2.2167e-04
# Epoch 41/200
#
# Epoch 41: val_loss did not improve from 0.04065
# 3041/3041 - 101s - 33ms/step - accuracy: 0.9957 - loss: 0.0315 - val_accuracy: 0.9956 - val_loss: 0.0413 - learning_rate: 2.1108e-04
# Epoch 42/200
#
# Epoch 42: val_loss did not improve from 0.04065
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9958 - loss: 0.0315 - val_accuracy: 0.9956 - val_loss: 0.0413 - learning_rate: 2.0103e-04
# Epoch 43/200
#
# Epoch 43: val_loss improved from 0.04065 to 0.04018, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0043-val_loss-0.040-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9955 - loss: 0.0316 - val_accuracy: 0.9956 - val_loss: 0.0402 - learning_rate: 1.9148e-04
# Epoch 44/200
#
# Epoch 44: val_loss did not improve from 0.04018
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9957 - loss: 0.0306 - val_accuracy: 0.9956 - val_loss: 0.0403 - learning_rate: 1.8240e-04
# Epoch 45/200
#
# Epoch 45: val_loss improved from 0.04018 to 0.03989, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0045-val_loss-0.040-val_accuracy-0.996.keras
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9956 - loss: 0.0304 - val_accuracy: 0.9956 - val_loss: 0.0399 - learning_rate: 1.7378e-04
# Epoch 46/200
#
# Epoch 46: val_loss did not improve from 0.03989
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9958 - loss: 0.0295 - val_accuracy: 0.9956 - val_loss: 0.0401 - learning_rate: 1.6559e-04
# Epoch 47/200
#
# Epoch 47: val_loss improved from 0.03989 to 0.03888, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0047-val_loss-0.039-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9949 - loss: 0.0309 - val_accuracy: 0.9956 - val_loss: 0.0389 - learning_rate: 1.5781e-04
# Epoch 48/200
#
# Epoch 48: val_loss improved from 0.03888 to 0.03860, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0048-val_loss-0.039-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9956 - loss: 0.0301 - val_accuracy: 0.9956 - val_loss: 0.0386 - learning_rate: 1.5042e-04
# Epoch 49/200
#
# Epoch 49: val_loss improved from 0.03860 to 0.03859, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0049-val_loss-0.039-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9957 - loss: 0.0301 - val_accuracy: 0.9963 - val_loss: 0.0386 - learning_rate: 1.4340e-04
# Epoch 50/200
#
# Epoch 50: val_loss improved from 0.03859 to 0.03852, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0050-val_loss-0.039-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9955 - loss: 0.0296 - val_accuracy: 0.9956 - val_loss: 0.0385 - learning_rate: 1.3673e-04
# Epoch 51/200
#
# Epoch 51: val_loss improved from 0.03852 to 0.03811, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0051-val_loss-0.038-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9957 - loss: 0.0296 - val_accuracy: 0.9963 - val_loss: 0.0381 - learning_rate: 1.3040e-04
# Epoch 52/200
#
# Epoch 52: val_loss did not improve from 0.03811
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9953 - loss: 0.0303 - val_accuracy: 0.9963 - val_loss: 0.0385 - learning_rate: 1.2438e-04
# Epoch 53/200
#
# Epoch 53: val_loss improved from 0.03811 to 0.03761, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0053-val_loss-0.038-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9963 - loss: 0.0290 - val_accuracy: 0.9956 - val_loss: 0.0376 - learning_rate: 1.1866e-04
# Epoch 54/200
#
# Epoch 54: val_loss improved from 0.03761 to 0.03724, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0054-val_loss-0.037-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9957 - loss: 0.0291 - val_accuracy: 0.9963 - val_loss: 0.0372 - learning_rate: 1.1322e-04
# Epoch 55/200
#
# Epoch 55: val_loss improved from 0.03724 to 0.03681, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0055-val_loss-0.037-val_accuracy-0.996.keras
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9960 - loss: 0.0285 - val_accuracy: 0.9963 - val_loss: 0.0368 - learning_rate: 1.0806e-04
# Epoch 56/200
#
# Epoch 56: val_loss did not improve from 0.03681
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9961 - loss: 0.0281 - val_accuracy: 0.9956 - val_loss: 0.0374 - learning_rate: 1.0316e-04
# Epoch 57/200
#
# Epoch 57: val_loss did not improve from 0.03681
# 3041/3041 - 80s - 26ms/step - accuracy: 0.9957 - loss: 0.0290 - val_accuracy: 0.9963 - val_loss: 0.0373 - learning_rate: 9.8502e-05
# Epoch 58/200
#
# Epoch 58: val_loss did not improve from 0.03681
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9957 - loss: 0.0287 - val_accuracy: 0.9963 - val_loss: 0.0370 - learning_rate: 9.4077e-05
# Epoch 59/200
#
# Epoch 59: val_loss improved from 0.03681 to 0.03662, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0059-val_loss-0.037-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9957 - loss: 0.0284 - val_accuracy: 0.9963 - val_loss: 0.0366 - learning_rate: 8.9873e-05
# Epoch 60/200
#
# Epoch 60: val_loss did not improve from 0.03662
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9957 - loss: 0.0280 - val_accuracy: 0.9963 - val_loss: 0.0368 - learning_rate: 8.5879e-05
# Epoch 61/200
#
# Epoch 61: val_loss improved from 0.03662 to 0.03633, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0061-val_loss-0.036-val_accuracy-0.997.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9961 - loss: 0.0278 - val_accuracy: 0.9970 - val_loss: 0.0363 - learning_rate: 8.2085e-05
# Epoch 62/200
#
# Epoch 62: val_loss improved from 0.03633 to 0.03598, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0062-val_loss-0.036-val_accuracy-0.996.keras
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9958 - loss: 0.0285 - val_accuracy: 0.9956 - val_loss: 0.0360 - learning_rate: 7.8481e-05
# Epoch 63/200
#
# Epoch 63: val_loss did not improve from 0.03598
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0280 - val_accuracy: 0.9963 - val_loss: 0.0362 - learning_rate: 7.5057e-05
# Epoch 64/200
#
# Epoch 64: val_loss improved from 0.03598 to 0.03568, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0064-val_loss-0.036-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9961 - loss: 0.0273 - val_accuracy: 0.9963 - val_loss: 0.0357 - learning_rate: 7.1804e-05
# Epoch 65/200
#
# Epoch 65: val_loss did not improve from 0.03568
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0273 - val_accuracy: 0.9963 - val_loss: 0.0361 - learning_rate: 6.8714e-05
# Epoch 66/200
#
# Epoch 66: val_loss did not improve from 0.03568
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9958 - loss: 0.0282 - val_accuracy: 0.9963 - val_loss: 0.0358 - learning_rate: 6.5778e-05
# Epoch 67/200
#
# Epoch 67: val_loss improved from 0.03568 to 0.03531, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0067-val_loss-0.035-val_accuracy-0.997.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0276 - val_accuracy: 0.9970 - val_loss: 0.0353 - learning_rate: 6.2989e-05
# Epoch 68/200
#
# Epoch 68: val_loss did not improve from 0.03531
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9961 - loss: 0.0269 - val_accuracy: 0.9963 - val_loss: 0.0355 - learning_rate: 6.0340e-05
# Epoch 69/200
#
# Epoch 69: val_loss did not improve from 0.03531
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9957 - loss: 0.0285 - val_accuracy: 0.9956 - val_loss: 0.0357 - learning_rate: 5.7823e-05
# Epoch 70/200
#
# Epoch 70: val_loss improved from 0.03531 to 0.03523, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0070-val_loss-0.035-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9961 - loss: 0.0275 - val_accuracy: 0.9963 - val_loss: 0.0352 - learning_rate: 5.5432e-05
# Epoch 71/200
#
# Epoch 71: val_loss improved from 0.03523 to 0.03516, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0071-val_loss-0.035-val_accuracy-0.997.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9966 - loss: 0.0265 - val_accuracy: 0.9970 - val_loss: 0.0352 - learning_rate: 5.3160e-05
# Epoch 72/200
#
# Epoch 72: val_loss did not improve from 0.03516
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9958 - loss: 0.0278 - val_accuracy: 0.9963 - val_loss: 0.0353 - learning_rate: 5.1002e-05
# Epoch 73/200
#
# Epoch 73: val_loss improved from 0.03516 to 0.03502, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0073-val_loss-0.035-val_accuracy-0.996.keras
# 3041/3041 - 101s - 33ms/step - accuracy: 0.9960 - loss: 0.0271 - val_accuracy: 0.9963 - val_loss: 0.0350 - learning_rate: 4.8952e-05
# Epoch 74/200
#
# Epoch 74: val_loss improved from 0.03502 to 0.03472, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0074-val_loss-0.035-val_accuracy-0.997.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9954 - loss: 0.0281 - val_accuracy: 0.9970 - val_loss: 0.0347 - learning_rate: 4.7004e-05
# Epoch 75/200
#
# Epoch 75: val_loss did not improve from 0.03472
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9961 - loss: 0.0270 - val_accuracy: 0.9970 - val_loss: 0.0349 - learning_rate: 4.5154e-05
# Epoch 76/200
#
# Epoch 76: val_loss did not improve from 0.03472
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9964 - loss: 0.0271 - val_accuracy: 0.9963 - val_loss: 0.0349 - learning_rate: 4.3396e-05
# Epoch 77/200
#
# Epoch 77: val_loss did not improve from 0.03472
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0266 - val_accuracy: 0.9963 - val_loss: 0.0352 - learning_rate: 4.1727e-05
# Epoch 78/200
#
# Epoch 78: val_loss did not improve from 0.03472
# 3041/3041 - 101s - 33ms/step - accuracy: 0.9962 - loss: 0.0264 - val_accuracy: 0.9963 - val_loss: 0.0348 - learning_rate: 4.0140e-05
# Epoch 79/200
#
# Epoch 79: val_loss did not improve from 0.03472
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9962 - loss: 0.0266 - val_accuracy: 0.9963 - val_loss: 0.0352 - learning_rate: 3.8633e-05
# Epoch 80/200
#
# Epoch 80: val_loss did not improve from 0.03472
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9965 - loss: 0.0267 - val_accuracy: 0.9963 - val_loss: 0.0347 - learning_rate: 3.7202e-05
# Epoch 81/200
#
# Epoch 81: val_loss did not improve from 0.03472
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9960 - loss: 0.0268 - val_accuracy: 0.9963 - val_loss: 0.0349 - learning_rate: 3.5842e-05
# Epoch 82/200
#
# Epoch 82: val_loss improved from 0.03472 to 0.03445, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0082-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0266 - val_accuracy: 0.9963 - val_loss: 0.0344 - learning_rate: 3.4549e-05
# Epoch 83/200
#
# Epoch 83: val_loss did not improve from 0.03445
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0264 - val_accuracy: 0.9963 - val_loss: 0.0345 - learning_rate: 3.3322e-05
# Epoch 84/200
#
# Epoch 84: val_loss improved from 0.03445 to 0.03416, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0084-val_loss-0.034-val_accuracy-0.997.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9966 - loss: 0.0265 - val_accuracy: 0.9970 - val_loss: 0.0342 - learning_rate: 3.2156e-05
# Epoch 85/200
#
# Epoch 85: val_loss did not improve from 0.03416
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9957 - loss: 0.0274 - val_accuracy: 0.9963 - val_loss: 0.0345 - learning_rate: 3.1048e-05
# Epoch 86/200
#
# Epoch 86: val_loss did not improve from 0.03416
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9959 - loss: 0.0266 - val_accuracy: 0.9970 - val_loss: 0.0343 - learning_rate: 2.9996e-05
# Epoch 87/200
#
# Epoch 87: val_loss did not improve from 0.03416
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9963 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0346 - learning_rate: 2.8996e-05
# Epoch 88/200
#
# Epoch 88: val_loss improved from 0.03416 to 0.03408, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0088-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0341 - learning_rate: 2.8046e-05
# Epoch 89/200
#
# Epoch 89: val_loss did not improve from 0.03408
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9960 - loss: 0.0267 - val_accuracy: 0.9963 - val_loss: 0.0342 - learning_rate: 2.7144e-05
# Epoch 90/200
#
# Epoch 90: val_loss did not improve from 0.03408
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9963 - loss: 0.0267 - val_accuracy: 0.9963 - val_loss: 0.0343 - learning_rate: 2.6287e-05
# Epoch 91/200
#
# Epoch 91: val_loss did not improve from 0.03408
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9961 - loss: 0.0266 - val_accuracy: 0.9963 - val_loss: 0.0341 - learning_rate: 2.5472e-05
# Epoch 92/200
#
# Epoch 92: val_loss improved from 0.03408 to 0.03400, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0092-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0340 - learning_rate: 2.4699e-05
# Epoch 93/200
#
# Epoch 93: val_loss did not improve from 0.03400
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9961 - loss: 0.0265 - val_accuracy: 0.9963 - val_loss: 0.0341 - learning_rate: 2.3964e-05
# Epoch 94/200
#
# Epoch 94: val_loss did not improve from 0.03400
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0342 - learning_rate: 2.3266e-05
# Epoch 95/200
#
# Epoch 95: val_loss did not improve from 0.03400
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0341 - learning_rate: 2.2602e-05
# Epoch 96/200
#
# Epoch 96: val_loss did not improve from 0.03400
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0267 - val_accuracy: 0.9963 - val_loss: 0.0341 - learning_rate: 2.1972e-05
# Epoch 97/200
#
# Epoch 97: val_loss improved from 0.03400 to 0.03393, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0097-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9961 - loss: 0.0265 - val_accuracy: 0.9963 - val_loss: 0.0339 - learning_rate: 2.1374e-05
# Epoch 98/200
#
# Epoch 98: val_loss improved from 0.03393 to 0.03390, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0098-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9964 - loss: 0.0265 - val_accuracy: 0.9963 - val_loss: 0.0339 - learning_rate: 2.0805e-05
# Epoch 99/200
#
# Epoch 99: val_loss did not improve from 0.03390
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9964 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0340 - learning_rate: 2.0265e-05
# Epoch 100/200
#
# Epoch 100: val_loss improved from 0.03390 to 0.03383, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0100-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9966 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0338 - learning_rate: 1.9751e-05
# Epoch 101/200
#
# Epoch 101: val_loss did not improve from 0.03383
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0339 - learning_rate: 1.9264e-05
# Epoch 102/200
#
# Epoch 102: val_loss did not improve from 0.03383
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9963 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0340 - learning_rate: 1.8801e-05
# Epoch 103/200
#
# Epoch 103: val_loss did not improve from 0.03383
# 3041/3041 - 84s - 27ms/step - accuracy: 0.9963 - loss: 0.0264 - val_accuracy: 0.9963 - val_loss: 0.0340 - learning_rate: 1.8361e-05
# Epoch 104/200
#
# Epoch 104: val_loss did not improve from 0.03383
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9966 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0339 - learning_rate: 1.7943e-05
# Epoch 105/200
#
# Epoch 105: val_loss improved from 0.03383 to 0.03382, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0105-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9964 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0338 - learning_rate: 1.7545e-05
# Epoch 106/200
#
# Epoch 106: val_loss improved from 0.03382 to 0.03382, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0106-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0338 - learning_rate: 1.7168e-05
# Epoch 107/200
#
# Epoch 107: val_loss improved from 0.03382 to 0.03367, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0107-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.6810e-05
# Epoch 108/200
#
# Epoch 108: val_loss did not improve from 0.03367
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9962 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0340 - learning_rate: 1.6469e-05
# Epoch 109/200
#
# Epoch 109: val_loss did not improve from 0.03367
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9967 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.6146e-05
# Epoch 110/200
#
# Epoch 110: val_loss did not improve from 0.03367
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9966 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0338 - learning_rate: 1.5839e-05
# Epoch 111/200
#
# Epoch 111: val_loss did not improve from 0.03367
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9959 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.5547e-05
# Epoch 112/200
#
# Epoch 112: val_loss did not improve from 0.03367
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9962 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.5269e-05
# Epoch 113/200
#
# Epoch 113: val_loss did not improve from 0.03367
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9962 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.5006e-05
# Epoch 114/200
#
# Epoch 114: val_loss improved from 0.03367 to 0.03365, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0114-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9968 - loss: 0.0254 - val_accuracy: 0.9963 - val_loss: 0.0336 - learning_rate: 1.4756e-05
# Epoch 115/200
#
# Epoch 115: val_loss did not improve from 0.03365
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.4518e-05
# Epoch 116/200
#
# Epoch 116: val_loss improved from 0.03365 to 0.03364, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0116-val_loss-0.034-val_accuracy-0.996.keras
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9964 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0336 - learning_rate: 1.4292e-05
# Epoch 117/200
#
# Epoch 117: val_loss improved from 0.03364 to 0.03337, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0117-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9963 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.4077e-05
# Epoch 118/200
#
# Epoch 118: val_loss did not improve from 0.03337
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9965 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0335 - learning_rate: 1.3873e-05
# Epoch 119/200
#
# Epoch 119: val_loss did not improve from 0.03337
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0336 - learning_rate: 1.3680e-05
# Epoch 120/200
#
# Epoch 120: val_loss did not improve from 0.03337
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9962 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0336 - learning_rate: 1.3496e-05
# Epoch 121/200
#
# Epoch 121: val_loss did not improve from 0.03337
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9965 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0335 - learning_rate: 1.3321e-05
# Epoch 122/200
#
# Epoch 122: val_loss did not improve from 0.03337
# 3041/3041 - 82s - 27ms/step - accuracy: 0.9966 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.3155e-05
# Epoch 123/200
#
# Epoch 123: val_loss improved from 0.03337 to 0.03336, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0123-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9962 - loss: 0.0266 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.2997e-05
# Epoch 124/200
#
# Epoch 124: val_loss did not improve from 0.03336
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9966 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.2847e-05
# Epoch 125/200
#
# Epoch 125: val_loss did not improve from 0.03336
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0336 - learning_rate: 1.2705e-05
# Epoch 126/200
#
# Epoch 126: val_loss did not improve from 0.03336
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9966 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.2570e-05
# Epoch 127/200
#
# Epoch 127: val_loss did not improve from 0.03336
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.2441e-05
# Epoch 128/200
#
# Epoch 128: val_loss did not improve from 0.03336
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9964 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.2319e-05
# Epoch 129/200
#
# Epoch 129: val_loss did not improve from 0.03336
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9966 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0334 - learning_rate: 1.2203e-05
# Epoch 130/200
#
# Epoch 130: val_loss improved from 0.03336 to 0.03334, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0130-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9961 - loss: 0.0265 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.2093e-05
# Epoch 131/200
#
# Epoch 131: val_loss improved from 0.03334 to 0.03322, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0131-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9960 - loss: 0.0264 - val_accuracy: 0.9963 - val_loss: 0.0332 - learning_rate: 1.1988e-05
# Epoch 132/200
#
# Epoch 132: val_loss did not improve from 0.03322
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9966 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0332 - learning_rate: 1.1889e-05
# Epoch 133/200
#
# Epoch 133: val_loss improved from 0.03322 to 0.03314, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0133-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9962 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.1795e-05
# Epoch 134/200
#
# Epoch 134: val_loss did not improve from 0.03314
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9963 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1705e-05
# Epoch 135/200
#
# Epoch 135: val_loss did not improve from 0.03314
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9965 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1620e-05
# Epoch 136/200
#
# Epoch 136: val_loss did not improve from 0.03314
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9961 - loss: 0.0260 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1539e-05
# Epoch 137/200
#
# Epoch 137: val_loss did not improve from 0.03314
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0260 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.1462e-05
# Epoch 138/200
#
# Epoch 138: val_loss did not improve from 0.03314
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9964 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1389e-05
# Epoch 139/200
#
# Epoch 139: val_loss did not improve from 0.03314
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9962 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1319e-05
# Epoch 140/200
#
# Epoch 140: val_loss did not improve from 0.03314
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9965 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1253e-05
# Epoch 141/200
#
# Epoch 141: val_loss improved from 0.03314 to 0.03313, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0141-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9964 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.1191e-05
# Epoch 142/200
#
# Epoch 142: val_loss did not improve from 0.03313
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9966 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.1131e-05
# Epoch 143/200
#
# Epoch 143: val_loss did not improve from 0.03313
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9963 - loss: 0.0260 - val_accuracy: 0.9963 - val_loss: 0.0332 - learning_rate: 1.1074e-05
# Epoch 144/200
#
# Epoch 144: val_loss improved from 0.03313 to 0.03312, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0144-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9966 - loss: 0.0253 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.1021e-05
# Epoch 145/200
#
# Epoch 145: val_loss did not improve from 0.03312
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9959 - loss: 0.0262 - val_accuracy: 0.9963 - val_loss: 0.0332 - learning_rate: 1.0970e-05
# Epoch 146/200
#
# Epoch 146: val_loss did not improve from 0.03312
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.0921e-05
# Epoch 147/200
#
# Epoch 147: val_loss did not improve from 0.03312
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9967 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.0875e-05
# Epoch 148/200
#
# Epoch 148: val_loss did not improve from 0.03312
# 3041/3041 - 82s - 27ms/step - accuracy: 0.9962 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0332 - learning_rate: 1.0831e-05
# Epoch 149/200
#
# Epoch 149: val_loss improved from 0.03312 to 0.03309, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0149-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 102s - 33ms/step - accuracy: 0.9966 - loss: 0.0252 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.0790e-05
# Epoch 150/200
#
# Epoch 150: val_loss did not improve from 0.03309
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9966 - loss: 0.0252 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.0750e-05
# Epoch 151/200
#
# Epoch 151: val_loss did not improve from 0.03309
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9962 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.0713e-05
# Epoch 152/200
#
# Epoch 152: val_loss did not improve from 0.03309
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9968 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0333 - learning_rate: 1.0677e-05
# Epoch 153/200
#
# Epoch 153: val_loss did not improve from 0.03309
# 3041/3041 - 84s - 27ms/step - accuracy: 0.9964 - loss: 0.0254 - val_accuracy: 0.9963 - val_loss: 0.0331 - learning_rate: 1.0643e-05
# Epoch 154/200
#
# Epoch 154: val_loss improved from 0.03309 to 0.03294, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0154-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9964 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0611e-05
# Epoch 155/200
#
# Epoch 155: val_loss improved from 0.03294 to 0.03287, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0155-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9964 - loss: 0.0252 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0581e-05
# Epoch 156/200
#
# Epoch 156: val_loss did not improve from 0.03287
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9964 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0552e-05
# Epoch 157/200
#
# Epoch 157: val_loss did not improve from 0.03287
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9965 - loss: 0.0254 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0524e-05
# Epoch 158/200
#
# Epoch 158: val_loss improved from 0.03287 to 0.03277, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0158-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9961 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0328 - learning_rate: 1.0498e-05
# Epoch 159/200
#
# Epoch 159: val_loss improved from 0.03277 to 0.03274, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0159-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 106s - 35ms/step - accuracy: 0.9966 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0473e-05
# Epoch 160/200
#
# Epoch 160: val_loss did not improve from 0.03274
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0449e-05
# Epoch 161/200
#
# Epoch 161: val_loss did not improve from 0.03274
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9960 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0328 - learning_rate: 1.0427e-05
# Epoch 162/200
#
# Epoch 162: val_loss did not improve from 0.03274
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9967 - loss: 0.0248 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0405e-05
# Epoch 163/200
#
# Epoch 163: val_loss did not improve from 0.03274
# 3041/3041 - 106s - 35ms/step - accuracy: 0.9962 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0385e-05
# Epoch 164/200
#
# Epoch 164: val_loss did not improve from 0.03274
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9962 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0328 - learning_rate: 1.0366e-05
# Epoch 165/200
#
# Epoch 165: val_loss did not improve from 0.03274
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9963 - loss: 0.0263 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0348e-05
# Epoch 166/200
#
# Epoch 166: val_loss did not improve from 0.03274
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9967 - loss: 0.0248 - val_accuracy: 0.9963 - val_loss: 0.0329 - learning_rate: 1.0330e-05
# Epoch 167/200
#
# Epoch 167: val_loss did not improve from 0.03274
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9963 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0328 - learning_rate: 1.0314e-05
# Epoch 168/200
#
# Epoch 168: val_loss improved from 0.03274 to 0.03272, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0168-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 84s - 28ms/step - accuracy: 0.9966 - loss: 0.0251 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0298e-05
# Epoch 169/200
#
# Epoch 169: val_loss improved from 0.03272 to 0.03268, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0169-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 82s - 27ms/step - accuracy: 0.9957 - loss: 0.0265 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0283e-05
# Epoch 170/200
#
# Epoch 170: val_loss did not improve from 0.03268
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9967 - loss: 0.0251 - val_accuracy: 0.9963 - val_loss: 0.0328 - learning_rate: 1.0269e-05
# Epoch 171/200
#
# Epoch 171: val_loss did not improve from 0.03268
# 3041/3041 - 79s - 26ms/step - accuracy: 0.9962 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0256e-05
# Epoch 172/200
#
# Epoch 172: val_loss did not improve from 0.03268
# 3041/3041 - 81s - 27ms/step - accuracy: 0.9965 - loss: 0.0250 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0243e-05
# Epoch 173/200
#
# Epoch 173: val_loss did not improve from 0.03268
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9964 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0231e-05
# Epoch 174/200
#
# Epoch 174: val_loss improved from 0.03268 to 0.03263, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0174-val_loss-0.033-val_accuracy-0.997.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9961 - loss: 0.0257 - val_accuracy: 0.9970 - val_loss: 0.0326 - learning_rate: 1.0219e-05
# Epoch 175/200
#
# Epoch 175: val_loss improved from 0.03263 to 0.03263, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0175-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9965 - loss: 0.0252 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0208e-05
# Epoch 176/200
#
# Epoch 176: val_loss improved from 0.03263 to 0.03261, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0176-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0198e-05
# Epoch 177/200
#
# Epoch 177: val_loss did not improve from 0.03261
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9965 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0188e-05
# Epoch 178/200
#
# Epoch 178: val_loss did not improve from 0.03261
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9962 - loss: 0.0254 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0178e-05
# Epoch 179/200
#
# Epoch 179: val_loss did not improve from 0.03261
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9964 - loss: 0.0258 - val_accuracy: 0.9963 - val_loss: 0.0327 - learning_rate: 1.0170e-05
# Epoch 180/200
#
# Epoch 180: val_loss did not improve from 0.03261
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9963 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0161e-05
# Epoch 181/200
#
# Epoch 181: val_loss improved from 0.03261 to 0.03261, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0181-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0153e-05
# Epoch 182/200
#
# Epoch 182: val_loss improved from 0.03261 to 0.03257, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0182-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9965 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0145e-05
# Epoch 183/200
#
# Epoch 183: val_loss did not improve from 0.03257
# 3041/3041 - 101s - 33ms/step - accuracy: 0.9967 - loss: 0.0248 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0138e-05
# Epoch 184/200
#
# Epoch 184: val_loss improved from 0.03257 to 0.03254, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0184-val_loss-0.033-val_accuracy-0.996.keras
# 3041/3041 - 82s - 27ms/step - accuracy: 0.9963 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0131e-05
# Epoch 185/200
#
# Epoch 185: val_loss did not improve from 0.03254
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9963 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0125e-05
# Epoch 186/200
#
# Epoch 186: val_loss did not improve from 0.03254
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9964 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0118e-05
# Epoch 187/200
#
# Epoch 187: val_loss improved from 0.03254 to 0.03244, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0187-val_loss-0.032-val_accuracy-0.996.keras
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9960 - loss: 0.0257 - val_accuracy: 0.9963 - val_loss: 0.0324 - learning_rate: 1.0112e-05
# Epoch 188/200
#
# Epoch 188: val_loss did not improve from 0.03244
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9965 - loss: 0.0250 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0107e-05
# Epoch 189/200
#
# Epoch 189: val_loss did not improve from 0.03244
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0252 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0102e-05
# Epoch 190/200
#
# Epoch 190: val_loss did not improve from 0.03244
# 3041/3041 - 83s - 27ms/step - accuracy: 0.9965 - loss: 0.0246 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0096e-05
# Epoch 191/200
#
# Epoch 191: val_loss did not improve from 0.03244
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9965 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0092e-05
# Epoch 192/200
#
# Epoch 192: val_loss did not improve from 0.03244
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9961 - loss: 0.0259 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0087e-05
# Epoch 193/200
#
# Epoch 193: val_loss did not improve from 0.03244
# 3041/3041 - 105s - 35ms/step - accuracy: 0.9963 - loss: 0.0256 - val_accuracy: 0.9963 - val_loss: 0.0326 - learning_rate: 1.0083e-05
# Epoch 194/200
#
# Epoch 194: val_loss did not improve from 0.03244
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9962 - loss: 0.0254 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0079e-05
# Epoch 195/200
#
# Epoch 195: val_loss improved from 0.03244 to 0.03243, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0195-val_loss-0.032-val_accuracy-0.996.keras
# 3041/3041 - 103s - 34ms/step - accuracy: 0.9964 - loss: 0.0250 - val_accuracy: 0.9963 - val_loss: 0.0324 - learning_rate: 1.0075e-05
# Epoch 196/200
#
# Epoch 196: val_loss did not improve from 0.03243
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9966 - loss: 0.0249 - val_accuracy: 0.9963 - val_loss: 0.0325 - learning_rate: 1.0071e-05
# Epoch 197/200
#
# Epoch 197: val_loss improved from 0.03243 to 0.03236, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0197-val_loss-0.032-val_accuracy-0.996.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9960 - loss: 0.0261 - val_accuracy: 0.9963 - val_loss: 0.0324 - learning_rate: 1.0067e-05
# Epoch 198/200
#
# Epoch 198: val_loss improved from 0.03236 to 0.03225, saving model to /home/razvan/documentation/DeepLearning/CNN/10-L'apprentissage et rappels d’exécution--modèle VGG19--fruits-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0198-val_loss-0.032-val_accuracy-0.997.keras
# 3041/3041 - 104s - 34ms/step - accuracy: 0.9956 - loss: 0.0261 - val_accuracy: 0.9970 - val_loss: 0.0323 - learning_rate: 1.0064e-05
# Epoch 199/200
#
# Epoch 199: val_loss did not improve from 0.03225
# 3041/3041 - 105s - 34ms/step - accuracy: 0.9968 - loss: 0.0248 - val_accuracy: 0.9963 - val_loss: 0.0323 - learning_rate: 1.0061e-05
# Epoch 200/200
#
# Epoch 200: val_loss did not improve from 0.03225
# 3041/3041 - 102s - 34ms/step - accuracy: 0.9964 - loss: 0.0248 - val_accuracy: 0.9963 - val_loss: 0.0324 - learning_rate: 1.0058e-05

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
history = sauvegardeHistorique(model_history,
                               repertoireSauvegardes,
                               nomSauvegarde='history_batch_size_32')

# %%
afficheHistoriqueEntrainement(history, palette, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %%
sauvegarderModel(model, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du modèle </div></b>

# %%
model = tf.keras.models.load_model(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
for i, (img,lab) in enumerate(pipeline_validation):
    if i == 0 : 
        images, labels = img,lab
    else:
        images, labels = tf.concat([images,img], 0), tf.concat([labels,lab], 0)

# %%
probabilities = model.predict(images, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(48,16));
for i in range(4):
    afficheProbabilites(probabilities,ind=i,ax=ax[i], dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=labels,predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=images,
                                                  y_test=labels,
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Area under the ROC curve : 1.0000	--	Exécution  :15.76s
#             Classe    aucROC  avgPrecRec        f1        f2       f05  \
# 0           global  0.999988    0.999900  0.996306  0.996288  0.996366
# 1          Abricot  1.000000    1.000000  0.979592  0.967742  0.991736
# 2           Ananas  1.000000    1.000000  1.000000  1.000000  1.000000
# 3           Avocat  1.000000    1.000000  0.990476  0.996169  0.984848
# 4           Banane  1.000000    1.000000  1.000000  1.000000  1.000000
# 5           Cerise  1.000000    1.000000  1.000000  1.000000  1.000000
# 6           Citron  1.000000    1.000000  1.000000  1.000000  1.000000
# 7       Clémentine  1.000000    1.000000  1.000000  1.000000  1.000000
# 8           Fraise  1.000000    1.000000  1.000000  1.000000  1.000000
# 9        Framboise  1.000000    1.000000  1.000000  1.000000  1.000000
# 10            Kiwi  1.000000    1.000000  1.000000  1.000000  1.000000
# 11            Maïs  1.000000    1.000000  1.000000  1.000000  1.000000
# 12          Mangue  1.000000    1.000000  1.000000  1.000000  1.000000
# 13        Myrtille  1.000000    1.000000  1.000000  1.000000  1.000000
# 14          Oignon  1.000000    1.000000  1.000000  1.000000  1.000000
# 15          Orange  1.000000    1.000000  0.982759  0.993031  0.972696
# 16          Papaye  1.000000    1.000000  1.000000  1.000000  1.000000
# 17        Pastèque  1.000000    1.000000  1.000000  1.000000  1.000000
# 18           Pêche  0.999840    0.995139  0.977273  0.990783  0.964126
# 19           Poire  1.000000    1.000000  1.000000  1.000000  1.000000
# 20         Poivron  1.000000    1.000000  1.000000  1.000000  1.000000
# 21           Pomme  0.999880    0.998708  0.990566  0.984991  0.996205
# 22  Pomme de terre  1.000000    1.000000  0.988235  0.981308  0.995261
# 23           Prune  1.000000    1.000000  1.000000  1.000000  1.000000
# 24          Tomate  1.000000    1.000000  1.000000  1.000000  1.000000
#
#     accuracy  precision  sensibilite  vrais_positifs  vrais_negatifs  \
# 0   0.996299   0.996429     0.996299            1346           31068
# 1   0.998520   1.000000     0.960000              48            1301
# 2   1.000000   1.000000     1.000000              51            1300
# 3   0.999260   0.981132     1.000000              52            1298
# 4   1.000000   1.000000     1.000000              43            1308
# 5   1.000000   1.000000     1.000000              60            1291
# 6   1.000000   1.000000     1.000000              79            1272
# 7   1.000000   1.000000     1.000000              50            1301
# 8   1.000000   1.000000     1.000000              42            1309
# 9   1.000000   1.000000     1.000000              43            1308
# 10  1.000000   1.000000     1.000000              49            1302
# 11  1.000000   1.000000     1.000000              53            1298
# 12  1.000000   1.000000     1.000000              54            1297
# 13  1.000000   1.000000     1.000000              35            1316
# 14  1.000000   1.000000     1.000000              49            1302
# 15  0.998520   0.966102     1.000000              57            1292
# 16  1.000000   1.000000     1.000000              51            1300
# 17  1.000000   1.000000     1.000000              49            1302
# 18  0.998520   0.955556     1.000000              43            1306
# 19  1.000000   1.000000     1.000000              60            1291
# 20  1.000000   1.000000     1.000000             115            1236
# 21  0.998520   1.000000     0.981308             105            1244
# 22  0.999260   1.000000     0.976744              42            1308
# 23  1.000000   1.000000     1.000000              39            1312
# 24  1.000000   1.000000     1.000000              77            1274
#
#     faux_positifs  faux_negatifs  total_positifs    essai
# 0               5              5            1351  initial
# 1               0              2              50  initial
# 2               0              0              51  initial
# 3               1              0              52  initial
# 4               0              0              43  initial
# 5               0              0              60  initial
# 6               0              0              79  initial
# 7               0              0              50  initial
# 8               0              0              42  initial
# 9               0              0              43  initial
# 10              0              0              49  initial
# 11              0              0              53  initial
# 12              0              0              54  initial
# 13              0              0              35  initial
# 14              0              0              49  initial
# 15              2              0              57  initial
# 16              0              0              51  initial
# 17              0              0              49  initial
# 18              2              0              43  initial
# 19              0              0              60  initial
# 20              0              0             115  initial
# 21              0              2             107  initial
# 22              0              1              43  initial
# 23              0              0              39  initial
# 24              0              0              77  initial
