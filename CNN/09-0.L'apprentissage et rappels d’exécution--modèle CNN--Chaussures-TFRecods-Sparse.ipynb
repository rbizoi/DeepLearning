# %% [markdown]
# <table>
# <tr>
#      <th>
#          <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'><a href="https://www.kaggle.com/datasets/adityakadam1/footwear">Reconnaissance des Chaussures</a></div>
#      </th>
#      <th><img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/chaussures.png" width="96"></th>
#  </tr>
# </table>
#
#
#
# **Reconnaissance des Chaussures**<br>
# Le jeu de données contient **3 000** images de fleurs étiquetées en **3** classes.
#
# <table>
#     <tr>
#          <th  style="text-align:left;background-color:#053061;color:white;">Valeur</th>
#          <th  style="text-align:left;background-color:#053061;color:white;">Nom classe</th>
#      </tr>
#     <tr>
#         <th  style="text-align:left">0</th>
#         <th  style="text-align:left">Botte</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">1</th>
#         <th  style="text-align:left">Sandale</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">2</th>
#         <th  style="text-align:left">Chaussure</th>
#     </tr>
# </table>
#
# > https://www.larousse.fr/dictionnaires/francais/inf%C3%A9rence/42907<br><br>
#
# >> **inférence** : Opération par laquelle on passe d'une assertion considérée comme vraie à une autre assertion au moyen d'un système de règles qui rend cette deuxième assertion également vraie.<br>
#
# >> **Inférence statistique** : Ensemble des méthodes permettant de formuler en termes probabilistes un jugement sur une population à partir des résultats observés sur un échantillon extrait au hasard de cette population.<br>
#
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ['TF_XLA_FLAGS']='--tf_xla_auto_jit=1,--tf_xla_always_defer_compilation=true'
# os.environ['XLA_FLAGS']='--xla_backend_optimization_level=0,--xla_gpu_autotune_level=4,--xla_gpu_disable_ptxas_optimizations=true,--xla_gpu_use_cudnn_batchnorm_level=2'
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, pickle, time
from matplotlib import pyplot as plt
from datetime import datetime as dt

import matplotlib.font_manager as fm
from matplotlib.lines import Line2D

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist,fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm

from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer, confusion_matrix, roc_curve, auc, accuracy_score, log_loss, hamming_loss, \
                            precision_score, recall_score, f1_score, fbeta_score, jaccard_score, \
                            precision_recall_curve, average_precision_score, balanced_accuracy_score, \
                            classification_report,roc_auc_score

tf.get_logger().setLevel('ERROR')# Suppress TensorFlow logging (2)

# %%
print("Tensorflow\t : %s\tCUDA %s\tGPU %s\tXLA %s\nKeras\t\t : %s\nPandas\t\t : %s\nNumPy\t\t : %s"%
      (tf.__version__, 
       tf.test.is_built_with_cuda(), 
       tf.test.is_built_with_gpu_support(), 
       tf.test.is_built_with_xla(), 
       tf.keras.__version__, 
       pd.__version__, 
       np.__version__))
# Out:
# Tensorflow	 : 2.17.0	CUDA True	GPU True	XLA True
# Keras		 : 3.6.0
# Pandas		 : 2.2.2
# NumPy		 : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des GPUs presents</div></b>

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) >  0 :
    for i, gpu in enumerate(physical_devices):
        tf.config.experimental.set_memory_growth(physical_devices[i], True)

    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('Le système est initialisé avec {0:d} GPUs'.format(strategy.num_replicas_in_sync))
# Out:
# Le système est initialisé avec 1 GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751913582.326495 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.348017 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.348142 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751913582.354593 2573645 service.cc:146] XLA service 0x400d5170 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751913582.354613 2573645 service.cc:154]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1751913582.393239 2573802 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.393376 2573645 service.cc:146] XLA service 0x3d445a60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751913582.393391 2573645 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1751913582.393524 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.393619 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.393676 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.396977 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751913582.397063 2573645 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
palette = [
            "#030aa7", "#e50000", "#d8863b", "#005f6a", "#6b7c85", "#751973", "#d1e5f0", "#fddbc7",
            "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#f5054f", "#a0450e",
            "#0339f8", "#f4320c", "#fec615", "#017a79", "#85a3b2", "#fe2f4a", "#a00498", "#b04e0f",
            "#0165fc", "#ff724c", "#fddc5c", "#11875d", "#89a0b0", "#fe828c", "#cb00f5", "#b75203",
            "#0485d1", "#ff7855", "#fbeeac", "#0cb577", "#95a3a6", "#ffb7ce", "#c071fe", "#ca6b02",
            "#92c5de", "#f4a582", "#fef69e", "#18d17b", "#c5c9c7", "#ffcfdc", "#caa0ff", "#cb7723",
            "#d1e5f0", "#fddbc7", "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#d8863b",
            "#030764", "#be0119", "#dbb40c", "#005249", "#3c4142", "#cb0162", "#5d1451", "#653700",
            "#040348", "#67001f", "#b27a01", "#002d04", "#000000", "#a0025c", "#490648", "#3c0008"
          ]

# %%
nom_projet                = "09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods"
repertoireProjet          = os.getcwd()
repertoireEnregistrement  = repertoireProjet +'/'+nom_projet+ '/repertoire.images'
repertoireSauvegardes     = repertoireProjet +'/'+nom_projet+ '/repertoire.sauvegardes'

def controleExistenceRepertoire(directory, create_if_needed=True):
    """Voir si le répertoire existe. S'il n'existe pas il est créé."""
    path_exists = os.path.exists(directory)
    if path_exists:
        if not os.path.isdir(directory):
            raise Exception("Trouvé le nom "+directory+" mais c'est un fichier, pas un répertoire")
            return False
        return True
    if create_if_needed:
        os.makedirs(directory)
        
controleExistenceRepertoire(repertoireEnregistrement)
controleExistenceRepertoire(repertoireSauvegardes)

def sauvegarderImage( fichier):
    """Enregistrez la figure. Appelez la méthode juste avant plt.show ()."""
    plt.savefig(os.path.join(repertoireEnregistrement,
                             fichier+f"--{dt.now().strftime('%Y_%m_%d_%H.%M.%S')}.png"), 
                             dpi=600, 
                             bbox_inches='tight')
    
def sauvegarderModelPoids(model, fichierPoids, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez les poids du modèle Keras."""
    if fichierPoids != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichierPoids))
        model.save_weights(nomFichier)

def sauvegarderModel(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez le modèle Keras."""
    if fichier != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
        model.save(nomFichier)

def lectureModelPoids(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Si le fichier existe, il est chargé et retourne True, sinon retourne False."""
    nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
    if os.path.exists(nomFichier):
        if os.path.isfile(nomFichier):
            model.load_weights(nomFichier)
            return True
    return False

def sauvegardeHistorique(model,
                         repertoireSauvegardes,
                         nomSauvegarde='one_hidden_layer_history_batch_size_1'):

    history = pd.DataFrame( model.history)
    history.reset_index(inplace=True)
    history.rename(columns={'index':'epoch'},inplace=True)
    history.to_parquet(os.path.join(repertoireSauvegardes,f'{nomSauvegarde}.gzip'),compression='gzip', engine='pyarrow') 
    return history


def afficheHistoriqueEntrainement(history, palette, nom):
    fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(48,16));
    markersize = 8
    linewidth=2
    
    graph = sns.lineplot(x='epoch', 
                         y='accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='val_accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
        
    ax[0].set_title(f'Accuracy {nom}', fontproperties=fm.FontProperties(size=32))
    
    graph = sns.lineplot(x='epoch', 
                         y='loss',  
                         data=history,
                         ax=ax[1],      
                         label='loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_loss',  
                         data=history,
                         ax=ax[1],      
                         label='val_loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    ax[1].set_title(f'Loss {nom}', fontproperties=fm.FontProperties(size=32))
    
    sauvegarderImage(f'afficheHistoriqueEntrainement-{nom}')



def afficheMatriceConfusion(observations,predictions,dictLabels):
    plt.figure(figsize=(8,8))
    sns.set(font_scale=1.5)
    sns.heatmap(pd.crosstab(observations,predictions), 
                fmt= '.0f',
                linewidths=0.3,
                #vmax=1.0, 
                square=True, 
                cmap=plt.cm.Blues,
                linecolor='white', 
                annot=True,
                cbar=False,
                xticklabels=dictLabels.values(), 
                yticklabels=dictLabels.values()
               );
    plt.xlabel('Observations', fontsize = 18);
    plt.ylabel('Prédictions', fontsize = 18);
    sauvegarderImage('afficheMatriceConfusion')

def executeApprentissageChoixClassifieurs(model,
                                          X_test,
                                          y_test,
                                          label_dict,
                                          couleurs,
                                          nom_essai = 'initial'
                                         ):
    
    def afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict):
        plt.figure(figsize=(24, 24));
        for i, color in zip(range(nbClasses), palette):
            plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
                     label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
                                                             ''.format(i, aucROCt[i]))
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('Taux de faux Positifs-(1 - Spécificité) = VN / (FP + VN)',size=18)
        plt.ylabel('Taux de vrais positifs-Sensibilité = VP / (VP + FN)',size=18)
        plt.title('Courbe ROC (Receiver Operating Caracteristic) -- ',size=20)
        plt.legend(loc="lower right"); #, fontsize='large'
        sauvegarderImage('Courbe ROC')
        
        plt.figure(figsize=(24,24));
    
        f_scores = np.linspace(0.2, 0.9, num=8)
        for f_score in f_scores:
            x = np.linspace(0.01, 1)
            y = f_score * x / (2 * x - f_score)
            l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
            plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
    
        for i, color in zip(range(nbClasses), palette):
            plt.step(sensibilites[i], 
                         precisions[i], 
                         where='post', 
                         color=color, 
                         lw=lw, 
                         label=f"{label_dict[i]}(APR = {avgPrecRec[label_dict[i]]:0.8f})"
                    )
            plt.fill_between(sensibilites[i], precisions[i], step='post', alpha=0.05)            
    
            # plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
            #          label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
            #                                                  ''.format(i, aucROCt[i]))        
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])        
        plt.xlabel('Sensibilité/Rappel(Recall) = VP / (VP + FN)',size=18)
        plt.ylabel('Précision = VP / (VP + FP)',size=18)        
        plt.title('Courbe Précision-Rappel',size=20)
        plt.legend(loc="lower right") # , fontsize = 'large'
        sauvegarderImage('Courbe Précision-Rappel')
    
    cvF1, cvF1SD, cvAccuracy, cvAccSD, aucROC, avgPrecRec, accuracy, balanced_accuracy, logloss, hammingloss, precision, sensibilite, \
    f1, f2, f05, jaccard, vrais_negatifs, faux_positifs, faux_negatifs, vrais_positifs, total_positifs, aucROCtn = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(),\
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    #
    oneloss, precision_micro, precision_macro, precision_weighted, \
    sensibilite_macro, sensibilite_micro, sensibilite_weighted, \
    f1_micro, f1_macro, f1_weighted,f2_micro,f2_macro,f2_weighted,f05_micro,f05_macro,f05_weighted = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    
    fauxPositifs, vraisPositifs, precisions, sensibilites, aucROCt, pr_auc, tauxROC, tauxPR = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()        
    
    
    lw = 1
    # couleurs    = sns.hls_palette(len(classifieursDict.keys()), l=.4, s=.9)
    nbClasses   = len(dictLabels.keys())
    listClasses = list(dictLabels.keys())
    
    y_testA  = label_binarize(y_test, classes=listClasses)
    plt.figure(figsize=(18,18))
    
    
    t1 = time.time()  
    classifier = model
    
    # y_score     = model.predict_proba(X_test)
    # y_pred      = model.predict(X_test)
    y_score     = model.predict(X_test)
    y_pred      = np.argmax(y_score, axis=-1) 
    y_predA     = label_binarize(y_pred, classes=listClasses)
    
    accuracy['global']              = accuracy_score(y_test, y_pred)
    balanced_accuracy['global']     = balanced_accuracy_score(y_test, y_pred)
    precision['global']             = precision_score(y_test, y_pred, average='weighted')
    sensibilite['global']           = recall_score(y_test, y_pred, average='weighted')
    
    f1['global']                    = f1_score(y_test, y_pred, average='weighted')
    f2['global']                    = fbeta_score(y_test, y_pred, beta=2, average='weighted')
    f05['global']                   = fbeta_score(y_test, y_pred, beta=0.5, average='weighted')
    
    vrais_negatifs['global']        = 0
    faux_positifs ['global']        = 0
    faux_negatifs ['global']        = 0
    vrais_positifs['global']        = 0
    total_positifs['global']        = 0
    
    
    aucROC['global'] = roc_auc_score(y_test, y_score, multi_class='ovr')
    
    for i in range(nbClasses):
        fauxPositifs[i], vraisPositifs[i], tauxROC[i] = roc_curve(y_testA[:, i], y_score[:, i])
        aucROCt[i]                                    = auc(fauxPositifs[i], vraisPositifs[i])
        precisions[i], sensibilites[i], tauxPR[i]     = precision_recall_curve(y_testA[:, i], y_score[:, i])
    
        aucROC[label_dict[i]]                = aucROCt[i]
        avgPrecRec[label_dict[i]]            = average_precision_score(y_testA[:, i], y_score[:, i])
        accuracy[label_dict[i]]              = accuracy_score(y_testA[:, i], y_predA[:, i])
        balanced_accuracy[label_dict[i]]     = balanced_accuracy_score(y_testA[:, i],y_predA[:, i])
        logloss[label_dict[i]]               = log_loss(y_testA[:, i], y_predA[:, i])
        hammingloss[label_dict[i]]           = hamming_loss(y_testA[:, i], y_predA[:, i])
        precision[label_dict[i]]             = precision_score(y_testA[:, i], y_predA[:, i])
        sensibilite[label_dict[i]]           = recall_score(y_testA[:, i], y_predA[:, i])
        f1[label_dict[i]]                    = f1_score(y_testA[:, i], y_predA[:, i])
        f2[label_dict[i]]                    = fbeta_score(y_testA[:, i], y_predA[:, i], beta=2)
        f05[label_dict[i]]                   = fbeta_score(y_testA[:, i], y_predA[:, i], beta=0.5)
      
        jaccard[label_dict[i]]               = jaccard_score(y_testA[:, i], y_predA[:, i])
        vrais_negatifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 0]
        faux_positifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 1]
        faux_negatifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 0]
        vrais_positifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 1]
        total_positifs[label_dict[i]]        = vrais_positifs[label_dict[i]] + faux_negatifs [label_dict[i]]
        vrais_negatifs['global']              += vrais_negatifs[label_dict[i]]
        faux_positifs ['global']              += faux_positifs [label_dict[i]]
        faux_negatifs ['global']              += faux_negatifs [label_dict[i]]
        vrais_positifs['global']              += vrais_positifs[label_dict[i]]
    
    
    total_positifs['global'] = vrais_positifs['global'] + faux_negatifs ['global']
    
    
    fauxPositifs["micro"], vraisPositifs["micro"], _ = roc_curve(y_testA.ravel(), y_score.ravel())
    aucROCt["micro"]                                 = auc(fauxPositifs["micro"], vraisPositifs["micro"])
    
    listFauxPositifs = np.unique(np.concatenate([fauxPositifs[i] for i in range(nbClasses)]))
    moyenneVraisPositifs = np.zeros_like(listFauxPositifs)
    for i in range(nbClasses):
        moyenneVraisPositifs += np.interp(listFauxPositifs, fauxPositifs[i], vraisPositifs[i])
    
    moyenneVraisPositifs /= nbClasses
    
    fauxPositifs["macro"], vraisPositifs["macro"] = listFauxPositifs, moyenneVraisPositifs
    aucROCt["macro"] = auc(fauxPositifs["macro"], vraisPositifs["macro"])
    # aucROC['global'] = aucROCt["macro"]  # (aucROCt["micro"],aucROCt["macro"])
    
    avgPrecRec['global'] = average_precision_score(y_testA.ravel(), y_score.ravel(), average='weighted')
    
    afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict);
    
    print ("Area under the ROC curve : %0.4f" % aucROC['global'],end='\t--\t')
    print('Exécution  :'+('%.2fs' % (time.time() - t1)).lstrip('0'))
        
    resultats = pd.DataFrame(pd.Series(aucROC), columns=["aucROC"])
    resultats["avgPrecRec"]              = pd.Series(avgPrecRec)
    resultats["f1"]                      = pd.Series(f1)
    resultats["f2"]                      = pd.Series(f2)
    resultats["f05"]                     = pd.Series(f05)
    resultats["accuracy"]                = pd.Series(accuracy)
    
    resultats["precision"]               = pd.Series(precision)
    resultats["sensibilite"]             = pd.Series(sensibilite)
    resultats["vrais_positifs"]          = pd.Series(vrais_positifs)
    resultats["vrais_negatifs"]          = pd.Series(vrais_negatifs)
    resultats["faux_positifs"]           = pd.Series(faux_positifs)
    resultats["faux_negatifs"]           = pd.Series(faux_negatifs)
    resultats["total_positifs"]          = pd.Series(total_positifs)
    
    resultats.reset_index(inplace=True)
    resultats.rename(columns={"index": "Classe"}, inplace=True)
    resultats['essai'] = nom_essai
    return resultats

def afficheProbabilites(probabilities, ind, ax, dictLabels):
    prediction = pd.DataFrame(probabilities).iloc[ind,:].reset_index()
    prediction.columns = ['Classe','Probabilite']
    prediction.Classe = prediction.Classe.apply(lambda x : f'{x:02d}-{dictLabels[x]}')
    
    graph = sns.barplot(
                        x='Classe',
                        y='Probabilite',
                        data=prediction.sort_values('Probabilite',ascending=False),
                        palette=palette[1:],
                        ax=ax        
                        );
    graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
    
    for i, patche in enumerate(graph.patches):
        if patche.get_height() > 0 :
            graph.text(
                        patche.get_x()+0.4,
                        0.4, #2*patche.get_height()/3,
                        f'{patche.get_height()*100:0.4f}%',
                        color='black',
                        rotation='vertical',
                        # size='large',
                        fontsize='large',
                        bbox=dict(boxstyle='round', facecolor='white', alpha=0.6),
                        verticalalignment='center',
                        horizontalalignment='center',
                       )       
    sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Paramétrés de l’exécution</div></b>

# %%
random_seed=123456
canaux=3 
image_size=(28, 28, 3)
image_height=image_size[0]
image_width=image_size[1]

batch_size = 16
epochs=1024
dictLabels = {
                0   : 'Botte',
                1   : 'Sandale',
                2   : 'Chaussure'
       }

number_of_classes=len(dictLabels.keys())


repertoireDonneesTFRec = '../donnees/tfRecords'

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Lecture des fichiers TFRecors</div></b>

# %%
redimensionnement_normalisation = tf.keras.models.Sequential(
    [
        tf.keras.layers.Resizing(height=image_size[0], width=image_size[1]),
        tf.keras.layers.Rescaling(scale=1./255.),
    ],
    name="redimensionnement_normalisation",
)

def _traitementImage(image):
    # image = tf.cast(tf.image.decode_jpeg(image, channels=canaux), tf.int32)
    # image = tf.cast(redimensionnement_normalisation(tf.image.decode_jpeg(image, channels=canaux)), tf.int32)
    image = redimensionnement_normalisation(tf.image.decode_jpeg(image, channels=canaux))
    return image

def _lectureTFRecord(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    enregistrement['image'] =  _traitementImage(enregistrement['image'])
    return enregistrement

def _dictToImageLabel(enregistrement):
    # return enregistrement['image'],tf.one_hot(enregistrement['label'], number_of_classes)
    return enregistrement['image'],enregistrement['label']

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(factor=(-0.2, 0.3)),
  # tf.keras.layers.RandomContrast(factor=(0.2, 0.95)),  
  # tf.keras.layers.RandomBrightness(factor=(-0.4, 0.4)),  
  # tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.3),width_factor=(-0.2, -0.3)),  
])

def _lectureTFRecordAugmentation(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    # enregistrement['image'] = tf.cast(data_augmentation(_traitementImage(enregistrement['image'])), tf.int32) 
    enregistrement['image'] = data_augmentation(_traitementImage(enregistrement['image']))
    return enregistrement

# %% [raw]
# def controleFichiersTfRecords(nom,dictLabels):
#
#     pipeline_train = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,f'{nom}-apprentissage.tfrecords'))
#     # pipeline_train = pipeline_train.map(_lectureTFRecord)
#     pipeline_train = pipeline_train.map(_lectureTFRecordAugmentation)
#     pipeline_train = pipeline_train.map(_dictToImageLabel)
#     pipeline_train = pipeline_train.batch(25)
#     pipeline_train = pipeline_train.prefetch(tf.data.AUTOTUNE)
#
#     image_batch, label_batch = next(iter(pipeline_train))
#
#     plt.figure(figsize=(24, 24))
#     for n in range(25):
#         ax = plt.subplot(5, 5, n + 1)
#         plt.imshow(image_batch[n])
#         plt.title(dictLabels[np.argmax(label_batch[n].numpy(), axis=-1)])
#         plt.axis("off")

# %% [raw]
# controleFichiersTfRecords('bloodmnist',dictLabels)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des flux de lecture des fichiers TFRecors</div></b>

# %%
pipeline_apprentissage = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'chaussures-apprentissage.tfrecords'))
pipeline_apprentissage = pipeline_apprentissage.shuffle(batch_size).repeat(4)
pipeline_apprentissage = pipeline_apprentissage.map(_lectureTFRecordAugmentation)
pipeline_apprentissage = pipeline_apprentissage.map(_dictToImageLabel)
pipeline_apprentissage = pipeline_apprentissage.batch(batch_size)
pipeline_apprentissage = pipeline_apprentissage.prefetch(tf.data.AUTOTUNE)  

pipeline_validation = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'chaussures-validation.tfrecords'))
pipeline_apprentissage = pipeline_apprentissage.shuffle(batch_size)
pipeline_validation = pipeline_validation.map(_lectureTFRecord)
pipeline_validation = pipeline_validation.map(_dictToImageLabel)
pipeline_validation = pipeline_validation.batch(batch_size)
pipeline_validation = pipeline_validation.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
initial_lrate = 1e-3
min_lrate = 1e-4

drop_lrate = 0.6
epochs_drop = epochs * 0.1

# %%
def make_model(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Entry block
    x = tf.keras.layers.Conv2D(128, 3, strides=1, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation("relu")(x)
        
        x = tf.keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation("relu")(x)

        x = tf.keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    return tf.keras.Model(inputs, outputs)


model = make_model(input_shape=image_size, num_classes=len(dictLabels.keys()))
# tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 28, 28, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 28, 28,    │      3,584 │ input_layer_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 28, 28,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ activation[0][0]  │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 28, 28,    │     34,176 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 28, 28,    │     68,096 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 14, 14,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 14, 14,    │     33,024 │ activation[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 14, 14,    │          0 │ max_pooling2d[0]… │
# │                     │ 256)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ add[0][0]         │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 14, 14,    │    133,888 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 14, 14,    │    267,264 │ activation_5[0][… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 7, 7, 512) │          0 │ activation_6[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 7, 7, 512) │    131,584 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 7, 7, 512) │          0 │ max_pooling2d_1[… │
# │                     │                   │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 7, 7, 512) │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 7, 7, 728) │    378,072 │ activation_7[0][… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 728) │      2,912 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 7, 7, 728) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 7, 7, 728) │    537,264 │ activation_8[0][… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 728) │      2,912 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 7, 7, 728) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 4, 4, 728) │          0 │ activation_9[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 728) │    373,464 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 4, 4, 728) │          0 │ max_pooling2d_2[… │
# │                     │                   │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 4, 4,      │    753,048 │ add_2[0][0]       │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      4,096 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      3,075 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,733,115 (10.43 MB)
#  Trainable params: 2,724,827 (10.39 MB)
#  Non-trainable params: 8,288 (32.38 KB)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Compilation du modèle </div></b>

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(initial_lrate), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>
#
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
# learning rate scheduler
def step_decay(epoch):
    lrate = (initial_lrate - min_lrate ) * drop_lrate**((1+epoch)/epochs_drop) + min_lrate
    return lrate
# learning schedule callback

learningRate = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
rng = [i for i in range(epochs)]
y = [step_decay(x) for x in rng]
plt.plot(rng, y)
print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.000996 à 0.000105

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels de sauvegarde automatique du modèle </div></b>

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde chaque étape </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic1-epoch-{epoch:04d}.keras')
checkpointTimer1  = tf.keras.callbacks.ModelCheckpoint(filename,save_freq='epoch')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde tous les 5 étapes </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic5-epoch-{epoch:04d}.keras')
checkpointTimer5 = tf.keras.callbacks.ModelCheckpoint(filename,save_freq=5)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_loss minim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVLoss-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')

checkpointLoss = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                    monitor = 'val_loss',
                                                    verbose = 1, 
                                                    save_best_only = True, 
                                                    mode = 'min')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_accuracy maxim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVAccuracy-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
checkpointAccuracy = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                           monitor = 'val_accuracy', 
                                                           verbose = 1, 
                                                           save_best_only = True, 
                                                           mode = 'max')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Arrêt de l'apprentissage</div></b>

# %%
arretPrecoce = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, verbose=1)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels utilisés</div></b>

# %%
callbacks = [
    learningRate,
    # checkpointTimer1,
    # checkpointTimer5,
    checkpointLoss,
    # checkpointAccuracy,
    arretPrecoce
]

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle</div></b>

# %%
model_history = model.fit(pipeline_apprentissage, 
                    validation_data=pipeline_validation, 
                    epochs=epochs, 
                    batch_size=batch_size,
                    callbacks=callbacks,
                    verbose=2
                   )
# Out:
# Epoch 1/1024
# I0000 00:00:1751913589.970410 2573836 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 1.35907, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0001-val_loss-1.359-val_accuracy-0.640.keras
# 675/675 - 16s - 24ms/step - accuracy: 0.7249 - loss: 0.6106 - val_accuracy: 0.6400 - val_loss: 1.3591 - learning_rate: 9.9552e-04
# Epoch 2/1024
#
# Epoch 2: val_loss improved from 1.35907 to 0.57137, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0002-val_loss-0.571-val_accuracy-0.790.keras
# 675/675 - 7s - 11ms/step - accuracy: 0.8483 - loss: 0.3767 - val_accuracy: 0.7900 - val_loss: 0.5714 - learning_rate: 9.9107e-04
# Epoch 3/1024
#
# Epoch 3: val_loss did not improve from 0.57137
# 675/675 - 7s - 11ms/step - accuracy: 0.8936 - loss: 0.2872 - val_accuracy: 0.7767 - val_loss: 0.6546 - learning_rate: 9.8663e-04
# Epoch 4/1024
#
# Epoch 4: val_loss improved from 0.57137 to 0.28897, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0004-val_loss-0.289-val_accuracy-0.910.keras
# 675/675 - 8s - 12ms/step - accuracy: 0.9098 - loss: 0.2422 - val_accuracy: 0.9100 - val_loss: 0.2890 - learning_rate: 9.8222e-04
# Epoch 5/1024
#
# Epoch 5: val_loss did not improve from 0.28897
# 675/675 - 7s - 11ms/step - accuracy: 0.9262 - loss: 0.1994 - val_accuracy: 0.9100 - val_loss: 0.3051 - learning_rate: 9.7783e-04
# Epoch 6/1024
#
# Epoch 6: val_loss did not improve from 0.28897
# 675/675 - 7s - 10ms/step - accuracy: 0.9311 - loss: 0.1921 - val_accuracy: 0.6700 - val_loss: 1.3890 - learning_rate: 9.7346e-04
# Epoch 7/1024
#
# Epoch 7: val_loss did not improve from 0.28897
# 675/675 - 6s - 9ms/step - accuracy: 0.9410 - loss: 0.1659 - val_accuracy: 0.8600 - val_loss: 0.4910 - learning_rate: 9.6911e-04
# Epoch 8/1024
#
# Epoch 8: val_loss improved from 0.28897 to 0.15917, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0008-val_loss-0.159-val_accuracy-0.947.keras
# 675/675 - 7s - 11ms/step - accuracy: 0.9469 - loss: 0.1465 - val_accuracy: 0.9467 - val_loss: 0.1592 - learning_rate: 9.6479e-04
# Epoch 9/1024
#
# Epoch 9: val_loss did not improve from 0.15917
# 675/675 - 7s - 10ms/step - accuracy: 0.9513 - loss: 0.1392 - val_accuracy: 0.8967 - val_loss: 0.3987 - learning_rate: 9.6049e-04
# Epoch 10/1024
#
# Epoch 10: val_loss improved from 0.15917 to 0.12189, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0010-val_loss-0.122-val_accuracy-0.957.keras
# 675/675 - 6s - 9ms/step - accuracy: 0.9552 - loss: 0.1259 - val_accuracy: 0.9567 - val_loss: 0.1219 - learning_rate: 9.5620e-04
# Epoch 11/1024
#
# Epoch 11: val_loss did not improve from 0.12189
# 675/675 - 6s - 10ms/step - accuracy: 0.9587 - loss: 0.1167 - val_accuracy: 0.9467 - val_loss: 0.1809 - learning_rate: 9.5194e-04
# Epoch 12/1024
#
# Epoch 12: val_loss did not improve from 0.12189
# 675/675 - 7s - 10ms/step - accuracy: 0.9600 - loss: 0.1120 - val_accuracy: 0.9433 - val_loss: 0.1997 - learning_rate: 9.4770e-04
# Epoch 13/1024
#
# Epoch 13: val_loss did not improve from 0.12189
# 675/675 - 7s - 10ms/step - accuracy: 0.9632 - loss: 0.1032 - val_accuracy: 0.9467 - val_loss: 0.1731 - learning_rate: 9.4349e-04
# Epoch 14/1024
#
# Epoch 14: val_loss did not improve from 0.12189
# 675/675 - 7s - 11ms/step - accuracy: 0.9643 - loss: 0.0999 - val_accuracy: 0.8900 - val_loss: 0.3661 - learning_rate: 9.3929e-04
# Epoch 15/1024
#
# Epoch 15: val_loss did not improve from 0.12189
# 675/675 - 6s - 9ms/step - accuracy: 0.9672 - loss: 0.0938 - val_accuracy: 0.9400 - val_loss: 0.1681 - learning_rate: 9.3511e-04
# Epoch 16/1024
#
# Epoch 16: val_loss did not improve from 0.12189
# 675/675 - 7s - 10ms/step - accuracy: 0.9716 - loss: 0.0802 - val_accuracy: 0.9500 - val_loss: 0.2011 - learning_rate: 9.3096e-04
# Epoch 17/1024
#
# Epoch 17: val_loss did not improve from 0.12189
# 675/675 - 8s - 11ms/step - accuracy: 0.9756 - loss: 0.0736 - val_accuracy: 0.8000 - val_loss: 0.7179 - learning_rate: 9.2682e-04
# Epoch 18/1024
#
# Epoch 18: val_loss did not improve from 0.12189
# 675/675 - 8s - 12ms/step - accuracy: 0.9744 - loss: 0.0690 - val_accuracy: 0.9033 - val_loss: 0.3113 - learning_rate: 9.2271e-04
# Epoch 19/1024
#
# Epoch 19: val_loss did not improve from 0.12189
# 675/675 - 7s - 11ms/step - accuracy: 0.9737 - loss: 0.0726 - val_accuracy: 0.9433 - val_loss: 0.1573 - learning_rate: 9.1861e-04
# Epoch 20/1024
#
# Epoch 20: val_loss improved from 0.12189 to 0.11060, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0020-val_loss-0.111-val_accuracy-0.963.keras
# 675/675 - 8s - 11ms/step - accuracy: 0.9775 - loss: 0.0647 - val_accuracy: 0.9633 - val_loss: 0.1106 - learning_rate: 9.1454e-04
# Epoch 21/1024
#
# Epoch 21: val_loss did not improve from 0.11060
# 675/675 - 7s - 10ms/step - accuracy: 0.9787 - loss: 0.0621 - val_accuracy: 0.9433 - val_loss: 0.1952 - learning_rate: 9.1049e-04
# Epoch 22/1024
#
# Epoch 22: val_loss did not improve from 0.11060
# 675/675 - 7s - 11ms/step - accuracy: 0.9807 - loss: 0.0550 - val_accuracy: 0.9467 - val_loss: 0.2099 - learning_rate: 9.0645e-04
# Epoch 23/1024
#
# Epoch 23: val_loss did not improve from 0.11060
# 675/675 - 7s - 11ms/step - accuracy: 0.9826 - loss: 0.0548 - val_accuracy: 0.9433 - val_loss: 0.2148 - learning_rate: 9.0244e-04
# Epoch 24/1024
#
# Epoch 24: val_loss did not improve from 0.11060
# 675/675 - 7s - 11ms/step - accuracy: 0.9777 - loss: 0.0594 - val_accuracy: 0.9433 - val_loss: 0.2118 - learning_rate: 8.9845e-04
# Epoch 25/1024
#
# Epoch 25: val_loss did not improve from 0.11060
# 675/675 - 7s - 10ms/step - accuracy: 0.9807 - loss: 0.0544 - val_accuracy: 0.9467 - val_loss: 0.1180 - learning_rate: 8.9447e-04
# Epoch 26/1024
#
# Epoch 26: val_loss did not improve from 0.11060
# 675/675 - 7s - 10ms/step - accuracy: 0.9849 - loss: 0.0421 - val_accuracy: 0.9233 - val_loss: 0.2676 - learning_rate: 8.9052e-04
# Epoch 27/1024
#
# Epoch 27: val_loss improved from 0.11060 to 0.10988, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0027-val_loss-0.110-val_accuracy-0.963.keras
# 675/675 - 7s - 10ms/step - accuracy: 0.9824 - loss: 0.0486 - val_accuracy: 0.9633 - val_loss: 0.1099 - learning_rate: 8.8659e-04
# Epoch 28/1024
#
# Epoch 28: val_loss did not improve from 0.10988
# 675/675 - 7s - 10ms/step - accuracy: 0.9820 - loss: 0.0510 - val_accuracy: 0.4233 - val_loss: 3.3507 - learning_rate: 8.8267e-04
# Epoch 29/1024
#
# Epoch 29: val_loss improved from 0.10988 to 0.09719, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0029-val_loss-0.097-val_accuracy-0.963.keras
# 675/675 - 7s - 11ms/step - accuracy: 0.9829 - loss: 0.0485 - val_accuracy: 0.9633 - val_loss: 0.0972 - learning_rate: 8.7878e-04
# Epoch 30/1024
#
# Epoch 30: val_loss did not improve from 0.09719
# 675/675 - 7s - 10ms/step - accuracy: 0.9864 - loss: 0.0402 - val_accuracy: 0.9567 - val_loss: 0.1499 - learning_rate: 8.7490e-04
# Epoch 31/1024
#
# Epoch 31: val_loss did not improve from 0.09719
# 675/675 - 7s - 10ms/step - accuracy: 0.9868 - loss: 0.0380 - val_accuracy: 0.9700 - val_loss: 0.1090 - learning_rate: 8.7105e-04
# Epoch 32/1024
#
# Epoch 32: val_loss did not improve from 0.09719
# 675/675 - 7s - 10ms/step - accuracy: 0.9872 - loss: 0.0363 - val_accuracy: 0.9000 - val_loss: 0.2540 - learning_rate: 8.6721e-04
# Epoch 33/1024
#
# Epoch 33: val_loss did not improve from 0.09719
# 675/675 - 6s - 10ms/step - accuracy: 0.9893 - loss: 0.0328 - val_accuracy: 0.9667 - val_loss: 0.1451 - learning_rate: 8.6339e-04
# Epoch 34/1024
#
# Epoch 34: val_loss did not improve from 0.09719
# 675/675 - 7s - 10ms/step - accuracy: 0.9894 - loss: 0.0339 - val_accuracy: 0.9167 - val_loss: 0.3430 - learning_rate: 8.5959e-04
# Epoch 35/1024
#
# Epoch 35: val_loss did not improve from 0.09719
# 675/675 - 7s - 11ms/step - accuracy: 0.9880 - loss: 0.0333 - val_accuracy: 0.9467 - val_loss: 0.1681 - learning_rate: 8.5581e-04
# Epoch 36/1024
#
# Epoch 36: val_loss did not improve from 0.09719
# 675/675 - 7s - 11ms/step - accuracy: 0.9885 - loss: 0.0366 - val_accuracy: 0.9700 - val_loss: 0.1073 - learning_rate: 8.5205e-04
# Epoch 37/1024
#
# Epoch 37: val_loss did not improve from 0.09719
# 675/675 - 7s - 11ms/step - accuracy: 0.9882 - loss: 0.0346 - val_accuracy: 0.9567 - val_loss: 0.1448 - learning_rate: 8.4831e-04
# Epoch 38/1024
#
# Epoch 38: val_loss improved from 0.09719 to 0.07727, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0038-val_loss-0.077-val_accuracy-0.983.keras
# 675/675 - 7s - 11ms/step - accuracy: 0.9889 - loss: 0.0327 - val_accuracy: 0.9833 - val_loss: 0.0773 - learning_rate: 8.4459e-04
# Epoch 39/1024
#
# Epoch 39: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9927 - loss: 0.0225 - val_accuracy: 0.9067 - val_loss: 0.3874 - learning_rate: 8.4088e-04
# Epoch 40/1024
#
# Epoch 40: val_loss did not improve from 0.07727
# 675/675 - 6s - 9ms/step - accuracy: 0.9885 - loss: 0.0342 - val_accuracy: 0.9533 - val_loss: 0.1617 - learning_rate: 8.3720e-04
# Epoch 41/1024
#
# Epoch 41: val_loss did not improve from 0.07727
# 675/675 - 7s - 10ms/step - accuracy: 0.9927 - loss: 0.0229 - val_accuracy: 0.9533 - val_loss: 0.1805 - learning_rate: 8.3353e-04
# Epoch 42/1024
#
# Epoch 42: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9908 - loss: 0.0245 - val_accuracy: 0.9800 - val_loss: 0.1190 - learning_rate: 8.2988e-04
# Epoch 43/1024
#
# Epoch 43: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9898 - loss: 0.0326 - val_accuracy: 0.9667 - val_loss: 0.1260 - learning_rate: 8.2625e-04
# Epoch 44/1024
#
# Epoch 44: val_loss did not improve from 0.07727
# 675/675 - 8s - 11ms/step - accuracy: 0.9893 - loss: 0.0283 - val_accuracy: 0.9733 - val_loss: 0.1076 - learning_rate: 8.2263e-04
# Epoch 45/1024
#
# Epoch 45: val_loss did not improve from 0.07727
# 675/675 - 7s - 10ms/step - accuracy: 0.9924 - loss: 0.0214 - val_accuracy: 0.9500 - val_loss: 0.2109 - learning_rate: 8.1904e-04
# Epoch 46/1024
#
# Epoch 46: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9936 - loss: 0.0194 - val_accuracy: 0.9467 - val_loss: 0.2140 - learning_rate: 8.1546e-04
# Epoch 47/1024
#
# Epoch 47: val_loss did not improve from 0.07727
# 675/675 - 7s - 10ms/step - accuracy: 0.9913 - loss: 0.0248 - val_accuracy: 0.9567 - val_loss: 0.1927 - learning_rate: 8.1190e-04
# Epoch 48/1024
#
# Epoch 48: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9914 - loss: 0.0255 - val_accuracy: 0.9100 - val_loss: 0.2976 - learning_rate: 8.0835e-04
# Epoch 49/1024
#
# Epoch 49: val_loss did not improve from 0.07727
# 675/675 - 6s - 9ms/step - accuracy: 0.9938 - loss: 0.0183 - val_accuracy: 0.9733 - val_loss: 0.0993 - learning_rate: 8.0483e-04
# Epoch 50/1024
#
# Epoch 50: val_loss did not improve from 0.07727
# 675/675 - 7s - 10ms/step - accuracy: 0.9917 - loss: 0.0219 - val_accuracy: 0.9700 - val_loss: 0.1176 - learning_rate: 8.0132e-04
# Epoch 51/1024
#
# Epoch 51: val_loss did not improve from 0.07727
# 675/675 - 8s - 11ms/step - accuracy: 0.9925 - loss: 0.0228 - val_accuracy: 0.9600 - val_loss: 0.1719 - learning_rate: 7.9783e-04
# Epoch 52/1024
#
# Epoch 52: val_loss did not improve from 0.07727
# 675/675 - 7s - 10ms/step - accuracy: 0.9926 - loss: 0.0215 - val_accuracy: 0.9633 - val_loss: 0.2144 - learning_rate: 7.9436e-04
# Epoch 53/1024
#
# Epoch 53: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9949 - loss: 0.0187 - val_accuracy: 0.9600 - val_loss: 0.1232 - learning_rate: 7.9091e-04
# Epoch 54/1024
#
# Epoch 54: val_loss did not improve from 0.07727
# 675/675 - 7s - 11ms/step - accuracy: 0.9904 - loss: 0.0299 - val_accuracy: 0.9700 - val_loss: 0.1735 - learning_rate: 7.8747e-04
# Epoch 55/1024
#
# Epoch 55: val_loss did not improve from 0.07727
# 675/675 - 8s - 11ms/step - accuracy: 0.9936 - loss: 0.0189 - val_accuracy: 0.9600 - val_loss: 0.1834 - learning_rate: 7.8405e-04
# Epoch 56/1024
#
# Epoch 56: val_loss improved from 0.07727 to 0.07086, saving model to /home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0056-val_loss-0.071-val_accuracy-0.980.keras
# 675/675 - 8s - 11ms/step - accuracy: 0.9931 - loss: 0.0209 - val_accuracy: 0.9800 - val_loss: 0.0709 - learning_rate: 7.8064e-04
# Epoch 57/1024
#
# Epoch 57: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9915 - loss: 0.0216 - val_accuracy: 0.9767 - val_loss: 0.1359 - learning_rate: 7.7726e-04
# Epoch 58/1024
#
# Epoch 58: val_loss did not improve from 0.07086
# 675/675 - 6s - 10ms/step - accuracy: 0.9935 - loss: 0.0191 - val_accuracy: 0.9400 - val_loss: 0.2195 - learning_rate: 7.7389e-04
# Epoch 59/1024
#
# Epoch 59: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9947 - loss: 0.0164 - val_accuracy: 0.9600 - val_loss: 0.1600 - learning_rate: 7.7053e-04
# Epoch 60/1024
#
# Epoch 60: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9932 - loss: 0.0206 - val_accuracy: 0.9667 - val_loss: 0.1886 - learning_rate: 7.6720e-04
# Epoch 61/1024
#
# Epoch 61: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9931 - loss: 0.0204 - val_accuracy: 0.9667 - val_loss: 0.1749 - learning_rate: 7.6388e-04
# Epoch 62/1024
#
# Epoch 62: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.9667 - val_loss: 0.1613 - learning_rate: 7.6057e-04
# Epoch 63/1024
#
# Epoch 63: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9930 - loss: 0.0178 - val_accuracy: 0.9400 - val_loss: 0.1993 - learning_rate: 7.5728e-04
# Epoch 64/1024
#
# Epoch 64: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9959 - loss: 0.0123 - val_accuracy: 0.9700 - val_loss: 0.1468 - learning_rate: 7.5401e-04
# Epoch 65/1024
#
# Epoch 65: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9920 - loss: 0.0225 - val_accuracy: 0.9733 - val_loss: 0.1110 - learning_rate: 7.5076e-04
# Epoch 66/1024
#
# Epoch 66: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9948 - loss: 0.0169 - val_accuracy: 0.9700 - val_loss: 0.1060 - learning_rate: 7.4752e-04
# Epoch 67/1024
#
# Epoch 67: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9949 - loss: 0.0134 - val_accuracy: 0.9500 - val_loss: 0.1702 - learning_rate: 7.4430e-04
# Epoch 68/1024
#
# Epoch 68: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9967 - loss: 0.0093 - val_accuracy: 0.9767 - val_loss: 0.0984 - learning_rate: 7.4109e-04
# Epoch 69/1024
#
# Epoch 69: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9956 - loss: 0.0127 - val_accuracy: 0.9633 - val_loss: 0.1623 - learning_rate: 7.3790e-04
# Epoch 70/1024
#
# Epoch 70: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9935 - loss: 0.0196 - val_accuracy: 0.9467 - val_loss: 0.2594 - learning_rate: 7.3473e-04
# Epoch 71/1024
#
# Epoch 71: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9946 - loss: 0.0162 - val_accuracy: 0.9567 - val_loss: 0.1697 - learning_rate: 7.3157e-04
# Epoch 72/1024
#
# Epoch 72: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9969 - loss: 0.0109 - val_accuracy: 0.9800 - val_loss: 0.1542 - learning_rate: 7.2843e-04
# Epoch 73/1024
#
# Epoch 73: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9971 - loss: 0.0088 - val_accuracy: 0.9767 - val_loss: 0.1308 - learning_rate: 7.2530e-04
# Epoch 74/1024
#
# Epoch 74: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9949 - loss: 0.0143 - val_accuracy: 0.9433 - val_loss: 0.3161 - learning_rate: 7.2219e-04
# Epoch 75/1024
#
# Epoch 75: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9956 - loss: 0.0151 - val_accuracy: 0.9700 - val_loss: 0.1197 - learning_rate: 7.1909e-04
# Epoch 76/1024
#
# Epoch 76: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9957 - loss: 0.0126 - val_accuracy: 0.9667 - val_loss: 0.2308 - learning_rate: 7.1601e-04
# Epoch 77/1024
#
# Epoch 77: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.9667 - val_loss: 0.2450 - learning_rate: 7.1295e-04
# Epoch 78/1024
#
# Epoch 78: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9971 - loss: 0.0101 - val_accuracy: 0.9767 - val_loss: 0.1407 - learning_rate: 7.0990e-04
# Epoch 79/1024
#
# Epoch 79: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9967 - loss: 0.0103 - val_accuracy: 0.9800 - val_loss: 0.1147 - learning_rate: 7.0686e-04
# Epoch 80/1024
#
# Epoch 80: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.9800 - val_loss: 0.1065 - learning_rate: 7.0384e-04
# Epoch 81/1024
#
# Epoch 81: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9953 - loss: 0.0141 - val_accuracy: 0.9567 - val_loss: 0.1888 - learning_rate: 7.0084e-04
# Epoch 82/1024
#
# Epoch 82: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9977 - loss: 0.0060 - val_accuracy: 0.9633 - val_loss: 0.2087 - learning_rate: 6.9785e-04
# Epoch 83/1024
#
# Epoch 83: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9955 - loss: 0.0146 - val_accuracy: 0.9533 - val_loss: 0.1954 - learning_rate: 6.9487e-04
# Epoch 84/1024
#
# Epoch 84: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9944 - loss: 0.0150 - val_accuracy: 0.9600 - val_loss: 0.1725 - learning_rate: 6.9191e-04
# Epoch 85/1024
#
# Epoch 85: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9976 - loss: 0.0085 - val_accuracy: 0.9600 - val_loss: 0.1721 - learning_rate: 6.8897e-04
# Epoch 86/1024
#
# Epoch 86: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9958 - loss: 0.0134 - val_accuracy: 0.9833 - val_loss: 0.1531 - learning_rate: 6.8604e-04
# Epoch 87/1024
#
# Epoch 87: val_loss did not improve from 0.07086
# 675/675 - 6s - 10ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 0.9700 - val_loss: 0.1368 - learning_rate: 6.8312e-04
# Epoch 88/1024
#
# Epoch 88: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9964 - loss: 0.0109 - val_accuracy: 0.9600 - val_loss: 0.1321 - learning_rate: 6.8022e-04
# Epoch 89/1024
#
# Epoch 89: val_loss did not improve from 0.07086
# 675/675 - 6s - 9ms/step - accuracy: 0.9969 - loss: 0.0106 - val_accuracy: 0.9600 - val_loss: 0.2630 - learning_rate: 6.7733e-04
# Epoch 90/1024
#
# Epoch 90: val_loss did not improve from 0.07086
# 675/675 - 6s - 9ms/step - accuracy: 0.9972 - loss: 0.0091 - val_accuracy: 0.9667 - val_loss: 0.1182 - learning_rate: 6.7446e-04
# Epoch 91/1024
#
# Epoch 91: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9976 - loss: 0.0076 - val_accuracy: 0.9233 - val_loss: 0.5055 - learning_rate: 6.7160e-04
# Epoch 92/1024
#
# Epoch 92: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9978 - loss: 0.0084 - val_accuracy: 0.9367 - val_loss: 0.2383 - learning_rate: 6.6876e-04
# Epoch 93/1024
#
# Epoch 93: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9767 - val_loss: 0.1324 - learning_rate: 6.6592e-04
# Epoch 94/1024
#
# Epoch 94: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9956 - loss: 0.0114 - val_accuracy: 0.9533 - val_loss: 0.2697 - learning_rate: 6.6311e-04
# Epoch 95/1024
#
# Epoch 95: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9980 - loss: 0.0075 - val_accuracy: 0.4300 - val_loss: 5.1124 - learning_rate: 6.6031e-04
# Epoch 96/1024
#
# Epoch 96: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9945 - loss: 0.0151 - val_accuracy: 0.9733 - val_loss: 0.1606 - learning_rate: 6.5752e-04
# Epoch 97/1024
#
# Epoch 97: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9976 - loss: 0.0058 - val_accuracy: 0.9700 - val_loss: 0.1692 - learning_rate: 6.5474e-04
# Epoch 98/1024
#
# Epoch 98: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9767 - val_loss: 0.1365 - learning_rate: 6.5198e-04
# Epoch 99/1024
#
# Epoch 99: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9965 - loss: 0.0102 - val_accuracy: 0.9667 - val_loss: 0.2527 - learning_rate: 6.4924e-04
# Epoch 100/1024
#
# Epoch 100: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9953 - loss: 0.0134 - val_accuracy: 0.9633 - val_loss: 0.1977 - learning_rate: 6.4650e-04
# Epoch 101/1024
#
# Epoch 101: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9767 - val_loss: 0.1146 - learning_rate: 6.4378e-04
# Epoch 102/1024
#
# Epoch 102: val_loss did not improve from 0.07086
# 675/675 - 6s - 9ms/step - accuracy: 0.9981 - loss: 0.0062 - val_accuracy: 0.9833 - val_loss: 0.1429 - learning_rate: 6.4108e-04
# Epoch 103/1024
#
# Epoch 103: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9982 - loss: 0.0070 - val_accuracy: 0.9700 - val_loss: 0.1360 - learning_rate: 6.3839e-04
# Epoch 104/1024
#
# Epoch 104: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.9733 - val_loss: 0.1280 - learning_rate: 6.3571e-04
# Epoch 105/1024
#
# Epoch 105: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9975 - loss: 0.0068 - val_accuracy: 0.9733 - val_loss: 0.1465 - learning_rate: 6.3304e-04
# Epoch 106/1024
#
# Epoch 106: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.9800 - val_loss: 0.1357 - learning_rate: 6.3039e-04
# Epoch 107/1024
#
# Epoch 107: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9733 - val_loss: 0.1190 - learning_rate: 6.2775e-04
# Epoch 108/1024
#
# Epoch 108: val_loss did not improve from 0.07086
# 675/675 - 7s - 11ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9833 - val_loss: 0.0892 - learning_rate: 6.2512e-04
# Epoch 109/1024
#
# Epoch 109: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.9700 - val_loss: 0.1232 - learning_rate: 6.2251e-04
# Epoch 110/1024
#
# Epoch 110: val_loss did not improve from 0.07086
# 675/675 - 5s - 7ms/step - accuracy: 0.9973 - loss: 0.0080 - val_accuracy: 0.9767 - val_loss: 0.1588 - learning_rate: 6.1991e-04
# Epoch 111/1024
#
# Epoch 111: val_loss did not improve from 0.07086
# 675/675 - 5s - 8ms/step - accuracy: 0.9972 - loss: 0.0078 - val_accuracy: 0.9700 - val_loss: 0.1334 - learning_rate: 6.1732e-04
# Epoch 112/1024
#
# Epoch 112: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9971 - loss: 0.0093 - val_accuracy: 0.9767 - val_loss: 0.1376 - learning_rate: 6.1475e-04
# Epoch 113/1024
#
# Epoch 113: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9800 - val_loss: 0.1235 - learning_rate: 6.1219e-04
# Epoch 114/1024
#
# Epoch 114: val_loss did not improve from 0.07086
# 675/675 - 8s - 13ms/step - accuracy: 0.9970 - loss: 0.0092 - val_accuracy: 0.9700 - val_loss: 0.1619 - learning_rate: 6.0964e-04
# Epoch 115/1024
#
# Epoch 115: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9981 - loss: 0.0065 - val_accuracy: 0.9800 - val_loss: 0.0855 - learning_rate: 6.0710e-04
# Epoch 116/1024
#
# Epoch 116: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9733 - val_loss: 0.1274 - learning_rate: 6.0458e-04
# Epoch 117/1024
#
# Epoch 117: val_loss did not improve from 0.07086
# 675/675 - 5s - 7ms/step - accuracy: 0.9983 - loss: 0.0077 - val_accuracy: 0.9767 - val_loss: 0.1391 - learning_rate: 6.0207e-04
# Epoch 118/1024
#
# Epoch 118: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9969 - loss: 0.0087 - val_accuracy: 0.9767 - val_loss: 0.1327 - learning_rate: 5.9957e-04
# Epoch 119/1024
#
# Epoch 119: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9984 - loss: 0.0041 - val_accuracy: 0.9700 - val_loss: 0.1225 - learning_rate: 5.9708e-04
# Epoch 120/1024
#
# Epoch 120: val_loss did not improve from 0.07086
# 675/675 - 8s - 13ms/step - accuracy: 0.9980 - loss: 0.0072 - val_accuracy: 0.9767 - val_loss: 0.1198 - learning_rate: 5.9461e-04
# Epoch 121/1024
#
# Epoch 121: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9700 - val_loss: 0.1809 - learning_rate: 5.9215e-04
# Epoch 122/1024
#
# Epoch 122: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9667 - val_loss: 0.1935 - learning_rate: 5.8970e-04
# Epoch 123/1024
#
# Epoch 123: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9972 - loss: 0.0076 - val_accuracy: 0.9600 - val_loss: 0.2490 - learning_rate: 5.8726e-04
# Epoch 124/1024
#
# Epoch 124: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9985 - loss: 0.0054 - val_accuracy: 0.9733 - val_loss: 0.1390 - learning_rate: 5.8484e-04
# Epoch 125/1024
#
# Epoch 125: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9974 - loss: 0.0073 - val_accuracy: 0.9833 - val_loss: 0.1246 - learning_rate: 5.8243e-04
# Epoch 126/1024
#
# Epoch 126: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9970 - loss: 0.0078 - val_accuracy: 0.9800 - val_loss: 0.1376 - learning_rate: 5.8003e-04
# Epoch 127/1024
#
# Epoch 127: val_loss did not improve from 0.07086
# 675/675 - 8s - 13ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9733 - val_loss: 0.1454 - learning_rate: 5.7764e-04
# Epoch 128/1024
#
# Epoch 128: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 0.9667 - val_loss: 0.1902 - learning_rate: 5.7526e-04
# Epoch 129/1024
#
# Epoch 129: val_loss did not improve from 0.07086
# 675/675 - 8s - 13ms/step - accuracy: 0.9986 - loss: 0.0039 - val_accuracy: 0.9733 - val_loss: 0.2332 - learning_rate: 5.7290e-04
# Epoch 130/1024
#
# Epoch 130: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.9733 - val_loss: 0.1394 - learning_rate: 5.7054e-04
# Epoch 131/1024
#
# Epoch 131: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9733 - val_loss: 0.1388 - learning_rate: 5.6820e-04
# Epoch 132/1024
#
# Epoch 132: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9981 - loss: 0.0068 - val_accuracy: 0.9800 - val_loss: 0.2034 - learning_rate: 5.6587e-04
# Epoch 133/1024
#
# Epoch 133: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9981 - loss: 0.0050 - val_accuracy: 0.9800 - val_loss: 0.1379 - learning_rate: 5.6355e-04
# Epoch 134/1024
#
# Epoch 134: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9800 - val_loss: 0.1274 - learning_rate: 5.6125e-04
# Epoch 135/1024
#
# Epoch 135: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9984 - loss: 0.0041 - val_accuracy: 0.9800 - val_loss: 0.1170 - learning_rate: 5.5895e-04
# Epoch 136/1024
#
# Epoch 136: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9600 - val_loss: 0.2191 - learning_rate: 5.5667e-04
# Epoch 137/1024
#
# Epoch 137: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9985 - loss: 0.0037 - val_accuracy: 0.9800 - val_loss: 0.1271 - learning_rate: 5.5439e-04
# Epoch 138/1024
#
# Epoch 138: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9989 - loss: 0.0027 - val_accuracy: 0.9833 - val_loss: 0.1095 - learning_rate: 5.5213e-04
# Epoch 139/1024
#
# Epoch 139: val_loss did not improve from 0.07086
# 675/675 - 9s - 13ms/step - accuracy: 0.9969 - loss: 0.0111 - val_accuracy: 0.9633 - val_loss: 0.2121 - learning_rate: 5.4988e-04
# Epoch 140/1024
#
# Epoch 140: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9985 - loss: 0.0038 - val_accuracy: 0.9767 - val_loss: 0.1861 - learning_rate: 5.4764e-04
# Epoch 141/1024
#
# Epoch 141: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.9767 - val_loss: 0.1394 - learning_rate: 5.4542e-04
# Epoch 142/1024
#
# Epoch 142: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9833 - val_loss: 0.1546 - learning_rate: 5.4320e-04
# Epoch 143/1024
#
# Epoch 143: val_loss did not improve from 0.07086
# 675/675 - 8s - 13ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9733 - val_loss: 0.1611 - learning_rate: 5.4100e-04
# Epoch 144/1024
#
# Epoch 144: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9633 - val_loss: 0.2289 - learning_rate: 5.3880e-04
# Epoch 145/1024
#
# Epoch 145: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9733 - val_loss: 0.1635 - learning_rate: 5.3662e-04
# Epoch 146/1024
#
# Epoch 146: val_loss did not improve from 0.07086
# 675/675 - 8s - 12ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9767 - val_loss: 0.1462 - learning_rate: 5.3444e-04
# Epoch 147/1024
#
# Epoch 147: val_loss did not improve from 0.07086
# 675/675 - 8s - 11ms/step - accuracy: 0.9973 - loss: 0.0072 - val_accuracy: 0.9833 - val_loss: 0.1019 - learning_rate: 5.3228e-04
# Epoch 148/1024
#
# Epoch 148: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9667 - val_loss: 0.1697 - learning_rate: 5.3013e-04
# Epoch 149/1024
#
# Epoch 149: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9988 - loss: 0.0031 - val_accuracy: 0.9667 - val_loss: 0.1704 - learning_rate: 5.2799e-04
# Epoch 150/1024
#
# Epoch 150: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9980 - loss: 0.0079 - val_accuracy: 0.9767 - val_loss: 0.1173 - learning_rate: 5.2586e-04
# Epoch 151/1024
#
# Epoch 151: val_loss did not improve from 0.07086
# 675/675 - 6s - 9ms/step - accuracy: 0.9985 - loss: 0.0038 - val_accuracy: 0.9800 - val_loss: 0.1465 - learning_rate: 5.2374e-04
# Epoch 152/1024
#
# Epoch 152: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9667 - val_loss: 0.2425 - learning_rate: 5.2163e-04
# Epoch 153/1024
#
# Epoch 153: val_loss did not improve from 0.07086
# 675/675 - 6s - 9ms/step - accuracy: 0.9971 - loss: 0.0084 - val_accuracy: 0.9733 - val_loss: 0.1279 - learning_rate: 5.1954e-04
# Epoch 154/1024
#
# Epoch 154: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9767 - val_loss: 0.1585 - learning_rate: 5.1745e-04
# Epoch 155/1024
#
# Epoch 155: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9733 - val_loss: 0.1586 - learning_rate: 5.1537e-04
# Epoch 156/1024
#
# Epoch 156: val_loss did not improve from 0.07086
# 675/675 - 7s - 10ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9667 - val_loss: 0.1783 - learning_rate: 5.1330e-04
# Epoch 156: early stopping

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
history = sauvegardeHistorique(model_history,
                               repertoireSauvegardes,
                               nomSauvegarde='history_batch_size_32')

# %%
afficheHistoriqueEntrainement(history, palette, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %%
sauvegarderModel(model, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du modèle </div></b>

# %%
model = tf.keras.models.load_model(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
for i, (img,lab) in enumerate(pipeline_validation):
    if i == 0 : 
        images, labels = img,lab
    else:
        images, labels = tf.concat([images,img], 0), tf.concat([labels,lab], 0)

# %%
probabilities = model.predict(images, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(48,16));
for i in range(4):
    afficheProbabilites(probabilities,ind=i,ax=ax[i], dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=labels,predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=images,
                                                  y_test=labels,
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Area under the ROC curve : 0.9957	--	Exécution  :7.72s
#       Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0     global  0.995679    0.991705  0.966618  0.966587  0.966832  0.966667
# 1      Botte  0.999949    0.999897  0.989796  0.989796  0.989796  0.993333
# 2    Sandale  0.994748    0.981787  0.951923  0.941065  0.963035  0.966667
# 3  Chaussure  0.992341    0.992111  0.959184  0.971074  0.947581  0.973333
#
#    precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0   0.967075     0.966667             290             590             10
# 1   0.989796     0.989796              97             201              1
# 2   0.970588     0.933962              99             191              3
# 3   0.940000     0.979167              94             198              6
#
#    faux_negatifs  total_positifs    essai
# 0             10             300  initial
# 1              1              98  initial
# 2              7             106  initial
# 3              2              96  initial

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du meilleur modèle</div></b>

# %%
model = tf.keras.models.load_model("/home/razvan/documentation/DeepLearning/CNN/09-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0056-val_loss-0.071-val_accuracy-0.980.keras")

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
for i, (img,lab) in enumerate(pipeline_validation):
    if i == 0 : 
        images, labels = img,lab
    else:
        images, labels = tf.concat([images,img], 0), tf.concat([labels,lab], 0)

# %%
probabilities = model.predict(images, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(48,16));
for i in range(4):
    afficheProbabilites(probabilities,ind=i,ax=ax[i], dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=labels,predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=images,
                                                  y_test=labels,
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Area under the ROC curve : 0.9976	--	Exécution  :7.62s
#       Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0     global  0.997644    0.995830  0.980035  0.980010  0.980072  0.980000
# 1      Botte  0.999949    0.999897  0.994872  0.991820  0.997942  0.996667
# 2    Sandale  0.996353    0.990749  0.971698  0.971698  0.971698  0.980000
# 3  Chaussure  0.996630    0.995417  0.974093  0.977131  0.971074  0.983333
#
#    precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0   0.980103     0.980000             294             594              6
# 1   1.000000     0.989796              97             202              0
# 2   0.971698     0.971698             103             191              3
# 3   0.969072     0.979167              94             201              3
#
#    faux_negatifs  total_positifs    essai
# 0              6             300  initial
# 1              1              98  initial
# 2              3             106  initial
# 3              2              96  initial
