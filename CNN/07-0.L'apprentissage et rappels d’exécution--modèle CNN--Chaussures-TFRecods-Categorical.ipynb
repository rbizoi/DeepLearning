# %% [markdown]
# <table>
# <tr>
#      <th>
#          <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'><a href="https://www.kaggle.com/datasets/adityakadam1/footwear">Reconnaissance des Chaussures</a></div>
#      </th>
#      <th><img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/chaussures.png" width="96"></th>
#  </tr>
# </table>
#
#
#
# **Reconnaissance des Chaussures**<br>
# Le jeu de données contient **3 000** images de fleurs étiquetées en **3** classes.
#
# <table>
#     <tr>
#          <th  style="text-align:left;background-color:#053061;color:white;">Valeur</th>
#          <th  style="text-align:left;background-color:#053061;color:white;">Nom classe</th>
#      </tr>
#     <tr>
#         <th  style="text-align:left">0</th>
#         <th  style="text-align:left">Botte</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">1</th>
#         <th  style="text-align:left">Sandale</th>
#     </tr>
#     <tr>
#         <th  style="text-align:left">2</th>
#         <th  style="text-align:left">Chaussure</th>
#     </tr>
# </table>
#
# > https://www.larousse.fr/dictionnaires/francais/inf%C3%A9rence/42907<br><br>
#
# >> **inférence** : Opération par laquelle on passe d'une assertion considérée comme vraie à une autre assertion au moyen d'un système de règles qui rend cette deuxième assertion également vraie.<br>
#
# >> **Inférence statistique** : Ensemble des méthodes permettant de formuler en termes probabilistes un jugement sur une population à partir des résultats observés sur un échantillon extrait au hasard de cette population.<br>
#
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ['TF_XLA_FLAGS']='--tf_xla_auto_jit=1,--tf_xla_always_defer_compilation=true'
# os.environ['XLA_FLAGS']='--xla_backend_optimization_level=0,--xla_gpu_autotune_level=4,--xla_gpu_disable_ptxas_optimizations=true,--xla_gpu_use_cudnn_batchnorm_level=2'
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, pickle, time
from matplotlib import pyplot as plt
from datetime import datetime as dt

import matplotlib.font_manager as fm
from matplotlib.lines import Line2D

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist,fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm

from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer, confusion_matrix, roc_curve, auc, accuracy_score, log_loss, hamming_loss, \
                            precision_score, recall_score, f1_score, fbeta_score, jaccard_score, \
                            precision_recall_curve, average_precision_score, balanced_accuracy_score, \
                            classification_report,roc_auc_score

tf.get_logger().setLevel('ERROR')# Suppress TensorFlow logging (2)

# %%
print("Tensorflow\t : %s\tCUDA %s\tGPU %s\tXLA %s\nKeras\t\t : %s\nPandas\t\t : %s\nNumPy\t\t : %s"%
      (tf.__version__, 
       tf.test.is_built_with_cuda(), 
       tf.test.is_built_with_gpu_support(), 
       tf.test.is_built_with_xla(), 
       tf.keras.__version__, 
       pd.__version__, 
       np.__version__))
# Out:
# Tensorflow	 : 2.17.0	CUDA True	GPU True	XLA True
# Keras		 : 3.6.0
# Pandas		 : 2.2.2
# NumPy		 : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des GPUs presents</div></b>

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
physical_devices = tf.config.experimental.list_physical_devices('GPU')

if len(physical_devices) >  0 :
    for i, gpu in enumerate(physical_devices):
        tf.config.experimental.set_memory_growth(physical_devices[i], True)

    strategy = tf.distribute.experimental.CentralStorageStrategy()
    print('Le système est initialisé avec {0:d} GPUs'.format(strategy.num_replicas_in_sync))
# Out:
# Le système est initialisé avec 1 GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751909060.137224 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.158908 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.159022 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751909060.165372 2531695 service.cc:146] XLA service 0x39a8c8d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751909060.165391 2531695 service.cc:154]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1751909060.231863 2531854 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.231988 2531695 service.cc:146] XLA service 0x36e27f10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751909060.232000 2531695 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1751909060.232133 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.232217 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.232271 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.235578 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1751909060.235666 2531695 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
palette = [
            "#030aa7", "#e50000", "#d8863b", "#005f6a", "#6b7c85", "#751973", "#d1e5f0", "#fddbc7",
            "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#f5054f", "#a0450e",
            "#0339f8", "#f4320c", "#fec615", "#017a79", "#85a3b2", "#fe2f4a", "#a00498", "#b04e0f",
            "#0165fc", "#ff724c", "#fddc5c", "#11875d", "#89a0b0", "#fe828c", "#cb00f5", "#b75203",
            "#0485d1", "#ff7855", "#fbeeac", "#0cb577", "#95a3a6", "#ffb7ce", "#c071fe", "#ca6b02",
            "#92c5de", "#f4a582", "#fef69e", "#18d17b", "#c5c9c7", "#ffcfdc", "#caa0ff", "#cb7723",
            "#d1e5f0", "#fddbc7", "#ffffcb", "#12e193", "#d8dcd6", "#ffdaf0", "#dfc5fe", "#d8863b",
            "#030764", "#be0119", "#dbb40c", "#005249", "#3c4142", "#cb0162", "#5d1451", "#653700",
            "#040348", "#67001f", "#b27a01", "#002d04", "#000000", "#a0025c", "#490648", "#3c0008"
          ]

# %%
nom_projet                = "07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods"
repertoireProjet          = os.getcwd()
repertoireEnregistrement  = repertoireProjet +'/'+nom_projet+ '/repertoire.images'
repertoireSauvegardes     = repertoireProjet +'/'+nom_projet+ '/repertoire.sauvegardes'

def controleExistenceRepertoire(directory, create_if_needed=True):
    """Voir si le répertoire existe. S'il n'existe pas il est créé."""
    path_exists = os.path.exists(directory)
    if path_exists:
        if not os.path.isdir(directory):
            raise Exception("Trouvé le nom "+directory+" mais c'est un fichier, pas un répertoire")
            return False
        return True
    if create_if_needed:
        os.makedirs(directory)
        
controleExistenceRepertoire(repertoireEnregistrement)
controleExistenceRepertoire(repertoireSauvegardes)

def sauvegarderImage( fichier):
    """Enregistrez la figure. Appelez la méthode juste avant plt.show ()."""
    plt.savefig(os.path.join(repertoireEnregistrement,
                             fichier+f"--{dt.now().strftime('%Y_%m_%d_%H.%M.%S')}.png"), 
                             dpi=600, 
                             bbox_inches='tight')
    
def sauvegarderModelPoids(model, fichierPoids, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez les poids du modèle Keras."""
    if fichierPoids != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichierPoids))
        model.save_weights(nomFichier)

def sauvegarderModel(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Enregistrez le modèle Keras."""
    if fichier != None:
        controleExistenceRepertoire(repertoireSauvegardes)
        nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
        model.save(nomFichier)

def lectureModelPoids(model, fichier, repertoireSauvegardes=repertoireSauvegardes):
    """Si le fichier existe, il est chargé et retourne True, sinon retourne False."""
    nomFichier = os.path.join(repertoireSauvegardes, '{}.keras'.format(fichier))
    if os.path.exists(nomFichier):
        if os.path.isfile(nomFichier):
            model.load_weights(nomFichier)
            return True
    return False

def sauvegardeHistorique(model,
                         repertoireSauvegardes,
                         nomSauvegarde='one_hidden_layer_history_batch_size_1'):

    history = pd.DataFrame( model.history)
    history.reset_index(inplace=True)
    history.rename(columns={'index':'epoch'},inplace=True)
    history.to_parquet(os.path.join(repertoireSauvegardes,f'{nomSauvegarde}.gzip'),compression='gzip', engine='pyarrow') 
    return history


def afficheHistoriqueEntrainement(history, palette, nom):
    fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(48,16));
    markersize = 8
    linewidth=2
    
    graph = sns.lineplot(x='epoch', 
                         y='accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_accuracy',  
                         data=history,
                         ax=ax[0],      
                         label='val_accuracy',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
        
    ax[0].set_title(f'Accuracy {nom}', fontproperties=fm.FontProperties(size=32))
    
    graph = sns.lineplot(x='epoch', 
                         y='loss',  
                         data=history,
                         ax=ax[1],      
                         label='loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[0],
                         );
    graph = sns.lineplot(x='epoch', 
                         y='val_loss',  
                         data=history,
                         ax=ax[1],      
                         label='val_loss',
                         err_style=None, 
                         marker='o',
                         markersize=markersize,
                         linewidth=linewidth,
                         color=palette[1],
                         );
    ax[1].set_title(f'Loss {nom}', fontproperties=fm.FontProperties(size=32))
    
    sauvegarderImage(f'afficheHistoriqueEntrainement-{nom}')



def afficheMatriceConfusion(observations,predictions,dictLabels):
    plt.figure(figsize=(8,8))
    sns.set(font_scale=1.5)
    sns.heatmap(pd.crosstab(observations,predictions), 
                fmt= '.0f',
                linewidths=0.3,
                #vmax=1.0, 
                square=True, 
                cmap=plt.cm.Blues,
                linecolor='white', 
                annot=True,
                cbar=False,
                xticklabels=dictLabels.values(), 
                yticklabels=dictLabels.values()
               );
    plt.xlabel('Observations', fontsize = 18);
    plt.ylabel('Prédictions', fontsize = 18);
    sauvegarderImage('afficheMatriceConfusion')

def executeApprentissageChoixClassifieurs(model,
                                          X_test,
                                          y_test,
                                          label_dict,
                                          couleurs,
                                          nom_essai = 'initial'
                                         ):
    
    def afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict):
        plt.figure(figsize=(24, 24));
        for i, color in zip(range(nbClasses), palette):
            plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
                     label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
                                                             ''.format(i, aucROCt[i]))
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('Taux de faux Positifs-(1 - Spécificité) = VN / (FP + VN)',size=18)
        plt.ylabel('Taux de vrais positifs-Sensibilité = VP / (VP + FN)',size=18)
        plt.title('Courbe ROC (Receiver Operating Caracteristic) -- ',size=20)
        plt.legend(loc="lower right"); #, fontsize='large'
        sauvegarderImage('Courbe ROC')
        
        plt.figure(figsize=(24,24));
    
        f_scores = np.linspace(0.2, 0.9, num=8)
        for f_score in f_scores:
            x = np.linspace(0.01, 1)
            y = f_score * x / (2 * x - f_score)
            l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
            plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))
    
        for i, color in zip(range(nbClasses), palette):
            plt.step(sensibilites[i], 
                         precisions[i], 
                         where='post', 
                         color=color, 
                         lw=lw, 
                         label=f"{label_dict[i]}(APR = {avgPrecRec[label_dict[i]]:0.8f})"
                    )
            plt.fill_between(sensibilites[i], precisions[i], step='post', alpha=0.05)            
    
            # plt.plot(fauxPositifs[i], vraisPositifs[i], color=color, lw=lw,
            #          label=' ' + label_dict[i] + ' (AUC = {1:0.8f})'
            #                                                  ''.format(i, aucROCt[i]))        
    
        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])        
        plt.xlabel('Sensibilité/Rappel(Recall) = VP / (VP + FN)',size=18)
        plt.ylabel('Précision = VP / (VP + FP)',size=18)        
        plt.title('Courbe Précision-Rappel',size=20)
        plt.legend(loc="lower right") # , fontsize = 'large'
        sauvegarderImage('Courbe Précision-Rappel')
    
    cvF1, cvF1SD, cvAccuracy, cvAccSD, aucROC, avgPrecRec, accuracy, balanced_accuracy, logloss, hammingloss, precision, sensibilite, \
    f1, f2, f05, jaccard, vrais_negatifs, faux_positifs, faux_negatifs, vrais_positifs, total_positifs, aucROCtn = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(),\
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    #
    oneloss, precision_micro, precision_macro, precision_weighted, \
    sensibilite_macro, sensibilite_micro, sensibilite_weighted, \
    f1_micro, f1_macro, f1_weighted,f2_micro,f2_macro,f2_weighted,f05_micro,f05_macro,f05_weighted = \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict(), \
        dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
    
    fauxPositifs, vraisPositifs, precisions, sensibilites, aucROCt, pr_auc, tauxROC, tauxPR = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()        
    
    
    lw = 1
    # couleurs    = sns.hls_palette(len(classifieursDict.keys()), l=.4, s=.9)
    nbClasses   = len(dictLabels.keys())
    listClasses = list(dictLabels.keys())
    
    y_testA  = label_binarize(y_test, classes=listClasses)
    plt.figure(figsize=(18,18))
    
    
    t1 = time.time()  
    classifier = model
    
    # y_score     = model.predict_proba(X_test)
    # y_pred      = model.predict(X_test)
    y_score     = model.predict(X_test)
    y_pred      = np.argmax(y_score, axis=-1) 
    y_predA     = label_binarize(y_pred, classes=listClasses)
    
    accuracy['global']              = accuracy_score(y_test, y_pred)
    balanced_accuracy['global']     = balanced_accuracy_score(y_test, y_pred)
    precision['global']             = precision_score(y_test, y_pred, average='weighted')
    sensibilite['global']           = recall_score(y_test, y_pred, average='weighted')
    
    f1['global']                    = f1_score(y_test, y_pred, average='weighted')
    f2['global']                    = fbeta_score(y_test, y_pred, beta=2, average='weighted')
    f05['global']                   = fbeta_score(y_test, y_pred, beta=0.5, average='weighted')
    
    vrais_negatifs['global']        = 0
    faux_positifs ['global']        = 0
    faux_negatifs ['global']        = 0
    vrais_positifs['global']        = 0
    total_positifs['global']        = 0
    
    
    aucROC['global'] = roc_auc_score(y_test, y_score, multi_class='ovr')
    
    for i in range(nbClasses):
        fauxPositifs[i], vraisPositifs[i], tauxROC[i] = roc_curve(y_testA[:, i], y_score[:, i])
        aucROCt[i]                                    = auc(fauxPositifs[i], vraisPositifs[i])
        precisions[i], sensibilites[i], tauxPR[i]     = precision_recall_curve(y_testA[:, i], y_score[:, i])
    
        aucROC[label_dict[i]]                = aucROCt[i]
        avgPrecRec[label_dict[i]]            = average_precision_score(y_testA[:, i], y_score[:, i])
        accuracy[label_dict[i]]              = accuracy_score(y_testA[:, i], y_predA[:, i])
        balanced_accuracy[label_dict[i]]     = balanced_accuracy_score(y_testA[:, i],y_predA[:, i])
        logloss[label_dict[i]]               = log_loss(y_testA[:, i], y_predA[:, i])
        hammingloss[label_dict[i]]           = hamming_loss(y_testA[:, i], y_predA[:, i])
        precision[label_dict[i]]             = precision_score(y_testA[:, i], y_predA[:, i])
        sensibilite[label_dict[i]]           = recall_score(y_testA[:, i], y_predA[:, i])
        f1[label_dict[i]]                    = f1_score(y_testA[:, i], y_predA[:, i])
        f2[label_dict[i]]                    = fbeta_score(y_testA[:, i], y_predA[:, i], beta=2)
        f05[label_dict[i]]                   = fbeta_score(y_testA[:, i], y_predA[:, i], beta=0.5)
      
        jaccard[label_dict[i]]               = jaccard_score(y_testA[:, i], y_predA[:, i])
        vrais_negatifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 0]
        faux_positifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[0, 1]
        faux_negatifs[label_dict[i]]         = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 0]
        vrais_positifs[label_dict[i]]        = confusion_matrix(y_testA[:, i], y_predA[:, i])[1, 1]
        total_positifs[label_dict[i]]        = vrais_positifs[label_dict[i]] + faux_negatifs [label_dict[i]]
        vrais_negatifs['global']              += vrais_negatifs[label_dict[i]]
        faux_positifs ['global']              += faux_positifs [label_dict[i]]
        faux_negatifs ['global']              += faux_negatifs [label_dict[i]]
        vrais_positifs['global']              += vrais_positifs[label_dict[i]]
    
    
    total_positifs['global'] = vrais_positifs['global'] + faux_negatifs ['global']
    
    
    fauxPositifs["micro"], vraisPositifs["micro"], _ = roc_curve(y_testA.ravel(), y_score.ravel())
    aucROCt["micro"]                                 = auc(fauxPositifs["micro"], vraisPositifs["micro"])
    
    listFauxPositifs = np.unique(np.concatenate([fauxPositifs[i] for i in range(nbClasses)]))
    moyenneVraisPositifs = np.zeros_like(listFauxPositifs)
    for i in range(nbClasses):
        moyenneVraisPositifs += np.interp(listFauxPositifs, fauxPositifs[i], vraisPositifs[i])
    
    moyenneVraisPositifs /= nbClasses
    
    fauxPositifs["macro"], vraisPositifs["macro"] = listFauxPositifs, moyenneVraisPositifs
    aucROCt["macro"] = auc(fauxPositifs["macro"], vraisPositifs["macro"])
    # aucROC['global'] = aucROCt["macro"]  # (aucROCt["micro"],aucROCt["macro"])
    
    avgPrecRec['global'] = average_precision_score(y_testA.ravel(), y_score.ravel(), average='weighted')
    
    afficheCourbes(vraisPositifs,fauxPositifs,aucROCt,precisions,sensibilites,avgPrecRec,nbClasses,lw,label_dict);
    
    print ("Area under the ROC curve : %0.4f" % aucROC['global'],end='\t--\t')
    print('Exécution  :'+('%.2fs' % (time.time() - t1)).lstrip('0'))
        
    resultats = pd.DataFrame(pd.Series(aucROC), columns=["aucROC"])
    resultats["avgPrecRec"]              = pd.Series(avgPrecRec)
    resultats["f1"]                      = pd.Series(f1)
    resultats["f2"]                      = pd.Series(f2)
    resultats["f05"]                     = pd.Series(f05)
    resultats["accuracy"]                = pd.Series(accuracy)
    
    resultats["precision"]               = pd.Series(precision)
    resultats["sensibilite"]             = pd.Series(sensibilite)
    resultats["vrais_positifs"]          = pd.Series(vrais_positifs)
    resultats["vrais_negatifs"]          = pd.Series(vrais_negatifs)
    resultats["faux_positifs"]           = pd.Series(faux_positifs)
    resultats["faux_negatifs"]           = pd.Series(faux_negatifs)
    resultats["total_positifs"]          = pd.Series(total_positifs)
    
    resultats.reset_index(inplace=True)
    resultats.rename(columns={"index": "Classe"}, inplace=True)
    resultats['essai'] = nom_essai
    return resultats

def afficheProbabilites(probabilities, ind, ax, dictLabels):
    prediction = pd.DataFrame(probabilities).iloc[ind,:].reset_index()
    prediction.columns = ['Classe','Probabilite']
    prediction.Classe = prediction.Classe.apply(lambda x : f'{x:02d}-{dictLabels[x]}')
    
    graph = sns.barplot(
                        x='Classe',
                        y='Probabilite',
                        data=prediction.sort_values('Probabilite',ascending=False),
                        palette=palette[1:],
                        ax=ax        
                        );
    graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
    
    for i, patche in enumerate(graph.patches):
        if patche.get_height() > 0 :
            graph.text(
                        patche.get_x()+0.4,
                        0.4, #2*patche.get_height()/3,
                        f'{patche.get_height()*100:0.4f}%',
                        color='black',
                        rotation='vertical',
                        # size='large',
                        fontsize='large',
                        bbox=dict(boxstyle='round', facecolor='white', alpha=0.6),
                        verticalalignment='center',
                        horizontalalignment='center',
                       )       
    sauvegarderImage('Probabilités pour les 4 premiers prédictions')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Paramétrés de l’exécution</div></b>

# %%
random_seed=123456
canaux=3 
image_size=(28, 28, 3)
image_height=image_size[0]
image_width=image_size[1]

batch_size = 1024
epochs=128
dictLabels = {
                0   : 'Botte',
                1   : 'Sandale',
                2   : 'Chaussure'
       }

number_of_classes=len(dictLabels.keys())


repertoireDonneesTFRec = '../donnees/tfRecords'

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Lecture des fichiers TFRecors</div></b>

# %%
redimensionnement_normalisation = tf.keras.models.Sequential(
    [
        tf.keras.layers.Resizing(height=image_size[0], width=image_size[1]),
        tf.keras.layers.Rescaling(scale=1./127.5,offset=-1),
    ],
    name="redimensionnement_normalisation",
)

def _traitementImage(image):
    image = redimensionnement_normalisation(tf.image.decode_jpeg(image, channels=canaux))
    return image

def _lectureTFRecord(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    enregistrement['image'] =  _traitementImage(enregistrement['image'])
    return enregistrement

def _dictToImageLabel(enregistrement):
    # return enregistrement['image'],tf.one_hot(enregistrement['label'], number_of_classes)
    return enregistrement['image'],enregistrement['label']

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomFlip("vertical"),
  tf.keras.layers.RandomRotation(factor=(-0.2, 0.3)),
  tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.3),width_factor=(-0.2, -0.3)),  
])

def _lectureTFRecordAugmentation(enregistrement):
    formatTFRecord = ({
        'image': tf.io.FixedLenFeature([], tf.string),
        'label':  tf.io.FixedLenFeature([], tf.int64),
    })

    enregistrement = tf.io.parse_single_example(enregistrement, formatTFRecord)
    enregistrement['image'] = data_augmentation(_traitementImage(enregistrement['image']))
    return enregistrement

# %% [raw]
# def controleFichiersTfRecords(nom,dictLabels):
#
#     pipeline_train = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,f'{nom}-apprentissage.tfrecords'))
#     # pipeline_train = pipeline_train.map(_lectureTFRecord)
#     pipeline_train = pipeline_train.map(_lectureTFRecordAugmentation)
#     pipeline_train = pipeline_train.map(_dictToImageLabel)
#     pipeline_train = pipeline_train.batch(25)
#     pipeline_train = pipeline_train.prefetch(tf.data.AUTOTUNE)
#
#     image_batch, label_batch = next(iter(pipeline_train))
#
#     plt.figure(figsize=(24, 24))
#     for n in range(25):
#         ax = plt.subplot(5, 5, n + 1)
#         plt.imshow(image_batch[n])
#         plt.title(dictLabels[np.argmax(label_batch[n].numpy(), axis=-1)])
#         plt.axis("off")

# %% [raw]
# controleFichiersTfRecords('bloodmnist',dictLabels)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation des flux de lecture des fichiers TFRecors</div></b>

# %%
pipeline_apprentissage = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'chaussures-apprentissage.tfrecords'))
pipeline_apprentissage = pipeline_apprentissage.map(_lectureTFRecordAugmentation)
pipeline_apprentissage = pipeline_apprentissage.map(_dictToImageLabel)
pipeline_apprentissage = pipeline_apprentissage.batch(batch_size)
pipeline_apprentissage = pipeline_apprentissage.shuffle(batch_size*4)
pipeline_apprentissage = pipeline_apprentissage.repeat(4)
pipeline_apprentissage = pipeline_apprentissage.prefetch(tf.data.AUTOTUNE)  

pipeline_validation = tf.data.TFRecordDataset(os.path.join(repertoireDonneesTFRec,'chaussures-validation.tfrecords'))
pipeline_validation = pipeline_validation.map(_lectureTFRecord)
pipeline_validation = pipeline_validation.map(_dictToImageLabel)
pipeline_validation = pipeline_validation.batch(batch_size)
pipeline_validation = pipeline_validation.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
initial_lrate = 1e-3
min_lrate = 1e-4

drop_lrate = 0.5
epochs_drop = epochs * 0.1

# %%
def make_cnn_model(input_shape=image_size, 
                   num_classes=len(dictLabels.keys()), 
                   activation='relu',
                   kernel_initializer='glorot_normal',
                   nb_filtres = 256):
    inputs = tf.keras.Input(shape=input_shape)
    # Entry block
    x = tf.keras.layers.Conv2D(nb_filtres, kernel_size=(5,5), strides=(1,1), padding="same", kernel_initializer=kernel_initializer,kernel_constraint=max_norm())(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(nb_filtres, kernel_size=(3, 3), strides=(1,1), padding="same", kernel_initializer=kernel_initializer,kernel_constraint=max_norm())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding="same")(x)
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(128, kernel_size=(5,5), strides=(1,1), padding="same", kernel_initializer=kernel_initializer,kernel_constraint=max_norm())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(128, kernel_size=(3, 3), strides=(1,1), padding="same", kernel_initializer=kernel_initializer,kernel_constraint=max_norm())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding="same")(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    return tf.keras.Model(inputs, outputs)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>
#
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
# learning rate scheduler
def step_decay(epoch):
    lrate = (initial_lrate - min_lrate ) * drop_lrate**((1+epoch)/epochs_drop) + min_lrate
    return lrate
# learning schedule callback

learningRate = tf.keras.callbacks.LearningRateScheduler(step_decay)

# %%
rng = [i for i in range(epochs)]
y = [step_decay(x) for x in rng]
plt.plot(rng, y)
print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.000953 à 0.000101

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels de sauvegarde automatique du modèle </div></b>

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde chaque étape </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic1-epoch-{epoch:04d}.keras')
checkpointTimer1  = tf.keras.callbacks.ModelCheckpoint(filename,save_freq='epoch')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde tous les 5 étapes </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelAutomatic5-epoch-{epoch:04d}.keras')
checkpointTimer5 = tf.keras.callbacks.ModelCheckpoint(filename,save_freq=5)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_loss minim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVLoss-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')

checkpointLoss = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                    monitor = 'val_loss',
                                                    verbose = 1, 
                                                    save_best_only = True, 
                                                    mode = 'min')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde si val_accuracy maxim </div></b>

# %%
filename = os.path.join(repertoireSauvegardes, 'modelVAccuracy-epoch-{epoch:04d}-val_loss-{val_loss:0.3f}-val_accuracy-{val_accuracy:0.3f}.keras')
checkpointAccuracy = tf.keras.callbacks.ModelCheckpoint(filename, 
                                                           monitor = 'val_accuracy', 
                                                           verbose = 1, 
                                                           save_best_only = True, 
                                                           mode = 'max')

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Arrêt de l'apprentissage</div></b>

# %%
arretPrecoce = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, verbose=1)

# %% [markdown]
# ### <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:80%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels utilisés</div></b>

# %%
callbacks = [
    learningRate,
    # checkpointTimer1,
    # checkpointTimer5,
    checkpointLoss,
    # checkpointAccuracy,
    arretPrecoce
]

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle</div></b>

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Compilation du modèle </div></b>

# %%
np.random.seed(random_seed)
model = make_cnn_model(input_shape=image_size, 
                   num_classes=len(dictLabels.keys()), 
                   activation='relu',
                   kernel_initializer=tf.keras.initializers.LecunNormal(random_seed),
                   nb_filtres = 512)

model.compile(
    optimizer=tf.keras.optimizers.Adam(initial_lrate), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
)


start_time = time.time()

model_history = model.fit(pipeline_apprentissage, 
                    validation_data=pipeline_validation, 
                    epochs=1024, 
                    batch_size=batch_size,
                    callbacks=callbacks,
                    verbose=2
                   )
print(time.time()-start_time)
# Out:
# Epoch 1/1024
# I0000 00:00:1751909089.731020 2531889 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 5.49638, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0001-val_loss-5.496-val_accuracy-0.337.keras
# 12/12 - 48s - 4s/step - accuracy: 0.4083 - loss: 1.3264 - val_accuracy: 0.3367 - val_loss: 5.4964 - learning_rate: 9.5256e-04
# Epoch 2/1024
#
# Epoch 2: val_loss improved from 5.49638 to 2.64080, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0002-val_loss-2.641-val_accuracy-0.393.keras
# 12/12 - 12s - 1s/step - accuracy: 0.5075 - loss: 1.0400 - val_accuracy: 0.3933 - val_loss: 2.6408 - learning_rate: 9.0762e-04
# Epoch 3/1024
#
# Epoch 3: val_loss improved from 2.64080 to 1.17807, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0003-val_loss-1.178-val_accuracy-0.483.keras
# 12/12 - 9s - 709ms/step - accuracy: 0.5685 - loss: 0.9168 - val_accuracy: 0.4833 - val_loss: 1.1781 - learning_rate: 8.6505e-04
# Epoch 4/1024
#
# Epoch 4: val_loss did not improve from 1.17807
# 12/12 - 9s - 764ms/step - accuracy: 0.6123 - loss: 0.8350 - val_accuracy: 0.4333 - val_loss: 1.4635 - learning_rate: 8.2472e-04
# Epoch 5/1024
#
# Epoch 5: val_loss did not improve from 1.17807
# 12/12 - 13s - 1s/step - accuracy: 0.6217 - loss: 0.8108 - val_accuracy: 0.3300 - val_loss: 2.1679 - learning_rate: 7.8652e-04
# Epoch 6/1024
#
# Epoch 6: val_loss did not improve from 1.17807
# 12/12 - 8s - 667ms/step - accuracy: 0.6588 - loss: 0.7539 - val_accuracy: 0.3200 - val_loss: 2.6554 - learning_rate: 7.5033e-04
# Epoch 7/1024
#
# Epoch 7: val_loss did not improve from 1.17807
# 12/12 - 8s - 661ms/step - accuracy: 0.6826 - loss: 0.7104 - val_accuracy: 0.3200 - val_loss: 5.4650 - learning_rate: 7.1605e-04
# Epoch 8/1024
#
# Epoch 8: val_loss did not improve from 1.17807
# 12/12 - 11s - 887ms/step - accuracy: 0.7039 - loss: 0.6662 - val_accuracy: 0.3200 - val_loss: 6.0082 - learning_rate: 6.8358e-04
# Epoch 9/1024
#
# Epoch 9: val_loss did not improve from 1.17807
# 12/12 - 10s - 808ms/step - accuracy: 0.7244 - loss: 0.6348 - val_accuracy: 0.3200 - val_loss: 5.7082 - learning_rate: 6.5282e-04
# Epoch 10/1024
#
# Epoch 10: val_loss did not improve from 1.17807
# 12/12 - 13s - 1s/step - accuracy: 0.7343 - loss: 0.6142 - val_accuracy: 0.3200 - val_loss: 5.5223 - learning_rate: 6.2368e-04
# Epoch 11/1024
#
# Epoch 11: val_loss did not improve from 1.17807
# 12/12 - 12s - 1s/step - accuracy: 0.7463 - loss: 0.5823 - val_accuracy: 0.3200 - val_loss: 5.7920 - learning_rate: 5.9607e-04
# Epoch 12/1024
#
# Epoch 12: val_loss did not improve from 1.17807
# 12/12 - 11s - 956ms/step - accuracy: 0.7644 - loss: 0.5477 - val_accuracy: 0.3200 - val_loss: 5.3662 - learning_rate: 5.6992e-04
# Epoch 13/1024
#
# Epoch 13: val_loss did not improve from 1.17807
# 12/12 - 12s - 1s/step - accuracy: 0.7881 - loss: 0.5129 - val_accuracy: 0.3200 - val_loss: 4.5977 - learning_rate: 5.4515e-04
# Epoch 14/1024
#
# Epoch 14: val_loss did not improve from 1.17807
# 12/12 - 10s - 803ms/step - accuracy: 0.7946 - loss: 0.4984 - val_accuracy: 0.3200 - val_loss: 4.4481 - learning_rate: 5.2169e-04
# Epoch 15/1024
#
# Epoch 15: val_loss did not improve from 1.17807
# 12/12 - 13s - 1s/step - accuracy: 0.8012 - loss: 0.4764 - val_accuracy: 0.3367 - val_loss: 3.3084 - learning_rate: 4.9946e-04
# Epoch 16/1024
#
# Epoch 16: val_loss did not improve from 1.17807
# 12/12 - 11s - 900ms/step - accuracy: 0.8078 - loss: 0.4702 - val_accuracy: 0.3867 - val_loss: 2.3756 - learning_rate: 4.7840e-04
# Epoch 17/1024
#
# Epoch 17: val_loss did not improve from 1.17807
# 12/12 - 12s - 995ms/step - accuracy: 0.8210 - loss: 0.4406 - val_accuracy: 0.4200 - val_loss: 2.2604 - learning_rate: 4.5846e-04
# Epoch 18/1024
#
# Epoch 18: val_loss did not improve from 1.17807
# 12/12 - 12s - 963ms/step - accuracy: 0.8267 - loss: 0.4368 - val_accuracy: 0.4267 - val_loss: 1.8774 - learning_rate: 4.3956e-04
# Epoch 19/1024
#
# Epoch 19: val_loss did not improve from 1.17807
# 12/12 - 10s - 821ms/step - accuracy: 0.8413 - loss: 0.4057 - val_accuracy: 0.5000 - val_loss: 1.3909 - learning_rate: 4.2166e-04
# Epoch 20/1024
#
# Epoch 20: val_loss did not improve from 1.17807
# 12/12 - 12s - 1s/step - accuracy: 0.8472 - loss: 0.3881 - val_accuracy: 0.5800 - val_loss: 1.2631 - learning_rate: 4.0471e-04
# Epoch 21/1024
#
# Epoch 21: val_loss improved from 1.17807 to 0.97974, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0021-val_loss-0.980-val_accuracy-0.573.keras
# 12/12 - 12s - 974ms/step - accuracy: 0.8528 - loss: 0.3732 - val_accuracy: 0.5733 - val_loss: 0.9797 - learning_rate: 3.8865e-04
# Epoch 22/1024
#
# Epoch 22: val_loss did not improve from 0.97974
# 12/12 - 13s - 1s/step - accuracy: 0.8425 - loss: 0.3960 - val_accuracy: 0.5133 - val_loss: 1.2044 - learning_rate: 3.7343e-04
# Epoch 23/1024
#
# Epoch 23: val_loss did not improve from 0.97974
# 12/12 - 8s - 705ms/step - accuracy: 0.8536 - loss: 0.3719 - val_accuracy: 0.5900 - val_loss: 0.9805 - learning_rate: 3.5902e-04
# Epoch 24/1024
#
# Epoch 24: val_loss did not improve from 0.97974
# 12/12 - 10s - 810ms/step - accuracy: 0.8622 - loss: 0.3569 - val_accuracy: 0.4900 - val_loss: 1.3768 - learning_rate: 3.4536e-04
# Epoch 25/1024
#
# Epoch 25: val_loss did not improve from 0.97974
# 12/12 - 11s - 957ms/step - accuracy: 0.8690 - loss: 0.3406 - val_accuracy: 0.4633 - val_loss: 1.6315 - learning_rate: 3.3243e-04
# Epoch 26/1024
#
# Epoch 26: val_loss did not improve from 0.97974
# 12/12 - 13s - 1s/step - accuracy: 0.8733 - loss: 0.3288 - val_accuracy: 0.4800 - val_loss: 1.3330 - learning_rate: 3.2018e-04
# Epoch 27/1024
#
# Epoch 27: val_loss did not improve from 0.97974
# 12/12 - 10s - 852ms/step - accuracy: 0.8783 - loss: 0.3222 - val_accuracy: 0.4900 - val_loss: 1.3251 - learning_rate: 3.0857e-04
# Epoch 28/1024
#
# Epoch 28: val_loss did not improve from 0.97974
# 12/12 - 12s - 969ms/step - accuracy: 0.8753 - loss: 0.3184 - val_accuracy: 0.5833 - val_loss: 1.0570 - learning_rate: 2.9758e-04
# Epoch 29/1024
#
# Epoch 29: val_loss did not improve from 0.97974
# 12/12 - 14s - 1s/step - accuracy: 0.8756 - loss: 0.3246 - val_accuracy: 0.4833 - val_loss: 1.3923 - learning_rate: 2.8716e-04
# Epoch 30/1024
#
# Epoch 30: val_loss did not improve from 0.97974
# 12/12 - 11s - 928ms/step - accuracy: 0.8829 - loss: 0.3082 - val_accuracy: 0.6033 - val_loss: 1.0735 - learning_rate: 2.7730e-04
# Epoch 31/1024
#
# Epoch 31: val_loss did not improve from 0.97974
# 12/12 - 13s - 1s/step - accuracy: 0.8836 - loss: 0.3009 - val_accuracy: 0.6033 - val_loss: 1.0069 - learning_rate: 2.6795e-04
# Epoch 32/1024
#
# Epoch 32: val_loss did not improve from 0.97974
# 12/12 - 11s - 950ms/step - accuracy: 0.8882 - loss: 0.2937 - val_accuracy: 0.6200 - val_loss: 0.9840 - learning_rate: 2.5910e-04
# Epoch 33/1024
#
# Epoch 33: val_loss did not improve from 0.97974
# 12/12 - 9s - 788ms/step - accuracy: 0.8952 - loss: 0.2824 - val_accuracy: 0.5833 - val_loss: 1.1586 - learning_rate: 2.5071e-04
# Epoch 34/1024
#
# Epoch 34: val_loss did not improve from 0.97974
# 12/12 - 9s - 764ms/step - accuracy: 0.8905 - loss: 0.2837 - val_accuracy: 0.5833 - val_loss: 1.2102 - learning_rate: 2.4277e-04
# Epoch 35/1024
#
# Epoch 35: val_loss did not improve from 0.97974
# 12/12 - 12s - 968ms/step - accuracy: 0.8934 - loss: 0.2805 - val_accuracy: 0.6200 - val_loss: 1.0219 - learning_rate: 2.3524e-04
# Epoch 36/1024
#
# Epoch 36: val_loss did not improve from 0.97974
# 12/12 - 8s - 653ms/step - accuracy: 0.8939 - loss: 0.2752 - val_accuracy: 0.6167 - val_loss: 1.1038 - learning_rate: 2.2811e-04
# Epoch 37/1024
#
# Epoch 37: val_loss did not improve from 0.97974
# 12/12 - 11s - 892ms/step - accuracy: 0.9048 - loss: 0.2644 - val_accuracy: 0.5833 - val_loss: 1.2348 - learning_rate: 2.2136e-04
# Epoch 38/1024
#
# Epoch 38: val_loss did not improve from 0.97974
# 12/12 - 13s - 1s/step - accuracy: 0.9056 - loss: 0.2570 - val_accuracy: 0.5700 - val_loss: 1.3832 - learning_rate: 2.1496e-04
# Epoch 39/1024
#
# Epoch 39: val_loss did not improve from 0.97974
# 12/12 - 9s - 726ms/step - accuracy: 0.9096 - loss: 0.2486 - val_accuracy: 0.6167 - val_loss: 1.2581 - learning_rate: 2.0890e-04
# Epoch 40/1024
#
# Epoch 40: val_loss improved from 0.97974 to 0.92373, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0040-val_loss-0.924-val_accuracy-0.650.keras
# 12/12 - 7s - 590ms/step - accuracy: 0.9053 - loss: 0.2567 - val_accuracy: 0.6500 - val_loss: 0.9237 - learning_rate: 2.0316e-04
# Epoch 41/1024
#
# Epoch 41: val_loss did not improve from 0.92373
# 12/12 - 7s - 619ms/step - accuracy: 0.9068 - loss: 0.2566 - val_accuracy: 0.5967 - val_loss: 1.2898 - learning_rate: 1.9773e-04
# Epoch 42/1024
#
# Epoch 42: val_loss improved from 0.92373 to 0.84473, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0042-val_loss-0.845-val_accuracy-0.690.keras
# 12/12 - 10s - 862ms/step - accuracy: 0.9064 - loss: 0.2537 - val_accuracy: 0.6900 - val_loss: 0.8447 - learning_rate: 1.9257e-04
# Epoch 43/1024
#
# Epoch 43: val_loss improved from 0.84473 to 0.72526, saving model to /home/razvan/documentation/DeepLearning/CNN/07-L'apprentissage et rappels d’exécution--modèle CNN--Chaussures-TFRecods/repertoire.sauvegardes/modelVLoss-epoch-0043-val_loss-0.725-val_accuracy-0.720.keras
# 12/12 - 8s - 690ms/step - accuracy: 0.9082 - loss: 0.2459 - val_accuracy: 0.7200 - val_loss: 0.7253 - learning_rate: 1.8769e-04
# Epoch 44/1024
#
# Epoch 44: val_loss did not improve from 0.72526
# 12/12 - 11s - 945ms/step - accuracy: 0.9048 - loss: 0.2498 - val_accuracy: 0.6300 - val_loss: 1.0755 - learning_rate: 1.8307e-04
# Epoch 45/1024
#
# Epoch 45: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9127 - loss: 0.2342 - val_accuracy: 0.6700 - val_loss: 0.9502 - learning_rate: 1.7869e-04
# Epoch 46/1024
#
# Epoch 46: val_loss did not improve from 0.72526
# 12/12 - 11s - 879ms/step - accuracy: 0.9142 - loss: 0.2295 - val_accuracy: 0.6700 - val_loss: 0.9052 - learning_rate: 1.7454e-04
# Epoch 47/1024
#
# Epoch 47: val_loss did not improve from 0.72526
# 12/12 - 9s - 777ms/step - accuracy: 0.9166 - loss: 0.2330 - val_accuracy: 0.6700 - val_loss: 1.0022 - learning_rate: 1.7062e-04
# Epoch 48/1024
#
# Epoch 48: val_loss did not improve from 0.72526
# 12/12 - 6s - 523ms/step - accuracy: 0.9106 - loss: 0.2397 - val_accuracy: 0.6733 - val_loss: 0.9172 - learning_rate: 1.6689e-04
# Epoch 49/1024
#
# Epoch 49: val_loss did not improve from 0.72526
# 12/12 - 8s - 684ms/step - accuracy: 0.9150 - loss: 0.2299 - val_accuracy: 0.6433 - val_loss: 1.0776 - learning_rate: 1.6337e-04
# Epoch 50/1024
#
# Epoch 50: val_loss did not improve from 0.72526
# 12/12 - 11s - 902ms/step - accuracy: 0.9173 - loss: 0.2227 - val_accuracy: 0.6867 - val_loss: 0.9095 - learning_rate: 1.6003e-04
# Epoch 51/1024
#
# Epoch 51: val_loss did not improve from 0.72526
# 12/12 - 11s - 922ms/step - accuracy: 0.9156 - loss: 0.2258 - val_accuracy: 0.6633 - val_loss: 0.9450 - learning_rate: 1.5686e-04
# Epoch 52/1024
#
# Epoch 52: val_loss did not improve from 0.72526
# 12/12 - 9s - 723ms/step - accuracy: 0.9174 - loss: 0.2272 - val_accuracy: 0.6300 - val_loss: 1.1938 - learning_rate: 1.5387e-04
# Epoch 53/1024
#
# Epoch 53: val_loss did not improve from 0.72526
# 12/12 - 11s - 895ms/step - accuracy: 0.9231 - loss: 0.2106 - val_accuracy: 0.6167 - val_loss: 1.3183 - learning_rate: 1.5103e-04
# Epoch 54/1024
#
# Epoch 54: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9287 - loss: 0.2066 - val_accuracy: 0.6700 - val_loss: 0.9469 - learning_rate: 1.4834e-04
# Epoch 55/1024
#
# Epoch 55: val_loss did not improve from 0.72526
# 12/12 - 8s - 694ms/step - accuracy: 0.9261 - loss: 0.2053 - val_accuracy: 0.6667 - val_loss: 0.9573 - learning_rate: 1.4579e-04
# Epoch 56/1024
#
# Epoch 56: val_loss did not improve from 0.72526
# 12/12 - 10s - 862ms/step - accuracy: 0.9241 - loss: 0.2152 - val_accuracy: 0.6300 - val_loss: 1.0352 - learning_rate: 1.4337e-04
# Epoch 57/1024
#
# Epoch 57: val_loss did not improve from 0.72526
# 12/12 - 9s - 768ms/step - accuracy: 0.9258 - loss: 0.2033 - val_accuracy: 0.7167 - val_loss: 0.7796 - learning_rate: 1.4109e-04
# Epoch 58/1024
#
# Epoch 58: val_loss did not improve from 0.72526
# 12/12 - 7s - 584ms/step - accuracy: 0.9293 - loss: 0.1968 - val_accuracy: 0.6533 - val_loss: 1.0403 - learning_rate: 1.3892e-04
# Epoch 59/1024
#
# Epoch 59: val_loss did not improve from 0.72526
# 12/12 - 9s - 776ms/step - accuracy: 0.9280 - loss: 0.1993 - val_accuracy: 0.6533 - val_loss: 0.9705 - learning_rate: 1.3687e-04
# Epoch 60/1024
#
# Epoch 60: val_loss did not improve from 0.72526
# 12/12 - 7s - 592ms/step - accuracy: 0.9294 - loss: 0.1993 - val_accuracy: 0.5833 - val_loss: 1.5314 - learning_rate: 1.3493e-04
# Epoch 61/1024
#
# Epoch 61: val_loss did not improve from 0.72526
# 12/12 - 10s - 819ms/step - accuracy: 0.9255 - loss: 0.2024 - val_accuracy: 0.6800 - val_loss: 0.8699 - learning_rate: 1.3309e-04
# Epoch 62/1024
#
# Epoch 62: val_loss did not improve from 0.72526
# 12/12 - 13s - 1s/step - accuracy: 0.9289 - loss: 0.1959 - val_accuracy: 0.7100 - val_loss: 0.7444 - learning_rate: 1.3134e-04
# Epoch 63/1024
#
# Epoch 63: val_loss did not improve from 0.72526
# 12/12 - 11s - 945ms/step - accuracy: 0.9290 - loss: 0.1960 - val_accuracy: 0.7033 - val_loss: 0.7924 - learning_rate: 1.2969e-04
# Epoch 64/1024
#
# Epoch 64: val_loss did not improve from 0.72526
# 12/12 - 9s - 764ms/step - accuracy: 0.9315 - loss: 0.1906 - val_accuracy: 0.6667 - val_loss: 0.9985 - learning_rate: 1.2813e-04
# Epoch 65/1024
#
# Epoch 65: val_loss did not improve from 0.72526
# 12/12 - 11s - 951ms/step - accuracy: 0.9346 - loss: 0.1853 - val_accuracy: 0.6900 - val_loss: 0.8677 - learning_rate: 1.2664e-04
# Epoch 66/1024
#
# Epoch 66: val_loss did not improve from 0.72526
# 12/12 - 8s - 660ms/step - accuracy: 0.9350 - loss: 0.1840 - val_accuracy: 0.7033 - val_loss: 0.9335 - learning_rate: 1.2524e-04
# Epoch 67/1024
#
# Epoch 67: val_loss did not improve from 0.72526
# 12/12 - 10s - 829ms/step - accuracy: 0.9331 - loss: 0.1862 - val_accuracy: 0.6967 - val_loss: 0.8190 - learning_rate: 1.2391e-04
# Epoch 68/1024
#
# Epoch 68: val_loss did not improve from 0.72526
# 12/12 - 11s - 958ms/step - accuracy: 0.9313 - loss: 0.1855 - val_accuracy: 0.6433 - val_loss: 1.0713 - learning_rate: 1.2265e-04
# Epoch 69/1024
#
# Epoch 69: val_loss did not improve from 0.72526
# 12/12 - 10s - 802ms/step - accuracy: 0.9334 - loss: 0.1859 - val_accuracy: 0.6700 - val_loss: 0.9517 - learning_rate: 1.2145e-04
# Epoch 70/1024
#
# Epoch 70: val_loss did not improve from 0.72526
# 12/12 - 11s - 877ms/step - accuracy: 0.9381 - loss: 0.1789 - val_accuracy: 0.6733 - val_loss: 0.9239 - learning_rate: 1.2032e-04
# Epoch 71/1024
#
# Epoch 71: val_loss did not improve from 0.72526
# 12/12 - 11s - 915ms/step - accuracy: 0.9331 - loss: 0.1883 - val_accuracy: 0.6233 - val_loss: 1.1638 - learning_rate: 1.1925e-04
# Epoch 72/1024
#
# Epoch 72: val_loss did not improve from 0.72526
# 12/12 - 9s - 764ms/step - accuracy: 0.9390 - loss: 0.1767 - val_accuracy: 0.6867 - val_loss: 0.8191 - learning_rate: 1.1824e-04
# Epoch 73/1024
#
# Epoch 73: val_loss did not improve from 0.72526
# 12/12 - 10s - 821ms/step - accuracy: 0.9423 - loss: 0.1674 - val_accuracy: 0.7133 - val_loss: 0.8502 - learning_rate: 1.1728e-04
# Epoch 74/1024
#
# Epoch 74: val_loss did not improve from 0.72526
# 12/12 - 10s - 828ms/step - accuracy: 0.9414 - loss: 0.1713 - val_accuracy: 0.7000 - val_loss: 0.7895 - learning_rate: 1.1636e-04
# Epoch 75/1024
#
# Epoch 75: val_loss did not improve from 0.72526
# 12/12 - 7s - 593ms/step - accuracy: 0.9389 - loss: 0.1728 - val_accuracy: 0.7133 - val_loss: 0.8047 - learning_rate: 1.1550e-04
# Epoch 76/1024
#
# Epoch 76: val_loss did not improve from 0.72526
# 12/12 - 7s - 609ms/step - accuracy: 0.9397 - loss: 0.1716 - val_accuracy: 0.7333 - val_loss: 0.8265 - learning_rate: 1.1469e-04
# Epoch 77/1024
#
# Epoch 77: val_loss did not improve from 0.72526
# 12/12 - 8s - 707ms/step - accuracy: 0.9427 - loss: 0.1675 - val_accuracy: 0.6967 - val_loss: 0.8952 - learning_rate: 1.1391e-04
# Epoch 78/1024
#
# Epoch 78: val_loss did not improve from 0.72526
# 12/12 - 12s - 978ms/step - accuracy: 0.9411 - loss: 0.1722 - val_accuracy: 0.6633 - val_loss: 1.1333 - learning_rate: 1.1318e-04
# Epoch 79/1024
#
# Epoch 79: val_loss did not improve from 0.72526
# 12/12 - 11s - 950ms/step - accuracy: 0.9401 - loss: 0.1683 - val_accuracy: 0.6900 - val_loss: 1.0146 - learning_rate: 1.1248e-04
# Epoch 80/1024
#
# Epoch 80: val_loss did not improve from 0.72526
# 12/12 - 10s - 869ms/step - accuracy: 0.9440 - loss: 0.1629 - val_accuracy: 0.6867 - val_loss: 0.9182 - learning_rate: 1.1183e-04
# Epoch 81/1024
#
# Epoch 81: val_loss did not improve from 0.72526
# 12/12 - 8s - 665ms/step - accuracy: 0.9417 - loss: 0.1639 - val_accuracy: 0.6333 - val_loss: 1.0613 - learning_rate: 1.1120e-04
# Epoch 82/1024
#
# Epoch 82: val_loss did not improve from 0.72526
# 12/12 - 10s - 820ms/step - accuracy: 0.9464 - loss: 0.1583 - val_accuracy: 0.6967 - val_loss: 0.9863 - learning_rate: 1.1061e-04
# Epoch 83/1024
#
# Epoch 83: val_loss did not improve from 0.72526
# 12/12 - 13s - 1s/step - accuracy: 0.9469 - loss: 0.1553 - val_accuracy: 0.6733 - val_loss: 0.9499 - learning_rate: 1.1005e-04
# Epoch 84/1024
#
# Epoch 84: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9477 - loss: 0.1560 - val_accuracy: 0.6633 - val_loss: 1.0250 - learning_rate: 1.0952e-04
# Epoch 85/1024
#
# Epoch 85: val_loss did not improve from 0.72526
# 12/12 - 10s - 808ms/step - accuracy: 0.9433 - loss: 0.1593 - val_accuracy: 0.6867 - val_loss: 0.9258 - learning_rate: 1.0902e-04
# Epoch 86/1024
#
# Epoch 86: val_loss did not improve from 0.72526
# 12/12 - 12s - 974ms/step - accuracy: 0.9432 - loss: 0.1597 - val_accuracy: 0.6833 - val_loss: 0.8910 - learning_rate: 1.0854e-04
# Epoch 87/1024
#
# Epoch 87: val_loss did not improve from 0.72526
# 12/12 - 11s - 951ms/step - accuracy: 0.9462 - loss: 0.1542 - val_accuracy: 0.6733 - val_loss: 0.9411 - learning_rate: 1.0809e-04
# Epoch 88/1024
#
# Epoch 88: val_loss did not improve from 0.72526
# 12/12 - 7s - 585ms/step - accuracy: 0.9501 - loss: 0.1477 - val_accuracy: 0.6800 - val_loss: 0.9541 - learning_rate: 1.0767e-04
# Epoch 89/1024
#
# Epoch 89: val_loss did not improve from 0.72526
# 12/12 - 11s - 952ms/step - accuracy: 0.9487 - loss: 0.1481 - val_accuracy: 0.7133 - val_loss: 0.7911 - learning_rate: 1.0726e-04
# Epoch 90/1024
#
# Epoch 90: val_loss did not improve from 0.72526
# 12/12 - 9s - 786ms/step - accuracy: 0.9526 - loss: 0.1404 - val_accuracy: 0.6733 - val_loss: 0.8590 - learning_rate: 1.0688e-04
# Epoch 91/1024
#
# Epoch 91: val_loss did not improve from 0.72526
# 12/12 - 7s - 624ms/step - accuracy: 0.9504 - loss: 0.1453 - val_accuracy: 0.6233 - val_loss: 1.0284 - learning_rate: 1.0652e-04
# Epoch 92/1024
#
# Epoch 92: val_loss did not improve from 0.72526
# 12/12 - 9s - 720ms/step - accuracy: 0.9519 - loss: 0.1479 - val_accuracy: 0.6700 - val_loss: 0.9609 - learning_rate: 1.0617e-04
# Epoch 93/1024
#
# Epoch 93: val_loss did not improve from 0.72526
# 12/12 - 12s - 997ms/step - accuracy: 0.9490 - loss: 0.1457 - val_accuracy: 0.6800 - val_loss: 1.0080 - learning_rate: 1.0585e-04
# Epoch 94/1024
#
# Epoch 94: val_loss did not improve from 0.72526
# 12/12 - 11s - 938ms/step - accuracy: 0.9424 - loss: 0.1575 - val_accuracy: 0.5800 - val_loss: 1.4568 - learning_rate: 1.0554e-04
# Epoch 95/1024
#
# Epoch 95: val_loss did not improve from 0.72526
# 12/12 - 8s - 707ms/step - accuracy: 0.9479 - loss: 0.1554 - val_accuracy: 0.6733 - val_loss: 0.8031 - learning_rate: 1.0525e-04
# Epoch 96/1024
#
# Epoch 96: val_loss did not improve from 0.72526
# 12/12 - 11s - 912ms/step - accuracy: 0.9505 - loss: 0.1432 - val_accuracy: 0.5867 - val_loss: 1.2437 - learning_rate: 1.0497e-04
# Epoch 97/1024
#
# Epoch 97: val_loss did not improve from 0.72526
# 12/12 - 11s - 905ms/step - accuracy: 0.9509 - loss: 0.1411 - val_accuracy: 0.5933 - val_loss: 1.1709 - learning_rate: 1.0471e-04
# Epoch 98/1024
#
# Epoch 98: val_loss did not improve from 0.72526
# 12/12 - 11s - 935ms/step - accuracy: 0.9506 - loss: 0.1395 - val_accuracy: 0.7000 - val_loss: 0.8024 - learning_rate: 1.0446e-04
# Epoch 99/1024
#
# Epoch 99: val_loss did not improve from 0.72526
# 12/12 - 10s - 834ms/step - accuracy: 0.9541 - loss: 0.1365 - val_accuracy: 0.6267 - val_loss: 1.0301 - learning_rate: 1.0423e-04
# Epoch 100/1024
#
# Epoch 100: val_loss did not improve from 0.72526
# 12/12 - 12s - 969ms/step - accuracy: 0.9509 - loss: 0.1444 - val_accuracy: 0.7000 - val_loss: 0.7861 - learning_rate: 1.0400e-04
# Epoch 101/1024
#
# Epoch 101: val_loss did not improve from 0.72526
# 12/12 - 10s - 833ms/step - accuracy: 0.9534 - loss: 0.1350 - val_accuracy: 0.7000 - val_loss: 0.8854 - learning_rate: 1.0379e-04
# Epoch 102/1024
#
# Epoch 102: val_loss did not improve from 0.72526
# 12/12 - 11s - 916ms/step - accuracy: 0.9556 - loss: 0.1312 - val_accuracy: 0.6367 - val_loss: 1.1372 - learning_rate: 1.0359e-04
# Epoch 103/1024
#
# Epoch 103: val_loss did not improve from 0.72526
# 12/12 - 9s - 721ms/step - accuracy: 0.9531 - loss: 0.1369 - val_accuracy: 0.6800 - val_loss: 0.8389 - learning_rate: 1.0340e-04
# Epoch 104/1024
#
# Epoch 104: val_loss did not improve from 0.72526
# 12/12 - 9s - 723ms/step - accuracy: 0.9498 - loss: 0.1384 - val_accuracy: 0.6900 - val_loss: 0.9394 - learning_rate: 1.0322e-04
# Epoch 105/1024
#
# Epoch 105: val_loss did not improve from 0.72526
# 12/12 - 8s - 700ms/step - accuracy: 0.9480 - loss: 0.1437 - val_accuracy: 0.6800 - val_loss: 1.0108 - learning_rate: 1.0305e-04
# Epoch 106/1024
#
# Epoch 106: val_loss did not improve from 0.72526
# 12/12 - 11s - 913ms/step - accuracy: 0.9494 - loss: 0.1426 - val_accuracy: 0.6567 - val_loss: 0.9843 - learning_rate: 1.0289e-04
# Epoch 107/1024
#
# Epoch 107: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9565 - loss: 0.1311 - val_accuracy: 0.6200 - val_loss: 1.0532 - learning_rate: 1.0274e-04
# Epoch 108/1024
#
# Epoch 108: val_loss did not improve from 0.72526
# 12/12 - 11s - 929ms/step - accuracy: 0.9583 - loss: 0.1254 - val_accuracy: 0.6967 - val_loss: 1.0672 - learning_rate: 1.0260e-04
# Epoch 109/1024
#
# Epoch 109: val_loss did not improve from 0.72526
# 12/12 - 9s - 787ms/step - accuracy: 0.9542 - loss: 0.1329 - val_accuracy: 0.6033 - val_loss: 1.1916 - learning_rate: 1.0246e-04
# Epoch 110/1024
#
# Epoch 110: val_loss did not improve from 0.72526
# 12/12 - 12s - 995ms/step - accuracy: 0.9542 - loss: 0.1330 - val_accuracy: 0.7033 - val_loss: 0.8048 - learning_rate: 1.0233e-04
# Epoch 111/1024
#
# Epoch 111: val_loss did not improve from 0.72526
# 12/12 - 11s - 953ms/step - accuracy: 0.9593 - loss: 0.1207 - val_accuracy: 0.6933 - val_loss: 0.8207 - learning_rate: 1.0221e-04
# Epoch 112/1024
#
# Epoch 112: val_loss did not improve from 0.72526
# 12/12 - 9s - 735ms/step - accuracy: 0.9543 - loss: 0.1287 - val_accuracy: 0.6667 - val_loss: 1.0267 - learning_rate: 1.0209e-04
# Epoch 113/1024
#
# Epoch 113: val_loss did not improve from 0.72526
# 12/12 - 12s - 970ms/step - accuracy: 0.9547 - loss: 0.1341 - val_accuracy: 0.6267 - val_loss: 1.1404 - learning_rate: 1.0198e-04
# Epoch 114/1024
#
# Epoch 114: val_loss did not improve from 0.72526
# 12/12 - 11s - 921ms/step - accuracy: 0.9546 - loss: 0.1294 - val_accuracy: 0.6567 - val_loss: 1.1516 - learning_rate: 1.0188e-04
# Epoch 115/1024
#
# Epoch 115: val_loss did not improve from 0.72526
# 12/12 - 10s - 794ms/step - accuracy: 0.9531 - loss: 0.1308 - val_accuracy: 0.6000 - val_loss: 1.2533 - learning_rate: 1.0178e-04
# Epoch 116/1024
#
# Epoch 116: val_loss did not improve from 0.72526
# 12/12 - 9s - 748ms/step - accuracy: 0.9587 - loss: 0.1237 - val_accuracy: 0.6633 - val_loss: 0.9594 - learning_rate: 1.0168e-04
# Epoch 117/1024
#
# Epoch 117: val_loss did not improve from 0.72526
# 12/12 - 9s - 740ms/step - accuracy: 0.9606 - loss: 0.1227 - val_accuracy: 0.6600 - val_loss: 0.9216 - learning_rate: 1.0159e-04
# Epoch 118/1024
#
# Epoch 118: val_loss did not improve from 0.72526
# 12/12 - 9s - 716ms/step - accuracy: 0.9516 - loss: 0.1345 - val_accuracy: 0.6233 - val_loss: 1.2869 - learning_rate: 1.0151e-04
# Epoch 119/1024
#
# Epoch 119: val_loss did not improve from 0.72526
# 12/12 - 9s - 724ms/step - accuracy: 0.9500 - loss: 0.1424 - val_accuracy: 0.6633 - val_loss: 1.1971 - learning_rate: 1.0143e-04
# Epoch 120/1024
#
# Epoch 120: val_loss did not improve from 0.72526
# 12/12 - 11s - 944ms/step - accuracy: 0.9531 - loss: 0.1334 - val_accuracy: 0.6233 - val_loss: 1.2384 - learning_rate: 1.0136e-04
# Epoch 121/1024
#
# Epoch 121: val_loss did not improve from 0.72526
# 12/12 - 13s - 1s/step - accuracy: 0.9541 - loss: 0.1328 - val_accuracy: 0.6400 - val_loss: 1.2511 - learning_rate: 1.0128e-04
# Epoch 122/1024
#
# Epoch 122: val_loss did not improve from 0.72526
# 12/12 - 7s - 623ms/step - accuracy: 0.9507 - loss: 0.1377 - val_accuracy: 0.6533 - val_loss: 1.2106 - learning_rate: 1.0122e-04
# Epoch 123/1024
#
# Epoch 123: val_loss did not improve from 0.72526
# 12/12 - 12s - 981ms/step - accuracy: 0.9556 - loss: 0.1318 - val_accuracy: 0.6000 - val_loss: 1.6654 - learning_rate: 1.0115e-04
# Epoch 124/1024
#
# Epoch 124: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9627 - loss: 0.1127 - val_accuracy: 0.6867 - val_loss: 0.8407 - learning_rate: 1.0109e-04
# Epoch 125/1024
#
# Epoch 125: val_loss did not improve from 0.72526
# 12/12 - 10s - 830ms/step - accuracy: 0.9604 - loss: 0.1143 - val_accuracy: 0.6200 - val_loss: 1.1196 - learning_rate: 1.0103e-04
# Epoch 126/1024
#
# Epoch 126: val_loss did not improve from 0.72526
# 12/12 - 9s - 780ms/step - accuracy: 0.9653 - loss: 0.1128 - val_accuracy: 0.6500 - val_loss: 0.9343 - learning_rate: 1.0098e-04
# Epoch 127/1024
#
# Epoch 127: val_loss did not improve from 0.72526
# 12/12 - 11s - 907ms/step - accuracy: 0.9633 - loss: 0.1100 - val_accuracy: 0.7467 - val_loss: 0.7679 - learning_rate: 1.0093e-04
# Epoch 128/1024
#
# Epoch 128: val_loss did not improve from 0.72526
# 12/12 - 8s - 697ms/step - accuracy: 0.9606 - loss: 0.1160 - val_accuracy: 0.5800 - val_loss: 1.3762 - learning_rate: 1.0088e-04
# Epoch 129/1024
#
# Epoch 129: val_loss did not improve from 0.72526
# 12/12 - 12s - 984ms/step - accuracy: 0.9591 - loss: 0.1206 - val_accuracy: 0.6200 - val_loss: 1.1540 - learning_rate: 1.0083e-04
# Epoch 130/1024
#
# Epoch 130: val_loss did not improve from 0.72526
# 12/12 - 10s - 841ms/step - accuracy: 0.9623 - loss: 0.1096 - val_accuracy: 0.6100 - val_loss: 1.2781 - learning_rate: 1.0079e-04
# Epoch 131/1024
#
# Epoch 131: val_loss did not improve from 0.72526
# 12/12 - 13s - 1s/step - accuracy: 0.9631 - loss: 0.1129 - val_accuracy: 0.6267 - val_loss: 0.9966 - learning_rate: 1.0075e-04
# Epoch 132/1024
#
# Epoch 132: val_loss did not improve from 0.72526
# 12/12 - 10s - 806ms/step - accuracy: 0.9575 - loss: 0.1178 - val_accuracy: 0.6567 - val_loss: 0.9252 - learning_rate: 1.0071e-04
# Epoch 133/1024
#
# Epoch 133: val_loss did not improve from 0.72526
# 12/12 - 11s - 947ms/step - accuracy: 0.9573 - loss: 0.1237 - val_accuracy: 0.5833 - val_loss: 1.4966 - learning_rate: 1.0067e-04
# Epoch 134/1024
#
# Epoch 134: val_loss did not improve from 0.72526
# 12/12 - 8s - 679ms/step - accuracy: 0.9584 - loss: 0.1177 - val_accuracy: 0.6500 - val_loss: 1.2148 - learning_rate: 1.0064e-04
# Epoch 135/1024
#
# Epoch 135: val_loss did not improve from 0.72526
# 12/12 - 9s - 763ms/step - accuracy: 0.9616 - loss: 0.1187 - val_accuracy: 0.6367 - val_loss: 1.0820 - learning_rate: 1.0060e-04
# Epoch 136/1024
#
# Epoch 136: val_loss did not improve from 0.72526
# 12/12 - 10s - 793ms/step - accuracy: 0.9639 - loss: 0.1138 - val_accuracy: 0.6867 - val_loss: 0.8673 - learning_rate: 1.0057e-04
# Epoch 137/1024
#
# Epoch 137: val_loss did not improve from 0.72526
# 12/12 - 10s - 869ms/step - accuracy: 0.9635 - loss: 0.1108 - val_accuracy: 0.6300 - val_loss: 1.1023 - learning_rate: 1.0054e-04
# Epoch 138/1024
#
# Epoch 138: val_loss did not improve from 0.72526
# 12/12 - 11s - 880ms/step - accuracy: 0.9635 - loss: 0.1081 - val_accuracy: 0.6967 - val_loss: 0.7932 - learning_rate: 1.0051e-04
# Epoch 139/1024
#
# Epoch 139: val_loss did not improve from 0.72526
# 12/12 - 11s - 943ms/step - accuracy: 0.9607 - loss: 0.1116 - val_accuracy: 0.6367 - val_loss: 1.3609 - learning_rate: 1.0048e-04
# Epoch 140/1024
#
# Epoch 140: val_loss did not improve from 0.72526
# 12/12 - 9s - 772ms/step - accuracy: 0.9640 - loss: 0.1057 - val_accuracy: 0.5400 - val_loss: 1.9304 - learning_rate: 1.0046e-04
# Epoch 141/1024
#
# Epoch 141: val_loss did not improve from 0.72526
# 12/12 - 6s - 469ms/step - accuracy: 0.9629 - loss: 0.1120 - val_accuracy: 0.6533 - val_loss: 0.9052 - learning_rate: 1.0043e-04
# Epoch 142/1024
#
# Epoch 142: val_loss did not improve from 0.72526
# 12/12 - 11s - 942ms/step - accuracy: 0.9646 - loss: 0.1096 - val_accuracy: 0.5733 - val_loss: 1.3541 - learning_rate: 1.0041e-04
# Epoch 143/1024
#
# Epoch 143: val_loss did not improve from 0.72526
# 12/12 - 12s - 1s/step - accuracy: 0.9659 - loss: 0.1054 - val_accuracy: 0.6633 - val_loss: 0.8705 - learning_rate: 1.0039e-04
# Epoch 143: early stopping
# 1503.7015926837921

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
history = sauvegardeHistorique(model_history,
                               repertoireSauvegardes,
                               nomSauvegarde='history_batch_size_32')

# %%
afficheHistoriqueEntrainement(history, palette, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %%
sauvegarderModel(model, 'history_batch_size_32')

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Chargement du modèle </div></b>

# %%
model = tf.keras.models.load_model(os.path.join(repertoireSauvegardes,'Keras-03-HistoriqueEntrainement.history_batch_size_32.keras'))

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
for i, (img,lab) in enumerate(pipeline_validation):
    if i == 0 : 
        images, labels = img,lab
    else:
        images, labels = tf.concat([images,img], 0), tf.concat([labels,lab], 0)

# %%
probabilities = model.predict(images, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 4 premiers prédictions </div></b>

# %%
fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(48,16));
for i in range(4):
    afficheProbabilites(probabilities,ind=i,ax=ax[i], dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheMatriceConfusion(observations=labels,predictions=predictions,dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=images,
                                                  y_test=labels,
                                                  label_dict=dictLabels,
                                                  couleurs=palette[2:],
                                                  nom_essai = 'initial'
                                                 )
resultats
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Area under the ROC curve : 0.8556	--	Exécution  :7.38s
#       Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0     global  0.855607    0.751277  0.664942  0.663324  0.668676  0.663333
# 1      Botte  0.882552    0.838835  0.709360  0.724346  0.694981  0.803333
# 2    Sandale  0.897199    0.809567  0.690722  0.654297  0.731441  0.800000
# 3  Chaussure  0.787071    0.660617  0.591133  0.610998  0.572519  0.723333
#
#    precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0   0.672454     0.663333             199             499            101
# 1   0.685714     0.734694              72             169             33
# 2   0.761364     0.632075              67             173             21
# 3   0.560748     0.625000              60             157             47
#
#    faux_negatifs  total_positifs    essai
# 0            101             300  initial
# 1             26              98  initial
# 2             39             106  initial
# 3             36              96  initial
